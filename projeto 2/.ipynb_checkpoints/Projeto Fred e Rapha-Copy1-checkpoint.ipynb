# %%
import socnet as sn
import networkx as nx
import pickle
import holoviews as hv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy.stats as ss
import numpy as np
import datetime
import dateutil.parser

from scipy.optimize import minimize, fmin_l_bfgs_b
from scipy.stats.stats import pearsonr

# import coreness
# hv.extension('bokeh')
# %opts Graph [width=400 height=400]
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
sn.node_size = 10
sn.node_color = (255, 255, 255)

sn.edge_width = 1
sn.edge_color = (192, 192, 192)

sn.node_label_position = 'top center'

# %% [markdown]
# ## Grafo
# <img src='./youtubeegg.png'/>

# %%
try:
    g = pickle.load(open('graph.p', 'rb'))
except:
    g = sn.load_graph('./collector/output.gml', has_pos=False)
    pickle.dump(g, open('graph.p', 'wb'))

for n in g.nodes:
    if ('country' not in g.nodes[n]):
        g.nodes[n]['country'] = None
    if ('publishedAt' not in g.nodes[n]):
        g.nodes[n]['publishedAt'] = None
        
    g.nodes[n]['viewCount'] = int(g.nodes[n]['viewCount'])
    g.nodes[n]['subscriberCount'] = int(g.nodes[n]['subscriberCount'])
    g.nodes[n]['videoCount'] = int(g.nodes[n]['videoCount'])
    if g.nodes[n]['publishedAt'] != None:
        g.nodes[n]['publishedAt'] = dateutil.parser.parse(g.nodes[n]['publishedAt'][:-1]).timestamp()

# %%
g.remove_edges_from(nx.selfloop_edges(g))

# %%
#sn.show_graph(g, nlab=False)

# %%
in_degree = sorted([(g.nodes[k], v) for k, v in dict(g.in_degree()).items()], key=lambda x: -x[1])
# s = [g.nodes[x[0]] for x in s if g.nodes[x[0]]['country'] == 'BR']
in_degree
# Out:
# [({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 956,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5339688413982051, 0.3292912282625936),
#    'publishedAt': 1145034449.0,
#    'subscriberCount': 17726175,
#    'title': 'Vevo',
#    'topics': {'n0': 'music'},
#    'videoCount': 1552,
#    'viewCount': 549779903,
#    'visited': 1},
#   25),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1475,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.13541765653438587, 0.8278394288222638),
#    'publishedAt': 1277240596.0,
#    'subscriberCount': 354843,
#    'title': 'Elgato Gaming',
#    'topics': {'n0': 'gaming', 'n1': 'technology', 'n2': 'lifestyle'},
#    'videoCount': 153,
#    'viewCount': 6547153,
#    'visited': 1},
#   24),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2043,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3926043641733174, 0.5710534713746201),
#    'publishedAt': 1271075965.0,
#    'subscriberCount': 5414470,
#    'title': 'Vikkstar123',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 4461,
#    'viewCount': 1475937480,
#    'visited': 1},
#   24),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 96,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4471181461766864, 0.42499440172747555),
#    'publishedAt': 1280455566.0,
#    'subscriberCount': 7353952,
#    'title': 'BRKsEDU',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 3762,
#    'viewCount': 1318455770,
#    'visited': 1},
#   20),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 374,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5024514805471674, 0.3741426771030991),
#    'publishedAt': 1185828213.0,
#    'subscriberCount': 13846965,
#    'title': 'Vsauce',
#    'topics': {'n0': 'lifestyle', 'n1': 'gaming'},
#    'videoCount': 370,
#    'viewCount': 1507323686,
#    'visited': 1},
#   19),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 192,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.42293428686195833, 0.5271730301700012),
#    'publishedAt': 1317952249.0,
#    'subscriberCount': 15780628,
#    'title': 'AuthenticGames',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3516,
#    'viewCount': 6318297208,
#    'visited': 1},
#   17),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1646,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.409319446451995, 0.5993522121452786),
#    'publishedAt': 1248484302.0,
#    'subscriberCount': 19809162,
#    'title': 'KSI',
#    'topics': {'n0': 'music', 'n1': 'sports game', 'n2': 'gaming'},
#    'videoCount': 1171,
#    'viewCount': 4586055969,
#    'visited': 1},
#   17),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1586,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.12076313968707757, 0.3635013993248653),
#    'publishedAt': 1305232451.0,
#    'subscriberCount': 5154046,
#    'title': 'Mini Ladd',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 1251,
#    'viewCount': 1179340436,
#    'visited': 1},
#   16),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1011,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.507309768746155, 0.5803958844805327),
#    'publishedAt': 1275283289.0,
#    'subscriberCount': 5495105,
#    'title': 'FaZe Clan',
#    'topics': {'n0': 'action game', 'n1': 'gaming', 'n2': 'music'},
#    'videoCount': 1471,
#    'viewCount': 571068921,
#    'visited': 1},
#   16),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1569,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4730428056712681, 0.5960428963055621),
#    'publishedAt': 1326751903.0,
#    'subscriberCount': 6406296,
#    'title': 'Daithi De Nogla',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 1040,
#    'viewCount': 1007256994,
#    'visited': 1},
#   15),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2243,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4505111238497373, 0.430199262728599),
#    'publishedAt': 1339873540.0,
#    'subscriberCount': 6172327,
#    'title': 'Sandaroo Kids [DisneyCarToys]',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 3157,
#    'viewCount': 6990246549,
#    'visited': 1},
#   15),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1601,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5455584898878241, 0.5911860358119901),
#    'publishedAt': 1316977705.0,
#    'subscriberCount': 6644207,
#    'title': 'I AM WILDCAT',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 991,
#    'viewCount': 1335479735,
#    'visited': 1},
#   14),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 210,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5480413121712584, 0.5360438505293251),
#    'publishedAt': 1329091105.0,
#    'subscriberCount': 20877027,
#    'title': 'rezendeevil',
#    'topics': {'n0': 'role-playing video game',
#     'n1': 'gaming',
#     'n2': 'entertainment'},
#    'videoCount': 6845,
#    'viewCount': 7221061643,
#    'visited': 1},
#   14),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 4068,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6485988345474812, 0.0229077705579767),
#    'publishedAt': 1391535382.0,
#    'subscriberCount': 68295,
#    'title': 'TOPSIFY',
#    'topics': {'n0': 'music'},
#    'videoCount': 3,
#    'viewCount': 12221,
#    'visited': 1},
#   14),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1021,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.31887319250286317, 0.03496754787187613),
#    'publishedAt': 1528793273.0,
#    'subscriberCount': 22537,
#    'title': 'Vevo Playlists',
#    'topics': {'n0': 'pop music', 'n1': 'music'},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   14),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 198,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.48455823949674476, 0.6350173013603411),
#    'publishedAt': 1333802140.0,
#    'subscriberCount': 5130254,
#    'title': 'SirKazzio',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 4099,
#    'viewCount': 964950693,
#    'visited': 1},
#   13),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1582,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4558307397680718, 0.4816876471181122),
#    'publishedAt': 1316024620.0,
#    'subscriberCount': 4229029,
#    'title': 'BasicallyIDoWrk',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 938,
#    'viewCount': 645138155,
#    'visited': 1},
#   13),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2709,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5717488244752316, 0.5511699889220658),
#    'publishedAt': 1343311066.0,
#    'subscriberCount': 13494901,
#    'title': 'W2S',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 644,
#    'viewCount': 3755412243,
#    'visited': 1},
#   13),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3048,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.45861638579663994, 0.5254475264538776),
#    'publishedAt': 1366807361.0,
#    'subscriberCount': 9164163,
#    'title': 'Toys And Funny Kids Play Doh Cartoons',
#    'topics': {'n0': 'hobby',
#     'n1': 'lifestyle',
#     'n2': 'movies',
#     'n3': 'entertainment'},
#    'videoCount': 2565,
#    'viewCount': 2681334946,
#    'visited': 1},
#   13),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1612,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.44866657971485524, 0.5811321197073571),
#    'publishedAt': 1316070329.0,
#    'subscriberCount': 23917026,
#    'title': 'VanossGaming',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 902,
#    'viewCount': 10193065462,
#    'visited': 1},
#   13),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 303,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6392481105991291, 0.544628576485052),
#    'publishedAt': 1434056858.0,
#    'subscriberCount': 2184742,
#    'title': 'Sr Pedro',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2926,
#    'viewCount': 345890463,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 166,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4794296313471904, 0.4371773566187114),
#    'publishedAt': 1355539470.0,
#    'subscriberCount': 12164492,
#    'title': 'AM3NlC',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3789,
#    'viewCount': 3319216094,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2059,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.39502178440919444, 0.46043409858174383),
#    'publishedAt': 1203265660.0,
#    'subscriberCount': 7698005,
#    'title': 'Miniminter',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 1613,
#    'viewCount': 2625546940,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1580,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4025077892902341, 0.5150708457473848),
#    'publishedAt': 1306697648.0,
#    'subscriberCount': 2982131,
#    'title': 'Moo',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 852,
#    'viewCount': 347584015,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7632,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4294773052897915, 0.3133188956955176),
#    'publishedAt': 1172629520.0,
#    'subscriberCount': 16216990,
#    'title': 'Werevertumorro',
#    'topics': {'n0': 'entertainment',
#     'n1': 'humor',
#     'n2': 'music',
#     'n3': 'movies'},
#    'videoCount': 1038,
#    'viewCount': 2544610988,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 278,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3688886673683893, 0.5622948631531831),
#    'publishedAt': 1329695872.0,
#    'subscriberCount': 4494173,
#    'title': 'BaixaMemoria',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2029,
#    'viewCount': 518062179,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2098,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4956897537039831, 0.419452420398645),
#    'publishedAt': 1127360747.0,
#    'subscriberCount': 19292899,
#    'title': 'shane',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 1731,
#    'viewCount': 4604096671,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1555,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3916313248456595, 0.49166260640980036),
#    'publishedAt': 1179996247.0,
#    'subscriberCount': 11378477,
#    'title': 'H2ODelirious',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 1654,
#    'viewCount': 2596269379,
#    'visited': 1},
#   12),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 217,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.49173246186953246, 0.43790015932505527),
#    'publishedAt': 1310515732.0,
#    'subscriberCount': 10587447,
#    'title': 'TazerCraft',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3039,
#    'viewCount': 3621971219,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1953,
#    'country': 'IE',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.49342129158991316, 0.541504752318546),
#    'publishedAt': 1172327336.0,
#    'subscriberCount': 20830430,
#    'title': 'jacksepticeye',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 3954,
#    'viewCount': 10336039005,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1971,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.46450024279518193, 0.5930848534376348),
#    'publishedAt': 1253906983.0,
#    'subscriberCount': 1278008,
#    'title': 'Mr Sark',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 487,
#    'viewCount': 294158203,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 675,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.58420310741264, 0.3879988306377455),
#    'publishedAt': 1279696682.0,
#    'subscriberCount': 5004410,
#    'title': 'Veritasium',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 253,
#    'viewCount': 463460432,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 127,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4693872687792422, 0.5640449026451859),
#    'publishedAt': 1335410779.0,
#    'subscriberCount': 4457706,
#    'title': 'CasalDeNerd',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2359,
#    'viewCount': 1262349113,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7645,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.404579136551416, 0.4449437609472902),
#    'publishedAt': 1396529971.0,
#    'subscriberCount': 5546473,
#    'title': 'PelucheEn ElEstuche',
#    'topics': {'n0': 'entertainment', 'n1': 'music'},
#    'videoCount': 309,
#    'viewCount': 737033413,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 174,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5550897200175391, 0.47474187131483686),
#    'publishedAt': 1426790506.0,
#    'subscriberCount': 2933320,
#    'title': 'Pokey',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1683,
#    'viewCount': 278900294,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 176,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.46881259602137376, 0.5655328224107475),
#    'publishedAt': 1233091919.0,
#    'subscriberCount': 5302745,
#    'title': 'malena010102',
#    'topics': {'n0': 'pop music', 'n1': 'gaming', 'n2': 'music'},
#    'videoCount': 3058,
#    'viewCount': 748187287,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1008,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4265201111062303, 0.5009489213676815),
#    'publishedAt': 1148093022.0,
#    'subscriberCount': 8609791,
#    'title': 'CrashCourse',
#    'topics': {'n0': 'knowledge', 'n1': 'entertainment', 'n2': 'society'},
#    'videoCount': 1045,
#    'viewCount': 954170670,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3872,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7791344212010013, 0.08532427090655782),
#    'publishedAt': 1158615902.0,
#    'subscriberCount': 308892,
#    'title': 'Warner Music Group',
#    'topics': {'n0': 'music', 'n1': 'pop music'},
#    'videoCount': 2,
#    'viewCount': 458527,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 298,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7085761362607496, 0.500071578116367),
#    'publishedAt': 1418135629.0,
#    'subscriberCount': 5666288,
#    'title': 'BIBI',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2194,
#    'viewCount': 657907678,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2137,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.49412880917898727, 0.5164166359273973),
#    'publishedAt': 1321403232.0,
#    'subscriberCount': 3144960,
#    'title': 'TBJZL',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 831,
#    'viewCount': 336306693,
#    'visited': 1},
#   11),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1679,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5988259849556736, 0.6257053857677763),
#    'publishedAt': 1204868186.0,
#    'subscriberCount': 4360001,
#    'title': 'AndreasChoice',
#    'topics': {'n0': 'lifestyle', 'n1': 'fashion'},
#    'videoCount': 191,
#    'viewCount': 278425070,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 195,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6550628541543704, 0.4324856529928351),
#    'publishedAt': 1391212945.0,
#    'subscriberCount': 2658153,
#    'title': 'Luiz1227',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1519,
#    'viewCount': 258524736,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 329,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9613543307946971, 0.42765541172545357),
#    'publishedAt': 1453663371.0,
#    'subscriberCount': 657905,
#    'title': 'Craft Studios',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1564,
#    'viewCount': 52405916,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 335,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6601586565141534, 0.8949169295954797),
#    'publishedAt': 1373497205.0,
#    'subscriberCount': 964467,
#    'title': 'Orion',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1201,
#    'viewCount': 106297031,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2004,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5559776947325509, 0.5146483071651958),
#    'publishedAt': 1232156705.0,
#    'subscriberCount': 5105544,
#    'title': 'Lui Calibre',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 448,
#    'viewCount': 562656956,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1297,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.516723305200761, 0.5541990181837749),
#    'publishedAt': 1231027436.0,
#    'subscriberCount': 3961460,
#    'title': 'Kandee Johnson',
#    'topics': {'n0': 'lifestyle', 'n1': 'fashion'},
#    'videoCount': 635,
#    'viewCount': 450179635,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1278,
#    'country': 'CA',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5542579156073599, 0.4909663712886547),
#    'publishedAt': 1303157214.0,
#    'subscriberCount': 2292002,
#    'title': 'SMii7Y',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 648,
#    'viewCount': 431825886,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 674,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4890848757102676, 0.43621794683996457),
#    'publishedAt': 1144123944.0,
#    'subscriberCount': 6049683,
#    'title': 'SmarterEveryDay',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 288,
#    'viewCount': 519851329,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1437,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5985531163710741, 0.4603557149925856),
#    'publishedAt': 1167481662.0,
#    'subscriberCount': 2240312,
#    'title': 'HIKAKIN',
#    'topics': {'n0': 'music', 'n1': 'hip hop music'},
#    'videoCount': 167,
#    'viewCount': 450980847,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3057,
#    'country': 'CA',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5458978683664096, 0.9455140826290892),
#    'publishedAt': 1371927586.0,
#    'subscriberCount': 355193,
#    'title': 'CottonCandyCorner',
#    'topics': {'n0': 'lifestyle', 'n1': 'hobby'},
#    'videoCount': 1315,
#    'viewCount': 186363751,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2093,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.45104727354025215, 0.5708050772725135),
#    'publishedAt': 1260068962.0,
#    'subscriberCount': 3099422,
#    'title': 'Zerkaa',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 1553,
#    'viewCount': 482566913,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1890,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5047740408549651, 0.5505161179798347),
#    'publishedAt': 1186405276.0,
#    'subscriberCount': 4137823,
#    'title': 'Julia Silva',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 1259,
#    'viewCount': 914155201,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7340,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.45510635246187775, 0.47328472960858353),
#    'publishedAt': 1309645257.0,
#    'subscriberCount': 9013046,
#    'title': 'Rayito',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 353,
#    'viewCount': 809252990,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1465,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3994421966946739, 0.590001926557327),
#    'publishedAt': 1190175996.0,
#    'subscriberCount': 7650138,
#    'title': 'Tyler Oakley',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 551,
#    'viewCount': 670802055,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6812507594788793, 0.49434988704062666),
#    'publishedAt': 1276293985.0,
#    'subscriberCount': 10191504,
#    'title': 'EU FICO LOKO',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 774,
#    'viewCount': 858775245,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1591,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4159482843760087, 0.5113498689033525),
#    'publishedAt': 1329855911.0,
#    'subscriberCount': 1491389,
#    'title': 'fourzer0seven',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 675,
#    'viewCount': 110575954,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1865,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.1043178893027076, 0.5889221392818519),
#    'publishedAt': 1248631298.0,
#    'subscriberCount': 5294435,
#    'title': 'PointlessBlog',
#    'topics': {'n0': 'lifestyle', 'n1': 'gaming'},
#    'videoCount': 258,
#    'viewCount': 495470311,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5936,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4146640503561059, 0.5460017004270109),
#    'publishedAt': 1325367766.0,
#    'subscriberCount': 5546763,
#    'title': 'Luan Palomera',
#    'topics': {'n0': 'technology', 'n1': 'lifestyle'},
#    'videoCount': 611,
#    'viewCount': 725720732,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2282,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4634834780778332, 0.450952431071393),
#    'publishedAt': 1423170113.0,
#    'subscriberCount': 1506591,
#    'title': 'Funhaus',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 1935,
#    'viewCount': 942415960,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 967,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5251953685710086, 0.44856428586619307),
#    'publishedAt': 1167699866.0,
#    'subscriberCount': 3156316,
#    'title': 'vlogbrothers',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 1668,
#    'viewCount': 763913438,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3074,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.44299953251259194, 0.5161209802065989),
#    'publishedAt': 1174854843.0,
#    'subscriberCount': 3270275,
#    'title': 'Toy Trains 4u',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'hobby',
#     'n2': 'entertainment',
#     'n3': 'vehicles'},
#    'videoCount': 2987,
#    'viewCount': 4441717764,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 273,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6270204492920118, 0.5917743986194032),
#    'publishedAt': 1381735179.0,
#    'subscriberCount': 1653663,
#    'title': 'Flokiis',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1099,
#    'viewCount': 131792454,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7711,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5484260593188846, 0.5472161162885131),
#    'publishedAt': 1413245754.0,
#    'subscriberCount': 28602699,
#    'title': 'Badabun',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 3420,
#    'viewCount': 7493539327,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 289,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.39781863433689035, 0.5543602198124026),
#    'publishedAt': 1334290504.0,
#    'subscriberCount': 4285532,
#    'title': 'Spok',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3998,
#    'viewCount': 461824900,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1595,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5640138152755733, 0.6406555579562407),
#    'publishedAt': 1206113154.0,
#    'subscriberCount': 7375284,
#    'title': 'Marques Brownlee',
#    'topics': {'n0': 'technology', 'n1': 'lifestyle'},
#    'videoCount': 1069,
#    'viewCount': 1103053438,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 221,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5347169952752536, 0.37777180253351084),
#    'publishedAt': 1420941185.0,
#    'subscriberCount': 5763100,
#    'title': 'PortugaPC',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1324,
#    'viewCount': 699937946,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 310,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5102124255868874, 0.500015597106095),
#    'publishedAt': 1261136630.0,
#    'subscriberCount': 1403953,
#    'title': 'Jabuti',
#    'topics': {'n0': 'gaming',
#     'n1': 'role-playing video game',
#     'n2': 'action game'},
#    'videoCount': 3281,
#    'viewCount': 144992183,
#    'visited': 1},
#   10),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 959,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9131504997889792, 0.5589628207215548),
#    'publishedAt': 1266271567.0,
#    'subscriberCount': 10651646,
#    'title': 'CaseyNeistat',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 979,
#    'viewCount': 2431711057,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8056,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.223384170977305, 0.1361670780152937),
#    'publishedAt': 1320098906.0,
#    'subscriberCount': 79008,
#    'title': 'Banaz',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 216,
#    'viewCount': 8524779,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8023,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7044060078604321, 0.9234548321357621),
#    'publishedAt': 1512432065.0,
#    'subscriberCount': 166014,
#    'title': 'La Gambeta',
#    'topics': {'n0': 'football', 'n1': 'sports'},
#    'videoCount': 502,
#    'viewCount': 33729344,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7744,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.40762790878786687, 0.410224222390841),
#    'publishedAt': 1297620778.0,
#    'subscriberCount': 1933008,
#    'title': 'QuePario!',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 571,
#    'viewCount': 377317679,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8051,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5816890589588917, 0.7190953595281792),
#    'publishedAt': 1532713337.0,
#    'subscriberCount': 2256603,
#    'title': 'Juki Dog',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 22,
#    'viewCount': 37352391,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8067,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.685561150158313, 0.9694209454071837),
#    'publishedAt': 1443227425.0,
#    'subscriberCount': 367251,
#    'title': 'Jiapsi Yanez',
#    'topics': {'n0': 'lifestyle', 'n1': 'music'},
#    'videoCount': 134,
#    'viewCount': 9115870,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8086,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.753917059508123, 0.06021243617013583),
#    'publishedAt': 1537807900.0,
#    'subscriberCount': 3908,
#    'title': 'Diario de Venus',
#    'topics': {'n0': 'music', 'n1': 'society', 'n2': 'entertainment'},
#    'videoCount': 3,
#    'viewCount': 101650,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1154,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3628026332399416, 0.4891107046915545),
#    'publishedAt': 1415538954.0,
#    'subscriberCount': 4412027,
#    'title': 'bytarifa',
#    'topics': {'n0': 'lifestyle', 'n1': 'food'},
#    'videoCount': 140,
#    'viewCount': 328782995,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8045,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8468555922561196, 0.8441069320229804),
#    'publishedAt': 1430150159.0,
#    'subscriberCount': 537981,
#    'title': 'Leo Osuna',
#    'topics': {'n0': 'entertainment', 'n1': 'technology', 'n2': 'lifestyle'},
#    'videoCount': 3,
#    'viewCount': 4069297,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 19,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4969023187506615, 0.45732508472518413),
#    'publishedAt': 1283309943.0,
#    'subscriberCount': 3538332,
#    'title': 'La Fenix',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 1009,
#    'viewCount': 573202164,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 297,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4321668966330723, 0.656970126061766),
#    'publishedAt': 1332122041.0,
#    'subscriberCount': 1141170,
#    'title': 'Nofaxu',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2140,
#    'viewCount': 115965143,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8095,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.0027520006108375777, 0.4632861457278889),
#    'publishedAt': 1539039063.0,
#    'subscriberCount': 52528,
#    'title': 'Max',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 1,
#    'viewCount': 160392,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2388,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4996909159732886, 0.5955389877179814),
#    'publishedAt': 1257822603.0,
#    'subscriberCount': 10560950,
#    'title': 'Jesse',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle', 'n2': 'humor'},
#    'videoCount': 246,
#    'viewCount': 2061412865,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8034,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7480203676356316, 0.10302414588459696),
#    'publishedAt': 1521920907.0,
#    'subscriberCount': 769057,
#    'title': 'Corte Y Queda',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 39,
#    'viewCount': 31646426,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 179,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.35344538317088053, 0.48174396680380055),
#    'publishedAt': 1389316380.0,
#    'subscriberCount': 7267762,
#    'title': 'Afreim',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2523,
#    'viewCount': 987893367,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8076,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9095818814810634, 0.7603655448646834),
#    'publishedAt': 1513132460.0,
#    'subscriberCount': 22971,
#    'title': 'Alfa Games',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 20,
#    'viewCount': 607652,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8040,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9659331085621669, 0.5729588452002069),
#    'publishedAt': 1399650001.0,
#    'subscriberCount': 544454,
#    'title': 'BCRPOWER',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 389,
#    'viewCount': 61867384,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1615,
#    'country': 'IE',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.42992874872166575, 0.6234344372678011),
#    'publishedAt': 1304920411.0,
#    'subscriberCount': 2859653,
#    'title': 'Terroriser',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 1000,
#    'viewCount': 292873181,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5356,
#    'country': 'IN',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5442886494613991, 0.4093457531541055),
#    'publishedAt': 1360396308.0,
#    'subscriberCount': 21053770,
#    'title': 'ChuChu TV Nursery Rhymes & Kids Songs',
#    'topics': {'n0': 'music', 'n1': 'entertainment'},
#    'videoCount': 268,
#    'viewCount': 15992224046,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1989,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5194537516260026, 0.5572701172828589),
#    'publishedAt': 1315867975.0,
#    'subscriberCount': 1622180,
#    'title': 'JoblessGarrett',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 3416,
#    'viewCount': 270637700,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8057,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5838184037620876, 0.9319870937313798),
#    'publishedAt': 1421169060.0,
#    'subscriberCount': 740247,
#    'title': 'Victor Gonzalez',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 35,
#    'viewCount': 11675967,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7752,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5488519037714992, 0.547607041241404),
#    'publishedAt': 1459643276.0,
#    'subscriberCount': 1753625,
#    'title': 'Malcriado',
#    'topics': {'n0': 'society', 'n1': 'lifestyle', 'n2': 'entertainment'},
#    'videoCount': 48,
#    'viewCount': 43606898,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8093,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.16827645538001432, 0.10643099320393162),
#    'publishedAt': 1534030612.0,
#    'subscriberCount': 9632,
#    'title': 'Sin Censura',
#    'topics': {'n0': 'society'},
#    'videoCount': 2,
#    'viewCount': 109736,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1240,
#    'country': 'ES',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.37406041260794315, 0.5994176179517294),
#    'publishedAt': 1366133069.0,
#    'subscriberCount': 5062682,
#    'title': 'TheShooterCoC',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 191,
#    'viewCount': 374360402,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8096,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9509817931630296, 0.736058215173755),
#    'publishedAt': 1527527475.0,
#    'subscriberCount': 42883,
#    'title': 'El Chinchillas',
#    'topics': {},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8061,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.061973528742755676, 0.26544048061096254),
#    'publishedAt': 1542396984.0,
#    'subscriberCount': 2909,
#    'title': 'Javi Ferrer',
#    'topics': {'n0': 'music'},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 314,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.36789069050106554, 0.5008160926662152),
#    'publishedAt': 1346362989.0,
#    'subscriberCount': 7091624,
#    'title': 'Jazzghost',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3160,
#    'viewCount': 1452544982,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1178,
#    'country': 'ES',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4759638405136676, 0.5408097831027393),
#    'publishedAt': 1416680778.0,
#    'subscriberCount': 3478963,
#    'title': 'Salva',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'strategy video game',
#     'n2': 'gaming',
#     'n3': 'entertainment'},
#    'videoCount': 194,
#    'viewCount': 272724414,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 424,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3937768119722329, 0.4246478131764926),
#    'publishedAt': 1316090701.0,
#    'subscriberCount': 2677560,
#    'title': 'Numberphile',
#    'topics': {'n0': 'lifestyle', 'n1': 'knowledge'},
#    'videoCount': 500,
#    'viewCount': 369678209,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8052,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9598058132342189, 0.6199858454330467),
#    'publishedAt': 1384720618.0,
#    'subscriberCount': 514127,
#    'title': 'Carlos Rizo',
#    'topics': {'n0': 'music', 'n1': 'entertainment', 'n2': 'lifestyle'},
#    'videoCount': 93,
#    'viewCount': 12709821,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1056,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4663769644714149, 0.5170778900412752),
#    'publishedAt': 1262574919.0,
#    'subscriberCount': 10608059,
#    'title': 'The King of Random',
#    'topics': {'n0': 'food', 'n1': 'lifestyle'},
#    'videoCount': 784,
#    'viewCount': 2060108301,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8079,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7949030786307393, 0.8731349197518943),
#    'publishedAt': 1335595731.0,
#    'subscriberCount': 82062,
#    'title': 'Jorge Valenzuela',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'performing arts',
#     'n2': 'entertainment'},
#    'videoCount': 21,
#    'viewCount': 3044024,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 232,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.591654223392006, 0.457966080568925),
#    'publishedAt': 1359478342.0,
#    'subscriberCount': 1558547,
#    'title': 'MissPinguina',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1533,
#    'viewCount': 162898271,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1663,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5387772411884277, 0.5070819833184951),
#    'publishedAt': 1276478786.0,
#    'subscriberCount': 5221222,
#    'title': 'devinsupertramp',
#    'topics': {'n0': 'lifestyle', 'n1': 'music'},
#    'videoCount': 301,
#    'viewCount': 1163934679,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 215,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.43283054766649726, 0.5245074800475575),
#    'publishedAt': 1413660818.0,
#    'subscriberCount': 2466625,
#    'title': 'MayconLorenz',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1240,
#    'viewCount': 216142103,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8088,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.11117905305593265, 0.22760461069593801),
#    'publishedAt': 1537824990.0,
#    'subscriberCount': 28325,
#    'title': 'Majo',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 1,
#    'viewCount': 55238,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3042,
#    'country': 'AU',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.39210140555320294, 0.5541577169239935),
#    'publishedAt': 1268799601.0,
#    'subscriberCount': 4419628,
#    'title': 'Fluffy Jet Toys',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle', 'n2': 'entertainment'},
#    'videoCount': 1414,
#    'viewCount': 2618259360,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2069,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5890122212599846, 0.4983829714556134),
#    'publishedAt': 1379619076.0,
#    'subscriberCount': 17597743,
#    'title': 'Jake Paul',
#    'topics': {'n0': 'entertainment',
#     'n1': 'music',
#     'n2': 'hip hop music',
#     'n3': 'pop music',
#     'n4': 'lifestyle'},
#    'videoCount': 709,
#    'viewCount': 5170097479,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8030,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9616030086263481, 0.6594611709569451),
#    'publishedAt': 1245801555.0,
#    'subscriberCount': 576868,
#    'title': 'Alberto del Arco',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 214,
#    'viewCount': 21190371,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2782,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.37763927066557523, 0.6231496971983977),
#    'publishedAt': 1330106570.0,
#    'subscriberCount': 2995563,
#    'title': 'Behzinga',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 776,
#    'viewCount': 398115044,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8005,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4290336212546436, 0.985001463021436),
#    'publishedAt': 1289627839.0,
#    'subscriberCount': 304713,
#    'title': 'Daniela Alfaro',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 11,
#    'viewCount': 3213005,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8081,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7140098182298297, 0.06859025071639446),
#    'publishedAt': 1541705391.0,
#    'subscriberCount': 7035,
#    'title': 'Carlos Carrera',
#    'topics': {'n0': 'society'},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1237,
#    'country': 'ES',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5487780722326493, 0.6667598110374633),
#    'publishedAt': 1381257905.0,
#    'subscriberCount': 3808361,
#    'title': 'Logan G',
#    'topics': {'n0': 'lifestyle', 'n1': 'food'},
#    'videoCount': 158,
#    'viewCount': 253024966,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2650,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4813746613502443, 0.6437156777884375),
#    'publishedAt': 1401196748.0,
#    'subscriberCount': 9802015,
#    'title': 'Jelly',
#    'topics': {'n0': 'action-adventure game', 'n1': 'gaming'},
#    'videoCount': 3072,
#    'viewCount': 3670061101,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8092,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.05879514421841695, 0.7174826369494666),
#    'publishedAt': 1535765886.0,
#    'subscriberCount': 9470,
#    'title': 'Lirio',
#    'topics': {},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1286,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4266078790391661, 0.5567412976570131),
#    'publishedAt': 1179704213.0,
#    'subscriberCount': 11291874,
#    'title': 'Lindsey Stirling',
#    'topics': {'n0': 'music', 'n1': 'pop music'},
#    'videoCount': 113,
#    'viewCount': 2441985877,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8078,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.954008364737082, 0.6800011873644072),
#    'publishedAt': 1474326221.0,
#    'subscriberCount': 16023,
#    'title': 'Kevin Achutegui',
#    'topics': {'n0': 'music'},
#    'videoCount': 1,
#    'viewCount': 14673,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8071,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8968639431012062, 0.8257621223400408),
#    'publishedAt': 1527523035.0,
#    'subscriberCount': 92052,
#    'title': 'Bryan Se La Sabe',
#    'topics': {'n0': 'entertainment', 'n1': 'food', 'n2': 'lifestyle'},
#    'videoCount': 6,
#    'viewCount': 545133,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2246,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4687109470794192, 0.49534737225561776),
#    'publishedAt': 1327901824.0,
#    'subscriberCount': 2980705,
#    'title': 'TheEngineeringFamily',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle', 'n2': 'entertainment'},
#    'videoCount': 2758,
#    'viewCount': 4086378073,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8087,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.03758941183324594, 0.3250510761130741),
#    'publishedAt': 1533688229.0,
#    'subscriberCount': 22796,
#    'title': 'Tony Scrots',
#    'topics': {},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 977,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4607730438077578, 0.4502108864071715),
#    'publishedAt': 1270696411.0,
#    'subscriberCount': 10785724,
#    'title': 'Rosanna Pansino',
#    'topics': {'n0': 'food', 'n1': 'lifestyle'},
#    'videoCount': 633,
#    'viewCount': 2566911850,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7901,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.26484167005475334, 0.5540181142562369),
#    'publishedAt': 1141075963.0,
#    'subscriberCount': 1872746,
#    'title': 'LA LATA',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 925,
#    'viewCount': 190801042,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 8084,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.46739541117942207, 0.981262905254382),
#    'publishedAt': 1527388282.0,
#    'subscriberCount': 19900,
#    'title': 'Brenda Corro',
#    'topics': {},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2855,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5510676518174626, 0.4800033871397165),
#    'publishedAt': 1316563348.0,
#    'subscriberCount': 5993804,
#    'title': 'EvanTubeHD',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle', 'n2': 'gaming'},
#    'videoCount': 626,
#    'viewCount': 3673727017,
#    'visited': 1},
#   9),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
# ...
#    'pos': (0.5877604520369009, 0.4097237344215045),
#    'publishedAt': 1398659989.0,
#    'subscriberCount': 2012122,
#    'title': 'Luna',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 933,
#    'viewCount': 515822101,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5395,
#    'country': 'KR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.18317795985967741, 0.819456052163237),
#    'publishedAt': 1522165096.0,
#    'subscriberCount': 4659,
#    'title': '!   -   - Peppa Pig',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 106,
#    'viewCount': 921545,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 598,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.2492202186163026, 0.9484764723975228),
#    'publishedAt': 1343839026.0,
#    'subscriberCount': 256601,
#    'title': 'HawkGameplays',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 465,
#    'viewCount': 15610349,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5839,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9527087295248033, 0.3062623491703023),
#    'publishedAt': 1369710800.0,
#    'subscriberCount': 792266,
#    'title': 'TDPresents',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 916,
#    'viewCount': 147914566,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7304,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.3412828766956238, 0.7105474562017785),
#    'publishedAt': 1252425069.0,
#    'subscriberCount': 5434458,
#    'title': 'Taciele Alcolea',
#    'topics': {'n0': 'lifestyle', 'n1': 'fashion'},
#    'videoCount': 1207,
#    'viewCount': 608327640,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7055,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.05356449127479668, 0.40583848136040407),
#    'publishedAt': 1185991465.0,
#    'subscriberCount': 648458,
#    'title': 'Jake Miller',
#    'topics': {'n0': 'music', 'n1': 'pop music', 'n2': 'hip hop music'},
#    'videoCount': 167,
#    'viewCount': 111980916,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 808,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.2820304149796012, 0.9410313183946002),
#    'publishedAt': 1441038340.0,
#    'subscriberCount': 257471,
#    'title': 'Canal VGames',
#    'topics': {'n0': 'gaming',
#     'n1': 'action game',
#     'n2': 'strategy video game'},
#    'videoCount': 1416,
#    'viewCount': 21334484,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 682,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4521846958499792, 0.5537007671721873),
#    'publishedAt': 1362877352.0,
#    'subscriberCount': 1062428,
#    'title': 'Super Oito',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 226,
#    'viewCount': 78881263,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5202,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.12431523712249605, 0.8555614027446787),
#    'publishedAt': 1473175884.0,
#    'subscriberCount': 21266,
#    'title': 'HuggyBoBo',
#    'topics': {'n0': 'music', 'n1': 'movies', 'n2': 'entertainment'},
#    'videoCount': 167,
#    'viewCount': 7458474,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1399,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.46071495583101, 0.0233443323634217),
#    'publishedAt': 1250019761.0,
#    'subscriberCount': 240348,
#    'title': 'Pigeons & Planes',
#    'topics': {'n0': 'hip hop music', 'n1': 'music'},
#    'videoCount': 476,
#    'viewCount': 88132614,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1520,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4020257178994758, 0.17324332608378545),
#    'publishedAt': 1346756259.0,
#    'subscriberCount': 4889106,
#    'title': 'Zoe Sugg',
#    'topics': {'n0': 'lifestyle', 'n1': 'pets'},
#    'videoCount': 485,
#    'viewCount': 772611487,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7331,
#    'country': 'MX',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6750341529528158, 0.08486013234907662),
#    'publishedAt': 1442256668.0,
#    'subscriberCount': 704282,
#    'title': 'CURIOSEANDO',
#    'topics': {'n0': 'lifestyle', 'n1': 'society'},
#    'videoCount': 271,
#    'viewCount': 110991448,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1592,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.2374223020645169, 0.9233983103460602),
#    'publishedAt': 1371435126.0,
#    'subscriberCount': 790331,
#    'title': 'iNoToRiOuS',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 189,
#    'viewCount': 113562302,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 722,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8644840160649133, 0.7734503247459373),
#    'publishedAt': 1427776190.0,
#    'subscriberCount': 105126,
#    'title': 'Dragao Mendigo',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 16,
#    'viewCount': 2206771,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5441,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6600987551706663, 0.37526569024881684),
#    'publishedAt': 1417684973.0,
#    'subscriberCount': 4734245,
#    'title': 'Dave and Ava - Nursery Rhymes and Baby Songs',
#    'topics': {'n0': 'music', 'n1': 'movies', 'n2': 'entertainment'},
#    'videoCount': 389,
#    'viewCount': 2862556256,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2639,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.6167135860461889, 0.31100131335561665),
#    'publishedAt': 1178581354.0,
#    'subscriberCount': 2936755,
#    'title': 'penguinz0',
#    'topics': {'n0': 'gaming', 'n1': 'action game'},
#    'videoCount': 1548,
#    'viewCount': 832299589,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2613,
#    'country': 'ES',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5724088895559554, 0.5600569995279406),
#    'publishedAt': 1393159657.0,
#    'subscriberCount': 1184617,
#    'title': 'Stratus',
#    'topics': {'n0': 'gaming', 'n1': 'action-adventure game'},
#    'videoCount': 3360,
#    'viewCount': 241265781,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 4748,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.7063580920500818, 0.16599147127160155),
#    'publishedAt': 1149537427.0,
#    'subscriberCount': 4521664,
#    'title': 'Rhett & Link',
#    'topics': {'n0': 'music', 'n1': 'entertainment'},
#    'videoCount': 324,
#    'viewCount': 807025541,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5171,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.36233782597439873, 0.7360505877753992),
#    'publishedAt': 1532092591.0,
#    'subscriberCount': 1070340,
#    'title': 'FV FAMILY',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 443,
#    'viewCount': 358743590,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5371,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.06895452073157754, 0.6544084358731082),
#    'publishedAt': 1415978092.0,
#    'subscriberCount': 144998,
#    'title': 'The Fixies',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 421,
#    'viewCount': 110236320,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2867,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5829074804347832, 0.44429370087836567),
#    'publishedAt': 1224620935.0,
#    'subscriberCount': 3273818,
#    'title': 'Annie LeBlanc',
#    'topics': {'n0': 'sports', 'n1': 'lifestyle'},
#    'videoCount': 248,
#    'viewCount': 384223840,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5691,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.0738787634732871, 0.5419525117444638),
#    'publishedAt': 1489174073.0,
#    'subscriberCount': 13018,
#    'title': 'Origins: The Journey of Humankind',
#    'topics': {'n0': 'entertainment', 'n1': 'movies'},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6050,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5435092878048419, 0.6514519498784285),
#    'publishedAt': 1313957238.0,
#    'subscriberCount': 1125813,
#    'title': 'SuperSaf',
#    'topics': {'n0': 'technology', 'n1': 'lifestyle'},
#    'videoCount': 721,
#    'viewCount': 210182013,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 306,
#    'country': 'PT',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4728564531425084, 0.5055861871682729),
#    'publishedAt': 1318889304.0,
#    'subscriberCount': 3270947,
#    'title': 'Fer0m0nas',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3859,
#    'viewCount': 586853735,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1691,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4890904225307541, 0.5094111920191442),
#    'publishedAt': 1319211368.0,
#    'subscriberCount': 1173730,
#    'title': 'Physics Girl',
#    'topics': {'n0': 'lifestyle', 'n1': 'knowledge'},
#    'videoCount': 129,
#    'viewCount': 79667826,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5338,
#    'country': 'AU',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8688588117034859, 0.22635142550142415),
#    'publishedAt': 1312194691.0,
#    'subscriberCount': 903435,
#    'title': 'Debbie Doo Kids TV',
#    'topics': {'n0': 'music'},
#    'videoCount': 130,
#    'viewCount': 668383688,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3342,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.0162204513390804, 0.45620976883189857),
#    'publishedAt': 1330547962.0,
#    'subscriberCount': 137354,
#    'title': 'Destination America',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle', 'n2': 'tv shows'},
#    'videoCount': 678,
#    'viewCount': 46708953,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5755,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9544272151871541, 0.6343059910004653),
#    'publishedAt': 1258682231.0,
#    'subscriberCount': 667040,
#    'title': 'The Muppets',
#    'topics': {'n0': 'music', 'n1': 'movies', 'n2': 'entertainment'},
#    'videoCount': 277,
#    'viewCount': 333586331,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6441,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.23875207369304347, 0.08738231657759445),
#    'publishedAt': 1484085200.0,
#    'subscriberCount': 18265,
#    'title': 'Blippi Deutsch',
#    'topics': {'n0': 'movies', 'n1': 'entertainment', 'n2': 'music'},
#    'videoCount': 3,
#    'viewCount': 8556308,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5204,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.9713854863570346, 0.6930168911193199),
#    'publishedAt': 1461791436.0,
#    'subscriberCount': 281935,
#    'title': 'Kidd In Me TV',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'hobby',
#     'n2': 'entertainment',
#     'n3': 'food'},
#    'videoCount': 30,
#    'viewCount': 118839438,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3908,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5697344716851698, 0.47139899171533567),
#    'publishedAt': 1350840469.0,
#    'subscriberCount': 1312164,
#    'title': 'TheBurntChip',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 468,
#    'viewCount': 141335381,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 398,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.5286668869546685, 0.2517231733862442),
#    'publishedAt': 1359967900.0,
#    'subscriberCount': 3222197,
#    'title': 'Inemafoo',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3270,
#    'viewCount': 644329431,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1749,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.052428007981955564, 0.6974131064558668),
#    'publishedAt': 1207442959.0,
#    'subscriberCount': 778457,
#    'title': 'Soldier Knows Best',
#    'topics': {'n0': 'technology', 'n1': 'lifestyle'},
#    'videoCount': 1488,
#    'viewCount': 193438947,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1860,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8089211314242339, 0.08669028931268939),
#    'publishedAt': 1318825221.0,
#    'subscriberCount': 353551,
#    'title': 'MR FOAMER SIMPSON',
#    'topics': {'n0': 'fashion', 'n1': 'lifestyle'},
#    'videoCount': 1009,
#    'viewCount': 48869242,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 4660,
#    'country': 'US',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.03889952265148951, 0.55714630596927),
#    'publishedAt': 1157665371.0,
#    'subscriberCount': 803551,
#    'title': 'BebopVox YOGSCAST',
#    'topics': {'n0': 'gaming', 'n1': 'role-playing video game'},
#    'videoCount': 682,
#    'viewCount': 238225361,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5818,
#    'country': 'GB',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.35444513776499476, 0.3413988909408085),
#    'publishedAt': 1285916013.0,
#    'subscriberCount': 2416853,
#    'title': 'Element Animation',
#    'topics': {'n0': 'movies', 'n1': 'entertainment', 'n2': 'gaming'},
#    'videoCount': 135,
#    'viewCount': 642052401,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1174,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.4758517416122141, 0.4429396762581863),
#    'publishedAt': 1355668343.0,
#    'subscriberCount': 3694327,
#    'title': 'Flakes Power',
#    'topics': {'n0': 'gaming',
#     'n1': 'action game',
#     'n2': 'strategy video game'},
#    'videoCount': 802,
#    'viewCount': 464465580,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 689,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.1203328706019378, 0.5240724607163122),
#    'publishedAt': 1406779672.0,
#    'subscriberCount': 21109795,
#    'title': 'Luccas Neto',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'food',
#     'n2': 'entertainment',
#     'n3': 'hobby'},
#    'videoCount': 550,
#    'viewCount': 4639198749,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 567,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'pos': (0.08740037977321767, 0.3377291402506623),
#    'publishedAt': 1523241250.0,
#    'subscriberCount': 68727,
#    'title': 'Bruno Faccio',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 196,
#    'viewCount': 2339037,
#    'visited': 1},
#   3),
#  ({'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2223,
#    'country': None,
#    'hiddenSubscriberCount': 0,
#    'pos': (0.8199219412570983, 0.9054861464832629),
#    'publishedAt': 1150301015.0,
#    'subscriberCount': 389706,
#    'title': 'The Platform',
#    'topics': {'n0': 'fashion', 'n1': 'lifestyle'},
#    'videoCount': 255,
#    'viewCount': 25317791,
#    'visited': 1},
#   3),
#  ...]

# %%
def cost(c, A):
    row = np.matrix(c)
    print('a')

    C = np.multiply(row.transpose(), row)

    correlation, _ = pearsonr(C.flat, A.flat)

    return -correlation


def write_coreness(g):
    length = g.number_of_nodes()

    c = np.random.rand(length)

    A = sn.build_matrix(g)

    bounds = [(0, 1) for _ in range(length)]

    result = minimize(cost, c, args=(A,), bounds=bounds)

    norm = 0

    for i, n in enumerate(g.nodes):
        g.nodes[n]['coreness'] = result['x'][i]

        norm += g.nodes[n]['coreness'] ** 2

    for n in g.nodes:
        g.nodes[n]['coreness'] /= norm

# %%
# cor = coreness(g)
# cor
# nx.to_numpy_matrix(g)
write_coreness(g)
# write_coreness(g)
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a

# %%
outdegrees = g.out_degree()
for k, v in outdegrees:
    g.nodes[k]["outdegrees"] = v
    
indegrees = g.in_degree()
for k, v in indegrees:
    g.nodes[k]["indegrees"] = v
    
bw = nx.betweenness_centrality(g)
for k,v in bw.items():
    g.nodes[k]["betweenness"] = v

closeness = nx.closeness_centrality(g)
for k,v in closeness.items():
    g.nodes[k]["closeness"] = v

# %%
# bw = nx.betweenness_centrality(g)
# betweenness = sorted([(g.nodes[k], v) for k, v in bw.items()], key=lambda x: -x[1])

# %% [markdown]
# ### Kindness

# %%
def kindness(cid):
    own_subs = int(g.nodes[cid]['subscriberCount'])
    kindness = 0
    neighbors = list(nx.neighbors(g, cid))
    if (len(neighbors) == 0):
        return 0
    
    neighbor_subs = [int(g.nodes[n]['subscriberCount']) for n in neighbors]
    for ns in neighbor_subs:
        if (ns < 10):
            continue
        kindness += own_subs/ns
    kindness /= len(neighbors)
    return kindness

MAX_KINDNESS = 0
for n in g.nodes:
    g.nodes[n]['kindness'] = kindness(n)
    if g.nodes[n]['kindness'] > MAX_KINDNESS:
        MAX_KINDNESS = g.nodes[n]['kindness']

for n in g.nodes:
    g.nodes[n]['kindness'] /= MAX_KINDNESS

# %%
k = sorted([(g.nodes[k],g.nodes[k]['kindness']) for k in g.nodes], key=lambda x: -x[1])
k_br = sorted([(g.nodes[k],g.nodes[k]['kindness']) for k in g.nodes if g.nodes[k]['country'] == 'BR'], key=lambda x: -x[1])
k_br
# Out:
# [({'betweenness': 0.0006506892404037674,
#    'closeness': 0.007838477308807443,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2558,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.028209145291022444,
#    'outdegrees': 21,
#    'pos': (0.5309357628230355, 0.5038837415916801),
#    'publishedAt': 1454867846.0,
#    'subscriberCount': 2633115,
#    'title': 'Hoje e dia de Marias',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 569,
#    'viewCount': 515461324,
#    'visited': 1},
#   0.028209145291022444),
#  ({'betweenness': 0.0001524824848835057,
#    'closeness': 0.010117651704941872,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 762,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.027940423536504742,
#    'outdegrees': 12,
#    'pos': (0.5069389617622548, 0.5278203256471768),
#    'publishedAt': 1326331667.0,
#    'subscriberCount': 1109162,
#    'title': 'SanInPlay',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 1238,
#    'viewCount': 111878056,
#    'visited': 1},
#   0.027940423536504742),
#  ({'betweenness': 5.2864840916254545e-05,
#    'closeness': 0.00947758641915839,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1171,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.02279130371220664,
#    'outdegrees': 7,
#    'pos': (0.5159264169499915, 0.5532838889057501),
#    'publishedAt': 1338899957.0,
#    'subscriberCount': 1216182,
#    'title': 'Canal Voce Nao Sabia',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 193,
#    'viewCount': 74349329,
#    'visited': 1},
#   0.02279130371220664),
#  ({'betweenness': 3.055656131682832e-05,
#    'closeness': 0.014031820907224879,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3988,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.02076762802665753,
#    'outdegrees': 24,
#    'pos': (0.5315319749767831, 0.45924589005133154),
#    'publishedAt': 1402071225.0,
#    'subscriberCount': 1030522,
#    'title': 'Little Baby Bum em Portugues',
#    'topics': {'n0': 'music', 'n1': 'movies', 'n2': 'entertainment'},
#    'videoCount': 369,
#    'viewCount': 394866195,
#    'visited': 1},
#   0.02076762802665753),
#  ({'betweenness': 0.00019928952238180452,
#    'closeness': 0.013019355823808693,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 45,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.020478055533075825,
#    'outdegrees': 13,
#    'pos': (0.5885961883074585, 0.5880113294862954),
#    'publishedAt': 1381147764.0,
#    'subscriberCount': 2350912,
#    'title': 'Irmaos Piologo',
#    'topics': {'n0': 'entertainment', 'n1': 'gaming'},
#    'videoCount': 783,
#    'viewCount': 310037461,
#    'visited': 1},
#   0.020478055533075825),
#  ({'betweenness': 5.092321639641501e-05,
#    'closeness': 0.00894829180410352,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1549,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.020207722030640588,
#    'outdegrees': 3,
#    'pos': (0.89008047871073, 0.4923602977560556),
#    'publishedAt': 1443153105.0,
#    'subscriberCount': 1050168,
#    'title': 'Brazil Kickers',
#    'topics': {'n0': 'football', 'n1': 'sports'},
#    'videoCount': 279,
#    'viewCount': 62756605,
#    'visited': 1},
#   0.020207722030640588),
#  ({'betweenness': 0.026978256849196424,
#    'closeness': 0.014313626520506915,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 19,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 9,
#    'kindness': 0.019771339943964343,
#    'outdegrees': 11,
#    'pos': (0.4969023187506615, 0.45732508472518413),
#    'publishedAt': 1283309943.0,
#    'subscriberCount': 3538332,
#    'title': 'La Fenix',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 1009,
#    'viewCount': 573202164,
#    'visited': 1},
#   0.019771339943964343),
#  ({'betweenness': 5.054350724350056e-05,
#    'closeness': 0.009565479953283903,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 602,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.019522884873812145,
#    'outdegrees': 6,
#    'pos': (0.45810781448559496, 0.45380103002520994),
#    'publishedAt': 1395016698.0,
#    'subscriberCount': 1136138,
#    'title': 'Davizinh',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 930,
#    'viewCount': 145507160,
#    'visited': 1},
#   0.019522884873812145),
#  ({'betweenness': 0.0002025256115229971,
#    'closeness': 0.00952372799825558,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 613,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.018667510913750008,
#    'outdegrees': 6,
#    'pos': (0.4870554970666373, 0.38300519428030594),
#    'publishedAt': 1469639465.0,
#    'subscriberCount': 6689256,
#    'title': 'Canal Top10',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment', 'n2': 'society'},
#    'videoCount': 239,
#    'viewCount': 715403087,
#    'visited': 1},
#   0.018667510913750008),
#  ({'betweenness': 3.372379809958663e-05,
#    'closeness': 0.00820569240975407,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1981,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.01834312499467519,
#    'outdegrees': 2,
#    'pos': (0.7962298307446406, 0.18552625064896727),
#    'publishedAt': 1382976285.0,
#    'subscriberCount': 2438472,
#    'title': 'Gabriel Gomes',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 127,
#    'viewCount': 110650868,
#    'visited': 1},
#   0.01834312499467519),
#  ({'betweenness': 0.0004143861046321527,
#    'closeness': 0.010866365683107344,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 462,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.016331087800749346,
#    'outdegrees': 25,
#    'pos': (0.4665040623718572, 0.4441375598788219),
#    'publishedAt': 1369665264.0,
#    'subscriberCount': 1421345,
#    'title': 'DG Gameplays',
#    'topics': {'n0': 'gaming', 'n1': 'lifestyle'},
#    'videoCount': 1224,
#    'viewCount': 176795174,
#    'visited': 1},
#   0.016331087800749346),
#  ({'betweenness': 4.907691683670712e-05,
#    'closeness': 0.010873308160543523,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 531,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.015271411161398959,
#    'outdegrees': 5,
#    'pos': (0.6851526823498161, 0.5477271047025947),
#    'publishedAt': 1341075190.0,
#    'subscriberCount': 2031488,
#    'title': 'super99andre',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3140,
#    'viewCount': 222720520,
#    'visited': 1},
#   0.015271411161398959),
#  ({'betweenness': 0.00010117139429875989,
#    'closeness': 0.010300499082334791,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 139,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.015010443585372657,
#    'outdegrees': 6,
#    'pos': (0.5719498727450392, 0.5884338133407194),
#    'publishedAt': 1449959542.0,
#    'subscriberCount': 1494542,
#    'title': 'Laizzando',
#    'topics': {'n0': 'music', 'n1': 'lifestyle'},
#    'videoCount': 94,
#    'viewCount': 143249049,
#    'visited': 1},
#   0.015010443585372657),
#  ({'betweenness': 0.0002529706756527791,
#    'closeness': 0.006185992269875953,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7313,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.013740997023433276,
#    'outdegrees': 7,
#    'pos': (0.5816406777417537, 0.5284433850420526),
#    'publishedAt': 1242258750.0,
#    'subscriberCount': 1114875,
#    'title': 'Juliana Goes',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 1040,
#    'viewCount': 80869298,
#    'visited': 1},
#   0.013740997023433276),
#  ({'betweenness': 0.00015157426852266252,
#    'closeness': 0.012018998540171414,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 22,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.013075327486582666,
#    'outdegrees': 9,
#    'pos': (0.4390010837922985, 0.3934942621250597),
#    'publishedAt': 1279071465.0,
#    'subscriberCount': 1276252,
#    'title': 'CamillaUckers',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 216,
#    'viewCount': 114086939,
#    'visited': 1},
#   0.013075327486582666),
#  ({'betweenness': 0.00010117139429875989,
#    'closeness': 0.008371305235348694,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1955,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.012536736387323114,
#    'outdegrees': 6,
#    'pos': (0.49601014705295116, 0.754440135143121),
#    'publishedAt': 1338786359.0,
#    'subscriberCount': 5248145,
#    'title': '7 Minutoz',
#    'topics': {'n0': 'music', 'n1': 'hip hop music'},
#    'videoCount': 339,
#    'viewCount': 872367782,
#    'visited': 1},
#   0.012536736387323114),
#  ({'betweenness': 0.0003371114112782282,
#    'closeness': 0.009536001531284094,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 270,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.012060175429287053,
#    'outdegrees': 8,
#    'pos': (0.504168238085575, 0.5088334619807696),
#    'publishedAt': 1381954474.0,
#    'subscriberCount': 3825041,
#    'title': 'Beleza Teen',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 537,
#    'viewCount': 315204767,
#    'visited': 1},
#   0.012060175429287053),
#  ({'betweenness': 0.00011823017957599032,
#    'closeness': 0.009459789407158938,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1190,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.01192179427681406,
#    'outdegrees': 8,
#    'pos': (0.5732683568911624, 0.6765739607345028),
#    'publishedAt': 1271873085.0,
#    'subscriberCount': 2742765,
#    'title': 'Cartoon Network Brasil',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 1456,
#    'viewCount': 530453030,
#    'visited': 1},
#   0.01192179427681406),
#  ({'betweenness': 0.0010561582381212549,
#    'closeness': 0.01062817831317225,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 444,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.011166959658464752,
#    'outdegrees': 5,
#    'pos': (0.5036859053419945, 0.39966646366450514),
#    'publishedAt': 1343005323.0,
#    'subscriberCount': 1663910,
#    'title': 'John Leitao',
#    'topics': {'n0': 'entertainment', 'n1': 'humor'},
#    'videoCount': 178,
#    'viewCount': 160722999,
#    'visited': 1},
#   0.011166959658464752),
#  ({'betweenness': 0.0005859568516894676,
#    'closeness': 0.013039105079749182,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1454,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.010703886493907478,
#    'outdegrees': 7,
#    'pos': (0.6154182713133888, 0.44208411302332684),
#    'publishedAt': 1305320102.0,
#    'subscriberCount': 10959013,
#    'title': 'Parafernalha',
#    'topics': {'n0': 'entertainment', 'n1': 'humor', 'n2': 'movies'},
#    'videoCount': 682,
#    'viewCount': 2571646291,
#    'visited': 1},
#   0.010703886493907478),
#  ({'betweenness': 0.0003019473545633031,
#    'closeness': 0.011615412184604643,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 219,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.010265895361891734,
#    'outdegrees': 14,
#    'pos': (0.518985737042475, 0.2996929688742009),
#    'publishedAt': 1212754891.0,
#    'subscriberCount': 2178816,
#    'title': 'consolesejogosbrasil',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 3278,
#    'viewCount': 623360435,
#    'visited': 1},
#   0.010265895361891734),
#  ({'betweenness': 0.00023615096650886518,
#    'closeness': 0.013021348074126032,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1480,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.010124673233503087,
#    'outdegrees': 5,
#    'pos': (0.4756898805745586, 0.22262472401930727),
#    'publishedAt': 1410813133.0,
#    'subscriberCount': 2203904,
#    'title': 'Na CorreRia',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 342,
#    'viewCount': 736266564,
#    'visited': 1},
#   0.010124673233503087),
#  ({'betweenness': 0.0003348587688508891,
#    'closeness': 0.010577316303842588,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 114,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.008995203341087072,
#    'outdegrees': 10,
#    'pos': (0.4951154835562635, 0.48304871059634813),
#    'publishedAt': 1449793448.0,
#    'subscriberCount': 1621435,
#    'title': 'Kel e Laura',
#    'topics': {'n0': 'entertainment', 'n1': 'music', 'n2': 'lifestyle'},
#    'videoCount': 1431,
#    'viewCount': 322527027,
#    'visited': 1},
#   0.008995203341087072),
#  ({'betweenness': 0.00034480285179962916,
#    'closeness': 0.01202579277337671,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 66,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.008025023730229662,
#    'outdegrees': 12,
#    'pos': (0.55329098953562, 0.5503424153145238),
#    'publishedAt': 1216300589.0,
#    'subscriberCount': 1927849,
#    'title': 'ChocolaTV',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 946,
#    'viewCount': 199124485,
#    'visited': 1},
#   0.008025023730229662),
#  ({'betweenness': 0.0008334777252591584,
#    'closeness': 0.010132246446942762,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 681,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.007975416976606578,
#    'outdegrees': 11,
#    'pos': (0.5967543029356847, 0.5007774567283024),
#    'publishedAt': 1343679266.0,
#    'subscriberCount': 9387659,
#    'title': 'Turma da Monica',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 729,
#    'viewCount': 7292932383,
#    'visited': 1},
#   0.007975416976606578),
#  ({'betweenness': 0.0006142132872974917,
#    'closeness': 0.007439306697942353,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3540,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.0077233775289118085,
#    'outdegrees': 12,
#    'pos': (0.534925791244644, 0.35181460924509095),
#    'publishedAt': 1397445028.0,
#    'subscriberCount': 10546015,
#    'title': 'Erlania e Valentina',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 589,
#    'viewCount': 2578427143,
#    'visited': 1},
#   0.0077233775289118085),
#  ({'betweenness': 0.00015127917060059156,
#    'closeness': 0.01096790741308418,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 200,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 7,
#    'kindness': 0.007611116132987651,
#    'outdegrees': 19,
#    'pos': (0.5027984081555364, 0.5157499264565877),
#    'publishedAt': 1355076504.0,
#    'subscriberCount': 1246707,
#    'title': 'stux777',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2864,
#    'viewCount': 150792618,
#    'visited': 1},
#   0.007611116132987651),
#  ({'betweenness': 5.058569714937994e-05,
#    'closeness': 0.010863705060708693,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 406,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0075434366580823765,
#    'outdegrees': 3,
#    'pos': (0.21483549859540327, 0.19451090361298545),
#    'publishedAt': 1330757813.0,
#    'subscriberCount': 1646763,
#    'title': 'YoshiGamer',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 8583,
#    'viewCount': 400999211,
#    'visited': 1},
#   0.0075434366580823765),
#  ({'betweenness': 5.058569714937994e-05,
#    'closeness': 0.007440673030973803,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3550,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0070239960229952275,
#    'outdegrees': 3,
#    'pos': (0.6654028019868374, 0.5700074200782511),
#    'publishedAt': 1284639600.0,
#    'subscriberCount': 2898754,
#    'title': 'Diario das Gemeas',
#    'topics': {'n0': 'lifestyle', 'n1': 'hobby'},
#    'videoCount': 471,
#    'viewCount': 459431161,
#    'visited': 1},
#   0.0070239960229952275),
#  ({'betweenness': 0.0006500083054166497,
#    'closeness': 0.010958020689513053,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 387,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.0060720166546240515,
#    'outdegrees': 17,
#    'pos': (0.5337178803064744, 0.5146449343039535),
#    'publishedAt': 1342472930.0,
#    'subscriberCount': 1297621,
#    'title': 'Davi',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 487,
#    'viewCount': 93393249,
#    'visited': 1},
#   0.0060720166546240515),
#  ({'betweenness': 0.0008898277483961846,
#    'closeness': 0.006465165602827352,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6818,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.005852703775275794,
#    'outdegrees': 5,
#    'pos': (0.7450135670705123, 0.5807929268894237),
#    'publishedAt': 1405822309.0,
#    'subscriberCount': 7049681,
#    'title': 'Kim RosaCuca',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 720,
#    'viewCount': 640256639,
#    'visited': 1},
#   0.005852703775275794),
#  ({'betweenness': 0.00041615548857193066,
#    'closeness': 0.00888019928665939,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1552,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.005678468299162576,
#    'outdegrees': 16,
#    'pos': (0.5242265454195222, 0.3885943031795809),
#    'publishedAt': 1391736468.0,
#    'subscriberCount': 7676223,
#    'title': 'Tauz',
#    'topics': {'n0': 'music'},
#    'videoCount': 160,
#    'viewCount': 1664428731,
#    'visited': 1},
#   0.005678468299162576),
#  ({'betweenness': 1.688065011907304e-05,
#    'closeness': 0.009864886351079714,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 697,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.005453122911718956,
#    'outdegrees': 5,
#    'pos': (0.5240480099750928, 0.7543038018532716),
#    'publishedAt': 1405446838.0,
#    'subscriberCount': 2592069,
#    'title': 'Mundo da Menina',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 450,
#    'viewCount': 439424475,
#    'visited': 1},
#   0.005453122911718956),
#  ({'betweenness': 0.0005451020017358153,
#    'closeness': 0.01095872629290581,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 273,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 10,
#    'kindness': 0.004793259720639576,
#    'outdegrees': 16,
#    'pos': (0.6270204492920118, 0.5917743986194032),
#    'publishedAt': 1381735179.0,
#    'subscriberCount': 1653663,
#    'title': 'Flokiis',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1099,
#    'viewCount': 131792454,
#    'visited': 1},
#   0.004793259720639576),
#  ({'betweenness': 3.417427724095688e-05,
#    'closeness': 0.007438006176689272,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3577,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.00474314522651029,
#    'outdegrees': 9,
#    'pos': (0.4794813834562694, 0.4705772949593723),
#    'publishedAt': 1415231876.0,
#    'subscriberCount': 1141105,
#    'title': 'Sarinha',
#    'topics': {'n0': 'lifestyle', 'n1': 'hobby'},
#    'videoCount': 429,
#    'viewCount': 140804687,
#    'visited': 1},
#   0.00474314522651029),
#  ({'betweenness': 6.970371985916087e-05,
#    'closeness': 0.010950969649882712,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 358,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.0043646513194169545,
#    'outdegrees': 9,
#    'pos': (0.4706547499156672, 0.3830043887686797),
#    'publishedAt': 1317760192.0,
#    'subscriberCount': 2969215,
#    'title': 'Febatista',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3722,
#    'viewCount': 603660460,
#    'visited': 1},
#   0.0043646513194169545),
#  ({'betweenness': 0.0013648966290634949,
#    'closeness': 0.007844981069827013,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2605,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 5,
#    'kindness': 0.004261830454176024,
#    'outdegrees': 20,
#    'pos': (0.4428575635684786, 0.64818983165336),
#    'publishedAt': 1409030049.0,
#    'subscriberCount': 3897376,
#    'title': 'Canal da Lele',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 442,
#    'viewCount': 1137937357,
#    'visited': 1},
#   0.004261830454176024),
#  ({'betweenness': 0.0,
#    'closeness': 0.0,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 0,
#    'kindness': 0.004220369849225829,
#    'outdegrees': 7,
#    'pos': (0.5490789812925926, 0.2349401451863514),
#    'publishedAt': 1331526627.0,
#    'subscriberCount': 15056101,
#    'title': 'Porta dos Fundos',
#    'topics': {'n0': 'entertainment', 'n1': 'humor', 'n2': 'movies'},
#    'videoCount': 947,
#    'viewCount': 4356891607,
#    'visited': 1},
#   0.004220369849225829),
#  ({'betweenness': 1.6861899049793316e-05,
#    'closeness': 0.01020920228845615,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 275,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.004141215137336405,
#    'outdegrees': 1,
#    'pos': (0.9090926151876806, 0.3227559167580627),
#    'publishedAt': 1201040576.0,
#    'subscriberCount': 8244163,
#    'title': 'MAIKI021',
#    'topics': {'n0': 'vehicles', 'n1': 'lifestyle'},
#    'videoCount': 921,
#    'viewCount': 873271091,
#    'visited': 1},
#   0.004141215137336405),
#  ({'betweenness': 3.372379809958663e-05,
#    'closeness': 0.006474979482400517,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6827,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.003869046094807957,
#    'outdegrees': 2,
#    'pos': (0.6067764440396877, 0.24949861800445597),
#    'publishedAt': 1154992588.0,
#    'subscriberCount': 3849689,
#    'title': 'Evelyn Regly',
#    'topics': {'n0': 'lifestyle', 'n1': 'fashion'},
#    'videoCount': 854,
#    'viewCount': 381440315,
#    'visited': 1},
#   0.003869046094807957),
#  ({'betweenness': 0.00045887465085466087,
#    'closeness': 0.01021236239596923,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 576,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.00371658254129941,
#    'outdegrees': 28,
#    'pos': (0.4490368170045672, 0.5163085579946377),
#    'publishedAt': 1295310972.0,
#    'subscriberCount': 3234917,
#    'title': 'viniccius13',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 454,
#    'viewCount': 385689070,
#    'visited': 1},
#   0.00371658254129941),
#  ({'betweenness': 0.001233914712892951,
#    'closeness': 0.00784353485707564,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2615,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 7,
#    'kindness': 0.0035815441102058825,
#    'outdegrees': 25,
#    'pos': (0.5156490192149544, 0.46655569957976867),
#    'publishedAt': 1228238249.0,
#    'subscriberCount': 1638598,
#    'title': 'Eloah e Diversao',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 447,
#    'viewCount': 318655825,
#    'visited': 1},
#   0.0035815441102058825),
#  ({'betweenness': 5.657502306569033e-05,
#    'closeness': 0.0093404887300773,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1106,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0034579614675027816,
#    'outdegrees': 4,
#    'pos': (0.33055944916488167, 0.278264732465169),
#    'publishedAt': 1321321675.0,
#    'subscriberCount': 1400654,
#    'title': 'Bruna Vieira',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 658,
#    'viewCount': 86992186,
#    'visited': 1},
#   0.0034579614675027816),
#  ({'betweenness': 0.00019498424695560136,
#    'closeness': 0.01095026504496379,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 286,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 5,
#    'kindness': 0.0033556979613758387,
#    'outdegrees': 14,
#    'pos': (0.5073887528443136, 0.43541469764477225),
#    'publishedAt': 1330539355.0,
#    'subscriberCount': 2681558,
#    'title': 'Godenot',
#    'topics': {'n0': 'gaming', 'n1': 'role-playing video game'},
#    'videoCount': 4521,
#    'viewCount': 745105731,
#    'visited': 1},
#   0.0033556979613758387),
#  ({'betweenness': 0.00012119529432175247,
#    'closeness': 0.010942520370914114,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 332,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.003353978182982007,
#    'outdegrees': 13,
#    'pos': (0.4371712660507733, 0.4574662604237326),
#    'publishedAt': 1333549048.0,
#    'subscriberCount': 4860590,
#    'title': 'Cronosplays',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 2499,
#    'viewCount': 684708653,
#    'visited': 1},
#   0.003353978182982007),
#  ({'betweenness': 0.0002271901062625812,
#    'closeness': 0.010849739852660157,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 484,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.003330348083081656,
#    'outdegrees': 14,
#    'pos': (0.58495002813908, 0.5343365503419679),
#    'publishedAt': 1354840933.0,
#    'subscriberCount': 1245244,
#    'title': 'MERCENA +',
#    'topics': {'n0': 'gaming', 'n1': 'action-adventure game'},
#    'videoCount': 2628,
#    'viewCount': 117520813,
#    'visited': 1},
#   0.003330348083081656),
#  ({'betweenness': 4.2112557718603904e-05,
#    'closeness': 0.008694646946399674,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1494,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0033043868251979368,
#    'outdegrees': 5,
#    'pos': (0.45972521570503977, 0.6798892064661981),
#    'publishedAt': 1434570035.0,
#    'subscriberCount': 3735865,
#    'title': 'Zoio Do dia',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment', 'n2': 'music'},
#    'videoCount': 211,
#    'viewCount': 188238416,
#    'visited': 1},
#   0.0033043868251979368),
#  ({'betweenness': 4.795351579923916e-05,
#    'closeness': 0.011864036143596695,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5400,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0032985159987510837,
#    'outdegrees': 14,
#    'pos': (0.5328009398972334, 0.45612516616154597),
#    'publishedAt': 1441280932.0,
#    'subscriberCount': 1303357,
#    'title': 'PJ Masks Brasil  Canal Oficial',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 264,
#    'viewCount': 483200267,
#    'visited': 1},
#   0.0032985159987510837),
#  ({'betweenness': 0.0018088585656793586,
#    'closeness': 0.008294620300654412,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1890,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 10,
#    'kindness': 0.0032101442032547124,
#    'outdegrees': 22,
#    'pos': (0.5047740408549651, 0.5505161179798347),
#    'publishedAt': 1186405276.0,
#    'subscriberCount': 4137823,
#    'title': 'Julia Silva',
#    'topics': {'n0': 'hobby', 'n1': 'lifestyle'},
#    'videoCount': 1259,
#    'viewCount': 914155201,
#    'visited': 1},
#   0.0032101442032547124),
#  ({'betweenness': 6.739134299133408e-05,
#    'closeness': 0.00923835736232913,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 436,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.003199114146953867,
#    'outdegrees': 5,
#    'pos': (0.4890830806265415, 0.2664554097130394),
#    'publishedAt': 1462798437.0,
#    'subscriberCount': 2133842,
#    'title': 'Canal Incognita',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 157,
#    'viewCount': 162273617,
#    'visited': 1},
#   0.003199114146953867),
#  ({'betweenness': 0.001246011621498418,
#    'closeness': 0.01250838007708564,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 102,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 8,
#    'kindness': 0.003079282880048304,
#    'outdegrees': 17,
#    'pos': (0.45475318136005655, 0.46938922245129044),
#    'publishedAt': 1256840961.0,
#    'subscriberCount': 3291757,
#    'title': 'Monark',
#    'topics': {'n0': 'gaming', 'n1': 'role-playing video game'},
#    'videoCount': 1749,
#    'viewCount': 390853438,
#    'visited': 1},
#   0.003079282880048304),
#  ({'betweenness': 0.000676322171296591,
#    'closeness': 0.010216653819715886,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 506,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.003033275221549913,
#    'outdegrees': 34,
#    'pos': (0.49004656846729094, 0.5652834942308019),
#    'publishedAt': 1256896104.0,
#    'subscriberCount': 1297867,
#    'title': 'Jr e Mi',
#    'topics': {'n0': 'gaming',
#     'n1': 'role-playing video game',
#     'n2': 'simulation video game'},
#    'videoCount': 4252,
#    'viewCount': 201578118,
#    'visited': 1},
#   0.003033275221549913),
#  ({'betweenness': 2.52295637158709e-05,
#    'closeness': 0.006463937837700909,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6820,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0027720522563652894,
#    'outdegrees': 3,
#    'pos': (0.8479132268861809, 0.3748070415629474),
#    'publishedAt': 1396025997.0,
#    'subscriberCount': 1805582,
#    'title': 'Leo Borges',
#    'topics': {'n0': 'lifestyle', 'n1': 'food'},
#    'videoCount': 401,
#    'viewCount': 118969900,
#    'visited': 1},
#   0.0027720522563652894),
#  ({'betweenness': 0.00035549916850621447,
#    'closeness': 0.010146605814632278,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 789,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.0027341043217059087,
#    'outdegrees': 19,
#    'pos': (0.48727877960215965, 0.45481686537501415),
#    'publishedAt': 1398225734.0,
#    'subscriberCount': 1207796,
#    'title': 'Foguinho',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 1584,
#    'viewCount': 158530532,
#    'visited': 1},
#   0.0027341043217059087),
#  ({'betweenness': 8.742538295581571e-05,
#    'closeness': 0.007838838345945707,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2552,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.0027209482861362483,
#    'outdegrees': 6,
#    'pos': (0.29710962569422744, 0.6615593781403087),
#    'publishedAt': 1406607565.0,
#    'subscriberCount': 4716436,
#    'title': 'Maisa Silva',
#    'topics': {'n0': 'pop music',
#     'n1': 'music',
#     'n2': 'entertainment',
#     'n3': 'lifestyle'},
#    'videoCount': 159,
#    'viewCount': 198026336,
#    'visited': 1},
#   0.0027209482861362483),
#  ({'betweenness': 3.372379809958663e-05,
#    'closeness': 0.009437704689843372,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1151,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0026862820965554554,
#    'outdegrees': 2,
#    'pos': (0.13264299412690544, 0.3124690164154856),
#    'publishedAt': 1402353419.0,
#    'subscriberCount': 5396438,
#    'title': 'E tipo isso',
#    'topics': {'n0': 'entertainment', 'n1': 'music'},
#    'videoCount': 169,
#    'viewCount': 318496491,
#    'visited': 1},
#   0.0026862820965554554),
#  ({'betweenness': 0.0009612146611932096,
#    'closeness': 0.007750661231843849,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2547,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0026790241288518054,
#    'outdegrees': 26,
#    'pos': (0.426660266158019, 0.48038418619827117),
#    'publishedAt': 1371058528.0,
#    'subscriberCount': 6826375,
#    'title': 'Desimpedidos',
#    'topics': {'n0': 'football', 'n1': 'sports'},
#    'videoCount': 1832,
#    'viewCount': 1368371850,
#    'visited': 1},
#   0.0026790241288518054),
#  ({'betweenness': 4.756640121588968e-05,
#    'closeness': 0.010913750117277621,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 128,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0026669081395971042,
#    'outdegrees': 3,
#    'pos': (0.6035173843192817, 0.7905006359336039),
#    'publishedAt': 1459142388.0,
#    'subscriberCount': 1770112,
#    'title': 'Careca TV',
#    'topics': {'n0': 'gaming', 'n1': 'lifestyle', 'n2': 'entertainment'},
#    'videoCount': 100,
#    'viewCount': 32436525,
#    'visited': 1},
#   0.0026669081395971042),
#  ({'betweenness': 0.0012396922306682865,
#    'closeness': 0.006465902485803246,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6822,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.002504213165982982,
#    'outdegrees': 8,
#    'pos': (0.37950285379790216, 0.7058485657713207),
#    'publishedAt': 1299618263.0,
#    'subscriberCount': 5216204,
#    'title': 'Boca Rosa',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 594,
#    'viewCount': 363884219,
#    'visited': 1},
#   0.002504213165982982),
#  ({'betweenness': 4.2119589369583805e-05,
#    'closeness': 0.009527460075509557,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 593,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0024559401644301832,
#    'outdegrees': 8,
#    'pos': (0.5206281635371866, 0.556695172494606),
#    'publishedAt': 1384883080.0,
#    'subscriberCount': 1079583,
#    'title': 'AranhaMaster',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 802,
#    'viewCount': 208332471,
#    'visited': 1},
#   0.0024559401644301832),
#  ({'betweenness': 1.6861899049793316e-05,
#    'closeness': 0.005937352320027891,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7616,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.002440680346717385,
#    'outdegrees': 1,
#    'pos': (0.9037686771505918, 0.6546708117930035),
#    'publishedAt': 1327201367.0,
#    'subscriberCount': 2182035,
#    'title': 'Duda Fernandes',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 1107,
#    'viewCount': 164956772,
#    'visited': 1},
#   0.002440680346717385),
#  ({'betweenness': 0.0007517466931641939,
#    'closeness': 0.011745273935736869,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 217,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 11,
#    'kindness': 0.002093244973154094,
#    'outdegrees': 9,
#    'pos': (0.49173246186953246, 0.43790015932505527),
#    'publishedAt': 1310515732.0,
#    'subscriberCount': 10587447,
#    'title': 'TazerCraft',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3039,
#    'viewCount': 3621971219,
#    'visited': 1},
#   0.002093244973154094),
#  ({'betweenness': 6.617890371191569e-05,
#    'closeness': 0.010950969649882712,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 378,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 6,
#    'kindness': 0.0020821184341278426,
#    'outdegrees': 10,
#    'pos': (0.4087584361689581, 0.641175892218556),
#    'publishedAt': 1270463699.0,
#    'subscriberCount': 4555990,
#    'title': 'jvnq',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 4440,
#    'viewCount': 1257842252,
#    'visited': 1},
#   0.0020821184341278426),
#  ({'betweenness': 3.372379809958663e-05,
#    'closeness': 0.00954283809967761,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 973,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0020422348697930106,
#    'outdegrees': 2,
#    'pos': (0.637129280734132, 0.8266153354003024),
#    'publishedAt': 1393267434.0,
#    'subscriberCount': 1260136,
#    'title': 'Chipart',
#    'topics': {'n0': 'gaming', 'n1': 'technology', 'n2': 'lifestyle'},
#    'videoCount': 1978,
#    'viewCount': 95364059,
#    'visited': 1},
#   0.0020422348697930106),
#  ({'betweenness': 8.423917873916761e-05,
#    'closeness': 0.011087954871902225,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 150,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.002017518565774591,
#    'outdegrees': 8,
#    'pos': (0.33395710535135065, 0.5457023679533983),
#    'publishedAt': 1357934224.0,
#    'subscriberCount': 2259140,
#    'title': 'AssombradO.com.br',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 3300,
#    'viewCount': 402690326,
#    'visited': 1},
#   0.002017518565774591),
#  ({'betweenness': 0.0006197673734844729,
#    'closeness': 0.012021545477772637,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 18,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0019504088703705999,
#    'outdegrees': 6,
#    'pos': (0.6504561571391547, 0.30523386601630986),
#    'publishedAt': 1423227487.0,
#    'subscriberCount': 4571230,
#    'title': 'O Que Nao Dizer Oficial',
#    'topics': {'n0': 'entertainment', 'n1': 'music', 'n2': 'lifestyle'},
#    'videoCount': 186,
#    'viewCount': 346041391,
#    'visited': 1},
#   0.0019504088703705999),
#  ({'betweenness': 0.0003543108295750565,
#    'closeness': 0.010206238040709279,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 322,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0018850616698670587,
#    'outdegrees': 3,
#    'pos': (0.5081577550382341, 0.2766665758352452),
#    'publishedAt': 1448471994.0,
#    'subscriberCount': 1562743,
#    'title': 'TOP',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment', 'n2': 'hobby'},
#    'videoCount': 136,
#    'viewCount': 158962856,
#    'visited': 1},
#   0.0018850616698670587),
#  ({'betweenness': 0.00015924669870188442,
#    'closeness': 0.010220335054577662,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 566,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 5,
#    'kindness': 0.0017906791616693004,
#    'outdegrees': 8,
#    'pos': (0.5577192232385475, 0.4529976115370981),
#    'publishedAt': 1424486683.0,
#    'subscriberCount': 4848208,
#    'title': 'Minguado',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 967,
#    'viewCount': 1104710255,
#    'visited': 1},
#   0.0017906791616693004),
#  ({'betweenness': 3.395998344305584e-05,
#    'closeness': 0.008696868482233493,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1470,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.0017379178652667119,
#    'outdegrees': 4,
#    'pos': (0.5132003368782598, 0.7080891967475015),
#    'publishedAt': 1356061286.0,
#    'subscriberCount': 2489860,
#    'title': 'Canal DVC',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 156,
#    'viewCount': 151168112,
#    'visited': 1},
#   0.0017379178652667119),
#  ({'betweenness': 2.2470812648090964e-05,
#    'closeness': 0.009690753862249586,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 175,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.001643701501775532,
#    'outdegrees': 7,
#    'pos': (0.6303505366723254, 0.4662178313599604),
#    'publishedAt': 1426283779.0,
#    'subscriberCount': 1793097,
#    'title': 'Louco de Refri',
#    'topics': {'n0': 'lifestyle', 'n1': 'music', 'n2': 'entertainment'},
#    'videoCount': 239,
#    'viewCount': 94837329,
#    'visited': 1},
#   0.001643701501775532),
#  ({'betweenness': 0.0005191248322353047,
#    'closeness': 0.010862897767844975,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 412,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.0016096300757154158,
#    'outdegrees': 8,
#    'pos': (0.4019812359965822, 0.4422961418609936),
#    'publishedAt': 1410239012.0,
#    'subscriberCount': 1694595,
#    'title': 'Clash com Nery',
#    'topics': {'n0': 'gaming',
#     'n1': 'strategy video game',
#     'n2': 'action game'},
#    'videoCount': 1939,
#    'viewCount': 244113346,
#    'visited': 1},
#   0.0016096300757154158),
#  ({'betweenness': 0.0006079143538160264,
#    'closeness': 0.01098112719839647,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 423,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.001592860254837847,
#    'outdegrees': 11,
#    'pos': (0.488153522970566, 0.5793189438299217),
#    'publishedAt': 1325732608.0,
#    'subscriberCount': 2231890,
#    'title': 'MuuhPro',
#    'topics': {'n0': 'sports game', 'n1': 'gaming'},
#    'videoCount': 1538,
#    'viewCount': 347642692,
#    'visited': 1},
#   0.001592860254837847),
#  ({'betweenness': 0.0007703363998709578,
#    'closeness': 0.010874002896225624,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 403,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.0015909953590428872,
#    'outdegrees': 24,
#    'pos': (0.4489518920143059, 0.5117589351655032),
#    'publishedAt': 1349289577.0,
#    'subscriberCount': 2343583,
#    'title': 'GamerZeal',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 2817,
#    'viewCount': 468789086,
#    'visited': 1},
#   0.0015909953590428872),
#  ({'betweenness': 0.0001066341224525775,
#    'closeness': 0.010864978251329623,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 505,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0015363455421536238,
#    'outdegrees': 8,
#    'pos': (0.5820963655354697, 0.5139576240572915),
#    'publishedAt': 1426610552.0,
#    'subscriberCount': 3236119,
#    'title': 'Canal Clash War',
#    'topics': {'n0': 'gaming',
#     'n1': 'action game',
#     'n2': 'strategy video game'},
#    'videoCount': 983,
#    'viewCount': 254017048,
#    'visited': 1},
#   0.0015363455421536238),
#  ({'betweenness': 1.6960342163511876e-05,
#    'closeness': 0.011734221239489381,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 6135,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0014753582374175103,
#    'outdegrees': 1,
#    'pos': (0.12227869806214514, 0.48873965399064173),
#    'publishedAt': 1141013472.0,
#    'subscriberCount': 1214894,
#    'title': 'FLA TV',
#    'topics': {'n0': 'football', 'n1': 'sports'},
#    'videoCount': 3543,
#    'viewCount': 124644283,
#    'visited': 1},
#   0.0014753582374175103),
#  ({'betweenness': 0.00030581822053402796,
#    'closeness': 0.010597734561854862,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 401,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.001446569125967101,
#    'outdegrees': 14,
#    'pos': (0.5189938416330746, 0.5390604088936489),
#    'publishedAt': 1308001144.0,
#    'subscriberCount': 1985853,
#    'title': 'Maju Trindade',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment'},
#    'videoCount': 184,
#    'viewCount': 70481811,
#    'visited': 1},
#   0.001446569125967101),
#  ({'betweenness': 4.2047214552202447e-05,
#    'closeness': 0.012036521910092551,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 9,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0014317044841951389,
#    'outdegrees': 3,
#    'pos': (0.576296960147868, 0.15878812590896785),
#    'publishedAt': 1153748556.0,
#    'subscriberCount': 11409853,
#    'title': 'Manual do Mundo',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 1400,
#    'viewCount': 1947151550,
#    'visited': 1},
#   0.0014317044841951389),
#  ({'betweenness': 6.743353289721346e-05,
#    'closeness': 0.009439795105633801,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1187,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0014146042783746034,
#    'outdegrees': 6,
#    'pos': (0.5029778301514815, 0.48164391296271536),
#    'publishedAt': 1445317721.0,
#    'subscriberCount': 1095938,
#    'title': 'Gellones',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 423,
#    'viewCount': 62517360,
#    'visited': 1},
#   0.0014146042783746034),
#  ({'betweenness': 0.00035089836479712294,
#    'closeness': 0.009624986954463706,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 283,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.001412963066401668,
#    'outdegrees': 7,
#    'pos': (0.5217372533364871, 0.6026625895768204),
#    'publishedAt': 1153163011.0,
#    'subscriberCount': 2037406,
#    'title': 'Karen Bachini',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 1117,
#    'viewCount': 196921824,
#    'visited': 1},
#   0.001412963066401668),
#  ({'betweenness': 1.684783574783352e-05,
#    'closeness': 0.009536001531284094,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1014,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.001371969541846338,
#    'outdegrees': 3,
#    'pos': (0.4228885007899839, 0.274884701712498),
#    'publishedAt': 1424583786.0,
#    'subscriberCount': 3075605,
#    'title': 'ProSidu',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1520,
#    'viewCount': 658568244,
#    'visited': 1},
#   0.001371969541846338),
#  ({'betweenness': 0.0003035704361041189,
#    'closeness': 0.010881140474095372,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 468,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0013453606570017458,
#    'outdegrees': 16,
#    'pos': (0.47289829101223335, 0.5733033665051109),
#    'publishedAt': 1452306685.0,
#    'subscriberCount': 2626312,
#    'title': 'RD Gameplay',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 1611,
#    'viewCount': 378669333,
#    'visited': 1},
#   0.0013453606570017458),
#  ({'betweenness': 5.434997430728488e-05,
#    'closeness': 0.009223837154020227,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1023,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.001284561706958663,
#    'outdegrees': 6,
#    'pos': (0.46965907418235475, 0.4652661570095767),
#    'publishedAt': 1322940931.0,
#    'subscriberCount': 1967077,
#    'title': 'The Master Invencoes',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 321,
#    'viewCount': 171103350,
#    'visited': 1},
#   0.001284561706958663),
#  ({'betweenness': 4.218990587938277e-08,
#    'closeness': 0.00011858176212498517,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.001250084306557765,
#    'outdegrees': 8,
#    'pos': (0.6007121995889937, 0.4213883428723904),
#    'publishedAt': 1315756583.0,
#    'subscriberCount': 2980074,
#    'title': 'Nando Moura',
#    'topics': {'n0': 'music', 'n1': 'lifestyle'},
#    'videoCount': 1585,
#    'viewCount': 598430204,
#    'visited': 1},
#   0.001250084306557765),
#  ({'betweenness': 0.0018768367531582179,
#    'closeness': 0.011049799982393665,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 192,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 17,
#    'kindness': 0.0012197197589596037,
#    'outdegrees': 19,
#    'pos': (0.42293428686195833, 0.5271730301700012),
#    'publishedAt': 1317952249.0,
#    'subscriberCount': 15780628,
#    'title': 'AuthenticGames',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 3516,
#    'viewCount': 6318297208,
# ...
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8665694525701704, 0.21436831858071528),
#    'publishedAt': 1366381148.0,
#    'subscriberCount': 74611,
#    'title': 'Montalvao Vlogs',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 46,
#    'viewCount': 703369,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.006745805857015583,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5916,
#    'country': 'BR',
#    'hiddenSubscriberCount': 1,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.6914400710349703, 0.05852638574702092),
#    'publishedAt': 1454180176.0,
#    'subscriberCount': 0,
#    'title': 'Fun Toys Clube',
#    'topics': {'n0': 'lifestyle',
#     'n1': 'hobby',
#     'n2': 'movies',
#     'n3': 'entertainment'},
#    'videoCount': 231,
#    'viewCount': 39351379,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007089796033214808,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 4758,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.5636987428496363, 0.07945240535989491),
#    'publishedAt': 1452319476.0,
#    'subscriberCount': 82629,
#    'title': 'Super Cute',
#    'topics': {'n0': 'lifestyle', 'n1': 'gaming'},
#    'videoCount': 4,
#    'viewCount': 113465,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.00942830926456727,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1162,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.021509200192940035, 0.657801439833718),
#    'publishedAt': 1470602315.0,
#    'subscriberCount': 298013,
#    'title': 'Ycro',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 154,
#    'viewCount': 13067698,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.008868192259930335,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1588,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.7774509679982072, 0.06185304472092979),
#    'publishedAt': 1468089993.0,
#    'subscriberCount': 8882,
#    'title': 'Closer',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 135,
#    'viewCount': 168395,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010117107407278387,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 770,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.08269777517998371, 0.7160539708587564),
#    'publishedAt': 1429901216.0,
#    'subscriberCount': 15567,
#    'title': 'Avengi',
#    'topics': {'n0': 'gaming'},
#    'videoCount': 8,
#    'viewCount': 61933,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.0067460728061986865,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 5908,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.2172016133635384, 0.14901301494870453),
#    'publishedAt': 1431993370.0,
#    'subscriberCount': 411445,
#    'title': 'Turma Kids',
#    'topics': {'n0': 'entertainment',
#     'n1': 'rock music',
#     'n2': 'music',
#     'n3': 'hobby',
#     'n4': 'lifestyle'},
#    'videoCount': 214,
#    'viewCount': 148565033,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007361629736694771,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3582,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.3073946899641627, 0.08111967645632352),
#    'publishedAt': 1509131505.0,
#    'subscriberCount': 218859,
#    'title': 'Pilhado',
#    'topics': {'n0': 'football', 'n1': 'sports'},
#    'videoCount': 91,
#    'viewCount': 8075523,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.009859074652283894,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 246,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.0916932458155344, 0.3627608596250686),
#    'publishedAt': 1469916210.0,
#    'subscriberCount': 53765,
#    'title': 'MoriMurando',
#    'topics': {'n0': 'action game', 'n1': 'entertainment', 'n2': 'gaming'},
#    'videoCount': 1,
#    'viewCount': 235321,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.00954283809967761,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1044,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8778245461759459, 0.8056342306488651),
#    'publishedAt': 1330320585.0,
#    'subscriberCount': 20186,
#    'title': 'Vicio em Games',
#    'topics': {'n0': 'action game', 'n1': 'gaming'},
#    'videoCount': 512,
#    'viewCount': 2177582,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.009238240926279782,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1024,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.9529030865814632, 0.38535257300912434),
#    'publishedAt': 1272376849.0,
#    'subscriberCount': 112219,
#    'title': 'Redelease',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 251,
#    'viewCount': 7146052,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010179331212315089,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 586,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.0629442603093857, 0.7611276916539622),
#    'publishedAt': 1396220120.0,
#    'subscriberCount': 896554,
#    'title': 'ThunberGames',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1565,
#    'viewCount': 150127150,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010236162839879182,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 7107,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8126121543108823, 0.10906960563478703),
#    'publishedAt': 1427390227.0,
#    'subscriberCount': 250188,
#    'title': 'Polly Pocket em Portugues Brasil',
#    'topics': {'n0': 'movies', 'n1': 'entertainment'},
#    'videoCount': 362,
#    'viewCount': 83923861,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.01021654439725763,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 276,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8887802503480695, 0.859967422227583),
#    'publishedAt': 1434774266.0,
#    'subscriberCount': 114139,
#    'title': 'Zorbs',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 470,
#    'viewCount': 7240025,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.00989727800730184,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 653,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.5790813125589171, 0.009955067999547299),
#    'publishedAt': 1433785884.0,
#    'subscriberCount': 161007,
#    'title': 'Nerdbunker',
#    'topics': {'n0': 'gaming',
#     'n1': 'action game',
#     'n2': 'movies',
#     'n3': 'entertainment'},
#    'videoCount': 262,
#    'viewCount': 4118706,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.008943563286954557,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1006,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.7437799936237478, 0.09071726326074675),
#    'publishedAt': 1457311153.0,
#    'subscriberCount': 210088,
#    'title': 'JuanDmc',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 303,
#    'viewCount': 18702640,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.01014238813735369,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 899,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.6901387059043727, 0.027249343105388693),
#    'publishedAt': 1396047383.0,
#    'subscriberCount': 19540,
#    'title': 'Isso Daria Um Video',
#    'topics': {'n0': 'entertainment', 'n1': 'lifestyle'},
#    'videoCount': 104,
#    'viewCount': 862665,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.008799074007052793,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1488,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 4,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.7117251404319677, 0.08034908675470254),
#    'publishedAt': 1424368273.0,
#    'subscriberCount': 747019,
#    'title': 'Rick Santina',
#    'topics': {'n0': 'gaming',
#     'n1': 'lifestyle',
#     'n2': 'role-playing video game'},
#    'videoCount': 360,
#    'viewCount': 81584189,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010750662786948403,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 126,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.4471665152160781, 0.9942781339706953),
#    'publishedAt': 1427049129.0,
#    'subscriberCount': 394870,
#    'title': 'Nakada',
#    'topics': {'n0': 'lifestyle'},
#    'videoCount': 76,
#    'viewCount': 10301825,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007080042354541108,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 4765,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.9829924821887147, 0.6392799699294747),
#    'publishedAt': 1530678073.0,
#    'subscriberCount': 190709,
#    'title': 'Diario da Tia Hellen',
#    'topics': {'n0': 'lifestyle', 'n1': 'hobby', 'n2': 'food'},
#    'videoCount': 18,
#    'viewCount': 2115674,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010283722013189408,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 437,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 3,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8827377696831686, 0.18194501260277024),
#    'publishedAt': 1416851923.0,
#    'subscriberCount': 215690,
#    'title': 'Likea',
#    'topics': {'n0': 'gaming', 'n1': 'role-playing video game'},
#    'videoCount': 98,
#    'viewCount': 3335967,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.010165370292942207,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 616,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.8265229103809821, 0.10948651360518426),
#    'publishedAt': 1373942301.0,
#    'subscriberCount': 81317,
#    'title': 'Vutuner',
#    'topics': {'n0': 'gaming', 'n1': 'action-adventure game'},
#    'videoCount': 506,
#    'viewCount': 6653120,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.00867548395993083,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1308,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.284995414591124, 0.09274890562340077),
#    'publishedAt': 1321611654.0,
#    'subscriberCount': 834557,
#    'title': 'Leandro Fellipe',
#    'topics': {'n0': 'lifestyle', 'n1': 'technology'},
#    'videoCount': 469,
#    'viewCount': 72032389,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.01023187442606331,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 318,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.9614263871396186, 0.6275045131130833),
#    'publishedAt': 1332005671.0,
#    'subscriberCount': 258589,
#    'title': 'Os Spardas',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 1631,
#    'viewCount': 35902502,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.008707388896344918,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1459,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.5419301429861454, 0.06663037722241207),
#    'publishedAt': 1433126623.0,
#    'subscriberCount': 483087,
#    'title': 'Luis Desiro - Ousadia',
#    'topics': {'n0': 'entertainment'},
#    'videoCount': 101,
#    'viewCount': 32395947,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007763252416441587,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2581,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 2,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.9243886414488387, 0.2390097553971647),
#    'publishedAt': 1414430330.0,
#    'subscriberCount': 285225,
#    'title': 'reVisao',
#    'topics': {'n0': 'society', 'n1': 'knowledge'},
#    'videoCount': 394,
#    'viewCount': 10793435,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007446523383245569,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 3538,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.41892313687591465, 0.016082398578984598),
#    'publishedAt': 1473727378.0,
#    'subscriberCount': 184039,
#    'title': 'ANIMAL TV',
#    'topics': {'n0': 'lifestyle', 'n1': 'entertainment', 'n2': 'pets'},
#    'videoCount': 123,
#    'viewCount': 27849356,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.009490244380818394,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 1155,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.0288674765371306, 0.32605693069386593),
#    'publishedAt': 1441224676.0,
#    'subscriberCount': 65109,
#    'title': 'Combo Infinito',
#    'topics': {'n0': 'gaming', 'n1': 'action game'},
#    'videoCount': 860,
#    'viewCount': 4843734,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.007918648555925554,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 2617,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.1580083888480188, 0.788814433359325),
#    'publishedAt': 1394863145.0,
#    'subscriberCount': 13014,
#    'title': 'MB',
#    'topics': {'n0': 'music', 'n1': 'movies', 'n2': 'entertainment'},
#    'videoCount': 18,
#    'viewCount': 210369,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.008976528872236364,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 993,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.48967082881421925, 0.9410950795978809),
#    'publishedAt': 1437538925.0,
#    'subscriberCount': 57408,
#    'title': 'RedLuck',
#    'topics': {'n0': 'role-playing video game', 'n1': 'gaming'},
#    'videoCount': 319,
#    'viewCount': 4178367,
#    'visited': 1},
#   0.0),
#  ({'betweenness': 0.0,
#    'closeness': 0.01011050707624938,
#    'color': (255, 255, 255),
#    'commentCount': '0',
#    'counterId': 824,
#    'country': 'BR',
#    'hiddenSubscriberCount': 0,
#    'indegrees': 1,
#    'kindness': 0.0,
#    'outdegrees': 0,
#    'pos': (0.30893659550648106, 0.029971241596576766),
#    'publishedAt': 1397795372.0,
#    'subscriberCount': 23819,
#    'title': 'Mister Joker',
#    'topics': {'n0': 'gaming',
#     'n1': 'action game',
#     'n2': 'action-adventure game'},
#    'videoCount': 0,
#    'viewCount': 0,
#    'visited': 1},
#   0.0),
#  ...]

# %%
df = pd.DataFrame({})

for n in g.nodes:
    df = df.append({
        'title': g.nodes[n]['title'],
        'country': g.nodes[n]['country'],
        'publishedAt': g.nodes[n]['publishedAt'],
        'viewCount': g.nodes[n]['viewCount'],
        'subscriberCount': g.nodes[n]['subscriberCount'],
        'videoCount': g.nodes[n]['videoCount'],
        'topics': g.nodes[n]['topics'],
        'kindness': g.nodes[n]['kindness'],
        'outdegrees': g.nodes[n]['outdegrees'],
        'indegrees': g.nodes[n]['indegrees'],
        'betweenness': g.nodes[n]['betweenness'],
        'closeness': g.nodes[n]['closeness'],
    }, ignore_index=True)

# %%
df.describe()
# Out:
#        betweenness    closeness    indegrees     kindness   outdegrees  \
# count  8434.000000  8434.000000  8434.000000  8434.000000  8434.000000
# mean      0.000202     0.011552     1.867204     0.001294     1.867204
# std       0.001293     0.002628     1.748889     0.017229     4.746400
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.009879     1.000000     0.000000     0.000000
# 50%       0.000000     0.011647     1.000000     0.000000     0.000000
# 75%       0.000000     0.013458     2.000000     0.000000     0.000000
# max       0.026978     0.020469    25.000000     1.000000   100.000000
#
#        subscriberCount     videoCount     viewCount
# count     8.434000e+03    8434.000000  8.434000e+03
# mean      1.127200e+06     700.256581  2.976974e+08
# std       2.730057e+06    3290.192979  1.076929e+09
# min       0.000000e+00       0.000000  0.000000e+00
# 25%       4.248425e+04      60.000000  2.909434e+06
# 50%       2.428710e+05     210.500000  2.916712e+07
# 75%       1.013607e+06     602.000000  1.679527e+08
# max       7.287236e+07  143419.000000  2.590377e+10

# %%
sorted_df = df.sort_values(by='subscriberCount', ascending=False)
sorted_df[sorted_df.country == 'BR']
# Out:
#        betweenness  closeness country  indegrees  kindness  outdegrees  \
# 5769  2.393338e-02   0.017930      BR        7.0  0.000398         5.0
# 579   1.666501e-05   0.015925      BR        3.0  0.000312         3.0
# 3922  4.003985e-03   0.010971      BR       14.0  0.000490        23.0
# 8319  4.821793e-04   0.011471      BR        3.0  0.000285         4.0
# 2633  1.876837e-03   0.011050      BR       17.0  0.001220        19.0
# 7660  0.000000e+00   0.000000      BR        0.0  0.004220         7.0
# 380   2.267461e-04   0.011007      BR       12.0  0.000317        10.0
# 7024  1.686893e-05   0.015925      BR        3.0  0.000707         5.0
# 8031  3.240718e-03   0.011587      BR        7.0  0.000224         7.0
# 4385  4.204721e-05   0.012037      BR        1.0  0.001432         3.0
# 1914  5.859569e-04   0.013039      BR        1.0  0.010704         7.0
# 4229  1.686190e-05   0.009706      BR        4.0  0.000230         1.0
# 1052  7.517467e-04   0.011745      BR       11.0  0.002093         9.0
# 1805  6.142133e-04   0.007439      BR        6.0  0.007723        12.0
# 1264  6.290775e-04   0.009261      BR        7.0  0.000222         9.0
# 3487  8.015502e-05   0.011454      BR        4.0  0.000622         4.0
# 6189  8.334777e-04   0.010132      BR        2.0  0.007975        11.0
# 7294  1.686190e-05   0.007445      BR        2.0  0.000920         1.0
# 8429  7.494564e-03   0.011746      BR        8.0  0.000797        17.0
# 2108  1.889170e-07   0.007441      BR        4.0  0.000552         3.0
# 6457  2.236629e-06   0.010333      BR        8.0  0.000039         1.0
# 1588  4.597810e-04   0.010866      BR        5.0  0.000147         6.0
# 1587  1.686190e-05   0.010209      BR        1.0  0.004141         1.0
# 3616  3.052615e-04   0.007846      BR        6.0  0.000690        12.0
# 4937  4.161555e-04   0.008880      BR        1.0  0.005678        16.0
# 6638  2.558658e-02   0.012640      BR       20.0  0.000127        13.0
# 2762  6.227980e-06   0.010975      BR        9.0  0.000120         6.0
# 4720  8.898277e-04   0.006465      BR        3.0  0.005853         5.0
# 7695  3.538336e-04   0.011630      BR        5.0  0.000407         7.0
# 6942  2.159187e-03   0.012145      BR        6.0  0.000179         8.0
# ...            ...        ...     ...        ...       ...         ...
# 2057  0.000000e+00   0.009460      BR        1.0  0.000000         0.0
# 2821  0.000000e+00   0.007445      BR        1.0  0.000000         0.0
# 3758  0.000000e+00   0.010111      BR        1.0  0.000000         0.0
# 4864  0.000000e+00   0.009904      BR        1.0  0.000000         0.0
# 6857  0.000000e+00   0.007079      BR        1.0  0.000000         0.0
# 5334  0.000000e+00   0.009485      BR        1.0  0.000000         0.0
# 5506  0.000000e+00   0.009547      BR        1.0  0.000000         0.0
# 6166  0.000000e+00   0.011105      BR        1.0  0.000000         0.0
# 6881  0.000000e+00   0.009460      BR        1.0  0.000000         0.0
# 4689  0.000000e+00   0.009620      BR        1.0  0.000000         0.0
# 3766  0.000000e+00   0.014053      BR        2.0  0.000000         0.0
# 4353  0.000000e+00   0.008435      BR        1.0  0.000000         0.0
# 911   0.000000e+00   0.009860      BR        1.0  0.000000         0.0
# 793   0.000000e+00   0.010111      BR        1.0  0.000000         0.0
# 3308  0.000000e+00   0.011945      BR        1.0  0.000000         0.0
# 4516  0.000000e+00   0.010198      BR        1.0  0.000000         0.0
# 4480  0.000000e+00   0.009460      BR        1.0  0.000000         0.0
# 329   0.000000e+00   0.008899      BR        1.0  0.000000         0.0
# 4954  0.000000e+00   0.010111      BR        1.0  0.000000         0.0
# 8408  0.000000e+00   0.009460      BR        1.0  0.000000         0.0
# 2675  0.000000e+00   0.009602      BR        1.0  0.000000         0.0
# 2239  0.000000e+00   0.008424      BR        1.0  0.000000         0.0
# 7098  0.000000e+00   0.010201      BR        1.0  0.000000         0.0
# 7143  0.000000e+00   0.006746      BR        1.0  0.000000         0.0
# 5498  0.000000e+00   0.009873      BR        1.0  0.000000         0.0
# 1494  0.000000e+00   0.008950      BR        3.0  0.000000         0.0
# 1439  0.000000e+00   0.007450      BR        2.0  0.000000         0.0
# 5730  0.000000e+00   0.013896      BR        3.0  0.000000         0.0
# 5786  0.000000e+00   0.007846      BR        1.0  0.000000         0.0
# 6245  0.000000e+00   0.006746      BR        1.0  0.000000         0.0
#
#       publishedAt  subscriberCount                  title  \
# 5769  1.14776e+09       27815339.0            Felipe Neto
# 579   1.40678e+09       21109795.0            Luccas Neto
# 3922  1.32909e+09       20877027.0            rezendeevil
# 8319  1.37808e+09       19148707.0            Voce Sabia?
# 2633  1.31795e+09       15780628.0         AuthenticGames
# 7660  1.33153e+09       15056101.0       Porta dos Fundos
# 380   1.35554e+09       12164492.0                 AM3NlC
# 7024  1.50067e+09       11831548.0            Irmaos Neto
# 8031  1.22195e+09       11656290.0        Canal Nostalgia
# 4385  1.15375e+09       11409853.0        Manual do Mundo
# 1914  1.30532e+09       10959013.0           Parafernalha
# 4229  1.40539e+09       10636672.0          Dani Russo Tv
# 1052  1.31052e+09       10587447.0             TazerCraft
# 1805  1.39745e+09       10546015.0    Erlania e Valentina
# 1264   1.2381e+09       10371344.0           Everson Zoio
# 3487  1.19143e+09       10126788.0             Galo Frito
# 6189  1.34368e+09        9387659.0        Turma da Monica
# 7294  1.44808e+09        9153396.0     Planeta das Gemeas
# 8429  1.25743e+09        8903658.0          Coisa de Nerd
# 2108   1.4406e+09        8638446.0               Kids Fun
# 6457  1.36493e+09        8356097.0         Gato Galactico
# 1588  1.35233e+09        8283225.0              Enaldinho
# 1587  1.20104e+09        8244163.0               MAIKI021
# 3616  1.27342e+09        7767448.0         Juliana Baltar
# 4937  1.39174e+09        7676223.0                   Tauz
# 6638  1.28046e+09        7353952.0                BRKsEDU
# 2762  1.38932e+09        7267762.0                 Afreim
# 4720  1.40582e+09        7049681.0           Kim RosaCuca
# 7695  1.31518e+09        7043615.0             Gameplayrj
# 6942   1.3755e+09        6946422.0        Caracol Raivoso
# ...           ...              ...                    ...
# 2057  1.46775e+09           1185.0            Hora do UP!
# 2821   1.4051e+09           1160.0          Julia Camargo
# 3758  1.45487e+09           1101.0         Drix Tattooist
# 4864  1.48866e+09           1038.0                Brunera
# 6857   1.4497e+09           1008.0  Brincando com a Carol
# 5334  1.27656e+09            933.0      Paulo Neto Design
# 5506  1.41685e+09            803.0          Kevin Breavan
# 6166  1.44838e+09            787.0        Fala ai Nathan!
# 6881   1.4541e+09            755.0             Pasalacqua
# 4689  1.46025e+09            700.0              La Favela
# 3766  1.48967e+09            686.0    KiiYii em Portugues
# 4353  1.50656e+09            672.0              TaNoBolso
# 911   1.45669e+09            651.0                BuzzPES
# 793   1.47508e+09            559.0          ESV GamePlays
# 3308  1.31605e+09            533.0          Vida de Gamer
# 4516  1.53431e+09            478.0        UMA TV TODO DIA
# 4480  1.45799e+09            453.0             TV de Tubo
# 329    1.3179e+09            280.0        Patrick Pereira
# 4954  1.53343e+09            251.0          Canal Do Ygor
# 8408  1.53981e+09            248.0              CANAL NSR
# 2675  1.53415e+09            131.0              Nham Nham
# 2239  1.47053e+09              0.0        The best sports
# 7098   1.3862e+09              0.0                   DARK
# 7143  1.45418e+09              0.0         Fun Toys Clube
# 5498  1.46992e+09              0.0                 schuzz
# 1494  1.46522e+09              0.0         Sempre Futebol
# 1439  1.40589e+09              0.0       Delicias da Gaby
# 5730  1.14533e+09              0.0          Chico Rezende
# 5786  1.31734e+09              0.0            Raissa Lima
# 6245  1.50181e+09              0.0    Baby Alive Kids Fun
#
#                                                  topics  videoCount  \
# 5769  {'n2': 'humor', 'n0': 'entertainment', 'n1': '...      1441.0
# 579   {'n2': 'entertainment', 'n3': 'hobby', 'n0': '...       550.0
# 3922  {'n2': 'entertainment', 'n0': 'role-playing vi...      6845.0
# 8319         {'n0': 'entertainment', 'n1': 'lifestyle'}       681.0
# 2633  {'n0': 'role-playing video game', 'n1': 'gaming'}      3516.0
# 7660  {'n2': 'movies', 'n0': 'entertainment', 'n1': ...       947.0
# 380   {'n0': 'role-playing video game', 'n1': 'gaming'}      3789.0
# 7024             {'n0': 'humor', 'n1': 'entertainment'}       198.0
# 8031            {'n0': 'movies', 'n1': 'entertainment'}       314.0
# 4385                                {'n0': 'lifestyle'}      1400.0
# 1914  {'n2': 'movies', 'n0': 'entertainment', 'n1': ...       682.0
# 4229                 {'n0': 'lifestyle', 'n1': 'music'}       108.0
# 1052  {'n0': 'role-playing video game', 'n1': 'gaming'}      3039.0
# 1805                 {'n0': 'hobby', 'n1': 'lifestyle'}       589.0
# 1264  {'n2': 'entertainment', 'n0': 'lifestyle', 'n1...       354.0
# 3487             {'n0': 'music', 'n1': 'entertainment'}       377.0
# 6189            {'n0': 'movies', 'n1': 'entertainment'}       729.0
# 7294                                {'n0': 'lifestyle'}       423.0
# 8429                                   {'n0': 'gaming'}      1807.0
# 2108         {'n0': 'lifestyle', 'n1': 'entertainment'}       689.0
# 6457  {'n2': 'movies', 'n0': 'entertainment', 'n1': ...       698.0
# 1588                  {'n0': 'food', 'n1': 'lifestyle'}       424.0
# 1587              {'n0': 'vehicles', 'n1': 'lifestyle'}       921.0
# 3616                 {'n0': 'hobby', 'n1': 'lifestyle'}       508.0
# 4937                                    {'n0': 'music'}       160.0
# 6638              {'n0': 'action game', 'n1': 'gaming'}      3762.0
# 2762  {'n0': 'role-playing video game', 'n1': 'gaming'}      2523.0
# 4720                                {'n0': 'lifestyle'}       720.0
# 7695                                   {'n0': 'gaming'}     13500.0
# 6942         {'n0': 'entertainment', 'n1': 'lifestyle'}        99.0
# ...                                                 ...         ...
# 2057  {'n0': 'role-playing video game', 'n1': 'gaming'}        40.0
# 2821  {'n2': 'hobby', 'n0': 'health', 'n1': 'lifesty...         0.0
# 3758  {'n2': 'technology', 'n4': 'entertainment', 'n...        14.0
# 4864    {'n0': 'music', 'n1': 'music of latin america'}       127.0
# 6857                 {'n0': 'hobby', 'n1': 'lifestyle'}        37.0
# 5334  {'n2': 'action game', 'n0': 'gaming', 'n1': 'r...        45.0
# 5506  {'n2': 'gaming', 'n3': 'entertainment', 'n0': ...        13.0
# 6166  {'n2': 'gaming', 'n0': 'lifestyle', 'n1': 'ent...        24.0
# 6881              {'n0': 'action game', 'n1': 'gaming'}       118.0
# 4689                                                 {}         0.0
# 3766             {'n0': 'music', 'n1': 'entertainment'}        62.0
# 4353                 {'n0': 'football', 'n1': 'sports'}        14.0
# 911               {'n0': 'sports game', 'n1': 'gaming'}        25.0
# 793               {'n0': 'gaming', 'n1': 'action game'}         2.0
# 3308              {'n0': 'gaming', 'n1': 'action game'}       204.0
# 4516  {'n2': 'entertainment', 'n0': 'health', 'n1': ...        10.0
# 4480              {'n0': 'gaming', 'n1': 'action game'}         0.0
# 329                                                  {}        28.0
# 4954  {'n2': 'lifestyle', 'n0': 'entertainment', 'n1...         5.0
# 8408  {'n2': 'role-playing video game', 'n0': 'gamin...        15.0
# 2675                  {'n0': 'food', 'n1': 'lifestyle'}        33.0
# 2239  {'n2': 'music', 'n0': 'football', 'n1': 'sports'}       237.0
# 7098              {'n0': 'gaming', 'n1': 'action game'}        17.0
# 7143  {'n2': 'movies', 'n3': 'entertainment', 'n0': ...       231.0
# 5498                {'n0': 'rock music', 'n1': 'music'}         7.0
# 1494                 {'n0': 'football', 'n1': 'sports'}       290.0
# 1439                  {'n0': 'food', 'n1': 'lifestyle'}       148.0
# 5730         {'n0': 'lifestyle', 'n1': 'entertainment'}       247.0
# 5786                 {'n0': 'lifestyle', 'n1': 'music'}         0.0
# 6245                                                 {}         0.0
#
#          viewCount
# 5769  5.323839e+09
# 579   4.639199e+09
# 3922  7.221062e+09
# 8319  2.062269e+09
# 2633  6.318297e+09
# 7660  4.356892e+09
# 380   3.319216e+09
# 7024  1.058501e+09
# 8031  9.487899e+08
# 4385  1.947152e+09
# 1914  2.571646e+09
# 4229  4.680991e+08
# 1052  3.621971e+09
# 1805  2.578427e+09
# 1264  6.486873e+08
# 3487  1.567558e+09
# 6189  7.292932e+09
# 7294  2.199802e+09
# 8429  2.318868e+09
# 2108  1.876938e+09
# 6457  1.527210e+09
# 1588  8.922014e+08
# 1587  8.732711e+08
# 3616  1.539608e+09
# 4937  1.664429e+09
# 6638  1.318456e+09
# 2762  9.878934e+08
# 4720  6.402566e+08
# 7695  2.570807e+09
# 6942  3.702642e+08
# ...            ...
# 2057  4.023100e+04
# 2821  0.000000e+00
# 3758  9.765000e+03
# 4864  4.852800e+04
# 6857  6.100200e+04
# 5334  1.568770e+05
# 5506  8.516000e+03
# 6166  8.768000e+03
# 6881  2.897300e+04
# 4689  0.000000e+00
# 3766  6.582300e+04
# 4353  1.503300e+04
# 911   1.936000e+03
# 793   1.865000e+03
# 3308  1.395300e+04
# 4516  5.212000e+03
# 4480  0.000000e+00
# 329   3.793800e+04
# 4954  4.060000e+03
# 8408  1.310000e+03
# 2675  1.909000e+03
# 2239  6.833081e+06
# 7098  7.471700e+04
# 7143  3.935138e+07
# 5498  1.034800e+04
# 1494  1.719269e+08
# 1439  2.398220e+05
# 5730  1.659998e+07
# 5786  4.690000e+02
# 6245  0.000000e+00
#
# [1071 rows x 12 columns]

# %%
us_df = df.loc[df["country"] == "BR"]

# %%
x = sns.lmplot(data=us_df, x='betweenness', y='kindness')
# x.set_yscale('log')

# %%
y = sns.lmplot(data=df, x='viewCount', y='subscriberCount', hue="country", palette=sns.color_palette("muted"))
# Out:
# /home/rapha/.local/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.

# %%
z = sns.regplot(data=df, x='subscriberCount', y='publishedAt')

# %%
df['kindness'].corr(df['betweenness'])
# Out:
# 0.024004974501257433

# %%
df['viewCount'].corr(df['subscriberCount'])
# Out:
# 0.7610870534177299

# %%
df['publishedAt'].astype(float).corr(df['subscriberCount'])
# Out:
# -0.1669796549579717

# %%
df['kindness'].corr(df['closeness'])
# Out:
# 0.018404340446056884

# %%
bet = [g.nodes[x]['kindness'] for x in g.nodes if g.nodes[x]['kindness'] > 0]
hist = plt.hist(bet, bins=10)
xdata = [(l + r) / 2 for l, r in zip(hist[1][:-1], hist[1][1:])]
ydata = [h + 1 for h in hist[0]]

# # Calcula uma regressão linear sobre os logaritmos dos dados.
# reg = ss.linregress(np.log(xdata), np.log(ydata))

# # Plota uma exponencial da curva de regressão.
# plt.plot(xdata, [x ** reg[0] * np.exp(reg[1]) - 1 for x in xdata])

# Exibe o gráfico.
# plt.title('distribuição de quantidade de citações')
plt.show()

# %%
# null_od = df.loc[(df["subscriberCount"] > 1000000) & (df["outdegrees"] == 0)]
# null_od.groupby('country').count()
kind_base = df.loc[(df["kindness"] > 0)]
kind_base
# Out:
#        betweenness  closeness country  indegrees  kindness  outdegrees  \
# 3     3.709605e-05   0.015524    None        2.0  0.000529         3.0
# 6     9.626703e-04   0.012689      GB        1.0  0.003231         9.0
# 13    3.372380e-05   0.007283      AR        1.0  0.000284         2.0
# 22    8.975129e-04   0.012642      CA        4.0  0.000082        10.0
# 25    1.535244e-07   0.010192      UA        5.0  0.002263        24.0
# 27    5.933748e-03   0.015504      US        7.0  0.000083         9.0
# 29    5.742726e-04   0.012937      US        6.0  0.006787        19.0
# 38    2.410689e-04   0.015323    None        5.0  0.002432         9.0
# 39    1.824991e-06   0.009604    None        1.0  0.000032         2.0
# 40    5.054351e-05   0.006921      CL        1.0  0.000581         5.0
# 41    5.163522e-04   0.010946      BR        7.0  0.000234        12.0
# 47    2.221758e-05   0.010230      BR        3.0  0.000083         7.0
# 49    2.162913e-03   0.015228    None        7.0  0.000513        11.0
# 61    3.369268e-03   0.018025      US        4.0  0.001800        11.0
# 66    4.438463e-05   0.016150      US        5.0  0.002785         3.0
# 71    1.675619e-03   0.016596      CA        8.0  0.000067         8.0
# 74    3.711396e-03   0.016614      US        8.0  0.000622        18.0
# 77    4.111719e-04   0.013910    None        1.0  0.001562         8.0
# 82    2.953293e-07   0.011055      US        5.0  0.000228         4.0
# 89    4.359952e-05   0.012555      US        1.0  0.000025         2.0
# 100   1.686190e-05   0.014649      US        2.0  0.000274         1.0
# 108   1.011714e-04   0.013878      GB        1.0  0.000556         6.0
# 110   3.654087e-05   0.010311      BR       10.0  0.000651         9.0
# 116   8.423918e-05   0.009464      BR        1.0  0.000558         6.0
# 121   4.218991e-08   0.006195    None        3.0  0.000797         2.0
# 123   2.510694e-03   0.008075      MX        8.0  0.000171         6.0
# 126   1.785673e-05   0.015423      US        5.0  0.000073         6.0
# 131   3.378005e-05   0.020184    None        9.0  0.002715         2.0
# 134   3.042455e-04   0.011047      US        4.0  0.000464         5.0
# 144   1.686190e-05   0.011668    None        2.0  0.000071         1.0
# ...            ...        ...     ...        ...       ...         ...
# 8327  2.726291e-03   0.012783    None        4.0  0.000427        15.0
# 8328  7.422186e-04   0.011681      BR        8.0  0.000929        13.0
# 8333  6.197674e-04   0.012022      BR        2.0  0.001950         6.0
# 8334  1.570970e-03   0.016349      US        2.0  0.000121         7.0
# 8335  4.596862e-03   0.015839      US        5.0  0.000065        12.0
# 8337  2.534676e-05   0.011884    None        3.0  0.000278         7.0
# 8341  1.686190e-05   0.013932      AU        1.0  0.003184         1.0
# 8345  4.300588e-04   0.010280    None        5.0  0.054975        10.0
# 8347  1.116609e-03   0.015654      US        2.0  0.001104         6.0
# 8349  2.334930e-04   0.014580      US        1.0  0.000039         5.0
# 8352  6.848057e-05   0.014173      US        7.0  0.032964         6.0
# 8354  3.399100e-05   0.009530      US        1.0  0.012122         4.0
# 8364  1.684784e-05   0.010097    None        2.0  0.000463         3.0
# 8365  2.570309e-05   0.017330    None        4.0  0.000156         2.0
# 8370  4.139901e-05   0.012791      US        1.0  0.004167         5.0
# 8372  3.769858e-05   0.013865      GB        1.0  0.000170         5.0
# 8376  3.839373e-04   0.015407      US        1.0  0.001207         6.0
# 8378  7.703364e-04   0.010874      BR        4.0  0.001591        24.0
# 8384  1.337097e-03   0.016987    None        7.0  0.000404        13.0
# 8391  3.372380e-05   0.013476    None        2.0  0.000013         1.0
# 8393  5.867476e-05   0.018130    None        9.0  0.000115         2.0
# 8403  3.369567e-05   0.006895      CR        1.0  0.000554         3.0
# 8407  1.689275e-04   0.012249      SE        2.0  0.000205        10.0
# 8413  1.686190e-05   0.006930      CO        1.0  0.000566         1.0
# 8415  0.000000e+00   0.015158      GB        1.0  0.000008         8.0
# 8418  4.177486e-04   0.016027      GB        5.0  0.000428        11.0
# 8419  9.695065e-04   0.015086    None        3.0  0.000059        12.0
# 8423  1.684784e-05   0.011142      US        1.0  0.000839         3.0
# 8429  7.494564e-03   0.011746      BR        8.0  0.000797        17.0
# 8433  1.347827e-04   0.006737    None        1.0  0.001630         9.0
#
#       publishedAt  subscriberCount  \
# 3     1.28529e+09        2399349.0
# 6     1.30937e+09        3878992.0
# 13    1.40073e+09        4741566.0
# 22    1.36338e+09        1280195.0
# 25    1.19773e+09        1564146.0
# 27    1.19433e+09        4794698.0
# 29    1.38132e+09        6584804.0
# 38     1.1679e+09        4600385.0
# 39    1.32459e+09        7511519.0
# 40    1.31382e+09        1010390.0
# 41    1.32789e+09        5152995.0
# 47    1.49569e+09        1383322.0
# 49    1.19509e+09        2879769.0
# 61    1.24488e+09        4408843.0
# 66    1.32177e+09        5521362.0
# 71    1.29359e+09        5271303.0
# 74    1.26742e+09        2309350.0
# 77    1.12827e+09        5392599.0
# 82    1.37462e+09        7059382.0
# 89    1.23277e+09        5939190.0
# 100   1.15138e+09        4439511.0
# 108   1.36241e+09        1976599.0
# 110   1.39121e+09        2658153.0
# 116   1.34089e+09        1180725.0
# 121   1.25243e+09        5434458.0
# 123   1.33446e+09       19845490.0
# 126    1.4726e+09        2710269.0
# 131   1.26627e+09       10651646.0
# 134   1.12809e+09        3914606.0
# 144   1.38163e+09        3892022.0
# ...           ...              ...
# 8327  1.35541e+09        1743120.0
# 8328  1.30488e+09        6665981.0
# 8333  1.42323e+09        4571230.0
# 8334  1.29097e+09        1837392.0
# 8335  1.18792e+09        2185136.0
# 8337  1.25911e+09        2039992.0
# 8341  1.21525e+09        1172397.0
# 8345  1.40049e+09        1632183.0
# 8347  1.23037e+09        1701983.0
# 8349  1.29575e+09        1350105.0
# 8352  1.34748e+09        3701876.0
# 8354  1.46734e+09        1796347.0
# 8364  1.42941e+09        4443231.0
# 8365  1.30004e+09        1187011.0
# 8370   1.3676e+09        1253840.0
# 8372  1.38057e+09        2588965.0
# 8376  1.42652e+09        3105176.0
# 8378  1.34929e+09        2343583.0
# 8384  1.20516e+09        8430438.0
# 8391  1.19664e+09        1768844.0
# 8393  1.32121e+09        8235675.0
# 8403  1.39163e+09        1210204.0
# 8407  1.32015e+09        1018121.0
# 8413  1.44497e+09        5269742.0
# 8415  1.51752e+09        1140785.0
# 8418  1.30408e+09        1816381.0
# 8419  1.22306e+09        3008094.0
# 8423  1.43716e+09        1322406.0
# 8429  1.25743e+09        8903658.0
# 8433  1.39639e+09        3507419.0
#
#                                              title  \
# 3                                         Tpindell
# 6                                   TheGamingLemon
# 13                                           VIRAL
# 22                                       MrTLexify
# 25
# 27                                Household Hacker
# 29                    Peppa Pig - Official Channel
# 38                                  blndsundoll4mj
# 39                                  Roma and Diana
# 40                                        iviiween
# 41                                        MoonKase
# 47                           Rezendeevil Minecraft
# 49                                       maxmoefoe
# 61                                      blogilates
# 66                                  Rebecca Zamolo
# 71                                       FaZe Rain
# 74                                         Jenn Im
# 77                                             CNN
# 82                             Saturday Night Live
# 89                                          G-Eazy
# 100                                     jacksfilms
# 108                                     Spencer FC
# 110                                       Luiz1227
# 116                                 Wendel Bezerra
# 121                                Taciele Alcolea
# 123                               Luisito Comunica
# 126                                Battle Universe
# 131                                   CaseyNeistat
# 134                                       whatever
# 144
# ...                                            ...
# 8327                          Alltime Conspiracies
# 8328                                  VenomExtreme
# 8333                       O Que Nao Dizer Oficial
# 8334                                 sawyerhartman
# 8335                                 The Warp Zone
# 8337                             Disney Studios LA
# 8341                                     superwog1
# 8345  HooplaKidz Edu - Educational Videos For Kids
# 8347                                 Lamarr Wilson
# 8349                                      SypherPK
# 8352                                        Seeker
# 8354                           Princess ToysReview
# 8364                                 Maria Venture
# 8365                                   Mamrie Hart
# 8370                           Brothers Green Eats
# 8372                  MasterOv - Mobile & io Games
# 8376                               Great Big Story
# 8378                                     GamerZeal
# 8384                               Shane Dawson TV
# 8391                                   KevinLaSean
# 8393                                   ThatcherJoe
# 8403                          La Habitacion Oscura
# 8407                                        Sp4zie
# 8413                                 Calle y Poche
# 8415                                   MoreSidemen
# 8418                                         Yammy
# 8419                                  AngryJoeShow
# 8423                                DomisLive NEWS
# 8429                                 Coisa de Nerd
# 8433                                   EugeneSagaz
#
#                                                  topics  videoCount  \
# 3               {'n0': 'entertainment', 'n1': 'gaming'}       399.0
# 6     {'n0': 'gaming', 'n1': 'role-playing video game'}       659.0
# 13           {'n0': 'lifestyle', 'n1': 'entertainment'}       603.0
# 22                {'n0': 'action game', 'n1': 'gaming'}       945.0
# 25    {'n2': 'tv shows', 'n3': 'music', 'n0': 'enter...      9486.0
# 27    {'n2': 'food', 'n0': 'lifestyle', 'n1': 'techn...       479.0
# 29              {'n0': 'movies', 'n1': 'entertainment'}       314.0
# 38                 {'n0': 'lifestyle', 'n1': 'fashion'}      2196.0
# 39    {'n2': 'music', 'n0': 'hobby', 'n1': 'lifestyle'}        33.0
# 40           {'n0': 'lifestyle', 'n1': 'entertainment'}       156.0
# 41    {'n0': 'role-playing video game', 'n1': 'gaming'}      2796.0
# 47    {'n0': 'role-playing video game', 'n1': 'gaming'}       233.0
# 49    {'n2': 'humor', 'n0': 'entertainment', 'n1': '...       149.0
# 61                 {'n0': 'fitness', 'n1': 'lifestyle'}       582.0
# 66                    {'n0': 'food', 'n1': 'lifestyle'}       544.0
# 71                {'n0': 'action game', 'n1': 'gaming'}      1638.0
# 74                 {'n0': 'fashion', 'n1': 'lifestyle'}       612.0
# 77                  {'n0': 'politics', 'n1': 'society'}    143419.0
# 82    {'n2': 'humor', 'n0': 'entertainment', 'n1': '...      6546.0
# 89               {'n0': 'hip hop music', 'n1': 'music'}       192.0
# 100              {'n0': 'entertainment', 'n1': 'music'}      1076.0
# 108               {'n0': 'sports game', 'n1': 'gaming'}      1056.0
# 110   {'n0': 'role-playing video game', 'n1': 'gaming'}      1519.0
# 116          {'n0': 'entertainment', 'n1': 'lifestyle'}       172.0
# 121                {'n0': 'lifestyle', 'n1': 'fashion'}      1207.0
# 123                   {'n0': 'lifestyle', 'n1': 'food'}       567.0
# 126   {'n2': 'hobby', 'n0': 'lifestyle', 'n1': 'ente...       430.0
# 131                                 {'n0': 'lifestyle'}       979.0
# 134              {'n0': 'entertainment', 'n1': 'humor'}       175.0
# 144          {'n0': 'lifestyle', 'n1': 'entertainment'}      1155.0
# ...                                                 ...         ...
# 8327  {'n2': 'entertainment', 'n0': 'society', 'n1':...       645.0
# 8328  {'n0': 'gaming', 'n1': 'role-playing video game'}      2481.0
# 8333  {'n2': 'lifestyle', 'n0': 'entertainment', 'n1...       186.0
# 8334         {'n0': 'lifestyle', 'n1': 'entertainment'}       493.0
# 8335  {'n2': 'music', 'n0': 'gaming', 'n1': 'enterta...       639.0
# 8337            {'n0': 'movies', 'n1': 'entertainment'}       844.0
# 8341         {'n0': 'entertainment', 'n1': 'lifestyle'}        69.0
# 8345  {'n2': 'music', 'n0': 'entertainment', 'n1': '...       132.0
# 8347            {'n0': 'lifestyle', 'n1': 'technology'}      1311.0
# 8349  {'n0': 'role-playing video game', 'n1': 'gaming'}       728.0
# 8352               {'n0': 'society', 'n1': 'lifestyle'}      3275.0
# 8354                 {'n0': 'hobby', 'n1': 'lifestyle'}       584.0
# 8364                                {'n0': 'lifestyle'}       101.0
# 8365         {'n0': 'lifestyle', 'n1': 'entertainment'}       249.0
# 8370                  {'n0': 'food', 'n1': 'lifestyle'}       476.0
# 8372                                   {'n0': 'gaming'}      1644.0
# 8376                                {'n0': 'lifestyle'}      2052.0
# 8378                                   {'n0': 'gaming'}      2817.0
# 8384             {'n0': 'entertainment', 'n1': 'music'}       216.0
# 8391  {'n2': 'music', 'n0': 'lifestyle', 'n1': 'ente...       319.0
# 8393  {'n2': 'lifestyle', 'n0': 'gaming', 'n1': 'ent...       284.0
# 8403  {'n2': 'society', 'n3': 'music', 'n0': 'movies...       360.0
# 8407      {'n0': 'gaming', 'n1': 'strategy video game'}       875.0
# 8413                 {'n0': 'lifestyle', 'n1': 'music'}       153.0
# 8415            {'n0': 'gaming', 'n1': 'entertainment'}        97.0
# 8418  {'n0': 'role-playing video game', 'n1': 'gaming'}      2212.0
# 8419              {'n0': 'action game', 'n1': 'gaming'}      1353.0
# 8423  {'n2': 'music', 'n0': 'hip hop music', 'n1': '...      1846.0
# 8429                                   {'n0': 'gaming'}      1807.0
# 8433              {'n0': 'action game', 'n1': 'gaming'}      1198.0
#
#          viewCount
# 3     3.496005e+08
# 6     6.321449e+08
# 13    1.094667e+09
# 22    3.820790e+08
# 25    9.990606e+08
# 27    8.074943e+08
# 29    2.283550e+09
# 38    1.448173e+09
# 39    1.440924e+08
# 40    8.749802e+07
# 41    1.482289e+09
# 47    5.729853e+07
# 49    2.658520e+08
# 61    6.221433e+08
# 66    8.999552e+08
# 71    9.960396e+08
# 74    2.383655e+08
# 77    3.957033e+09
# 82    5.299961e+09
# 89    4.218229e+08
# 100   1.909426e+09
# 108   6.225468e+08
# 110   2.585247e+08
# 116   5.167158e+07
# 121   6.083276e+08
# 123   2.288741e+09
# 126   6.877906e+08
# 131   2.431711e+09
# 134   8.368939e+08
# 144   3.018625e+09
# ...            ...
# 8327  2.999053e+08
# 8328  1.076992e+09
# 8333  3.460414e+08
# 8334  1.074919e+08
# 8335  6.063657e+08
# 8337  1.300993e+09
# 8341  1.965842e+08
# 8345  4.081776e+08
# 8347  1.871788e+08
# 8349  1.152716e+08
# 8352  8.506205e+08
# 8354  9.587289e+08
# 8364  1.622059e+08
# 8365  9.232773e+07
# 8370  1.069112e+08
# 8372  6.950927e+08
# 8376  9.357541e+08
# 8378  4.687891e+08
# 8384  1.131319e+09
# 8391  3.208725e+08
# 8393  1.255095e+09
# 8403  1.345279e+08
# 8407  5.237462e+08
# 8413  3.335279e+08
# 8415  9.841750e+07
# 8418  4.342533e+08
# 8419  8.936755e+08
# 8423  3.703924e+08
# 8429  2.318868e+09
# 8433  1.256411e+09
#
# [2025 rows x 12 columns]

# %%
bet = [g.nodes[x]['kindness'] for x in g.nodes if g.nodes[x]['kindness'] > 0]
hist = plt.hist(bet, bins=10)
xdata = [(l + r) / 2 for l, r in zip(hist[1][:-1], hist[1][1:])]
ydata = [h + 1 for h in hist[0]]

# # Calcula uma regressão linear sobre os logaritmos dos dados.
# reg = ss.linregress(np.log(xdata), np.log(ydata))

# # Plota uma exponencial da curva de regressão.
# plt.plot(xdata, [x ** reg[0] * np.exp(reg[1]) - 1 for x in xdata])

# Exibe o gráfico.
# plt.title('distribuição de quantidade de citações')
plt.show()

# %%
test = nx.k_core(g)

# %%
from pprint import pprint
for n in test.nodes:
    print(test.nodes[n]['subscriberCount'], test.nodes[n]['title'])
# Out:
# 1961323 Alex Flores
# 2580932 Andrea Zuniga
# 1047075 Tavo Betancourt
# 1753625 Malcriado
# 2525802 Lizbeth Rodriguez
# 1072489 Carolina Diaz
# 28602699 Badabun
# 2018495 KimShantal
# 1400516 Queen Buenrostro

# %%
nx.core_number(g)
# Out:
# {'UCsDdQUPa4NvPvf2f00E5zfw': 2,
#  'UCLFFdNaytZDDSR7JGXFnTiA': 1,
#  'UCBWhJHVuxtxbeRp_PAdfn2w': 2,
#  'UCjkUsjn8wf7pMfj31_4YnWA': 2,
#  'UCB4Rm7m0PxZ1W_mYwz2gUig': 1,
#  'UCiB8cQpQm8v1CjOi9VmAB_g': 2,
#  'UCoaWFCFBDCXS030uimjZAkw': 6,
#  'UCFrD70VdlgQvlMD04cGsn0g': 2,
#  'UCE8CeczHxvbWVxCQyzBGPiQ': 1,
#  'UCEjWwpHX71w6aELHNT9lFwQ': 1,
#  'UCKVV1b71dtciZ_APO0BqRcw': 2,
#  'UCjnJMbNunuOFeUdrw7j1iew': 1,
#  'UCAcomub-SUAB9ylPiai_5SQ': 1,
#  'UCUXqYwTCR6R3Wr-FkLTD4AQ': 1,
#  'UCUBuQif8Zupe4T0_KbS_pZw': 1,
#  'UCw-rZCOg-lvI_RNb5Hv7pzA': 1,
#  'UCjXgGxaZ2NrwOdVhODyXLPQ': 1,
#  'UC62IIuaPmV-KeuYmEaIZ0eQ': 1,
#  'UCU6Xdctu2CsQp3NhyyrW3Dw': 5,
#  'UCECJDeK0MNapZbpaOzxrUPA': 7,
#  'UCFqaprvZ2K5JOULCvr18NTQ': 2,
#  'UCrb7XNZEwPheovXjgbkH5vg': 7,
#  'UCtm8vkLl55Nzt6WmC3MJvdA': 1,
#  'UCI4I6ldZ0jWe7vXpUVeVcpg': 5,
#  'UCqWYoHfqLmwBVESpVbaVk3g': 1,
#  'UCWq1xltHB2fDe6YkYoOrryg': 1,
#  'UCAOtE1V7Ots4DjM8JLlrYgg': 6,
#  'UCI75eRPEIvr802Ma8YLGuFg': 2,
#  'UCYZKDmmS5NNIaiD6hlNWh7Q': 1,
#  'UCOcLfTvfHaZYAZAK1xTdeQQ': 1,
#  'UCTlWiQTrL0rqxCjCt6H-a9g': 1,
#  'UC24yfMhHL7ryQhbc_Zw_qng': 2,
#  'UCToJF1-7c-Q9cHE4-YiVQeA': 1,
#  'UCr3eGCyVWlRKwUMwDhMcbQA': 1,
#  'UCSjXXHwfaDq1w9oQ0xgOFNg': 2,
#  'UCF2oW5-MO8dB6ul9WH9xi0A': 5,
#  'UCl_P0sCqxOdQpMwuajdXkRg': 3,
#  'UCYVRjGqi73s_CX9or-duyzw': 2,
#  'UCB6p9lMfq6rczdFStOJ1eNA': 9,
#  'UCVBCJI7BEzlLBEWc5azzzaw': 1,
#  'UCLejLCrluslcvs2tjd7XxgQ': 1,
#  'UCeUkFla3dlPPsxJxjluDFqw': 1,
#  'UCpXJtZWhOZ-73Vbp-gcsGkQ': 1,
#  'UC_QCEccfIiVyasdCNcpPL2w': 3,
#  'UCLDlBQFSXtq_iN8CL6aiBzA': 1,
#  'UC7iyparkdas-4UTSL_gktQg': 8,
#  'UCVu1acqOmA_EsUgYWrSDptQ': 3,
#  'UCny_vGt2N7_QJ5qBOAHxlcw': 4,
#  'UCJUn6QmXuFV9CkuJB9T7F_w': 4,
#  'UC4pxfsq8C7Ciwl2XOICD3Yw': 4,
#  'UCgjx7-YNp62DNhW51WF9zlQ': 1,
#  'UCW-thPvAldBRX5shd2EhnKg': 1,
#  'UCFE5p8gnE8rP2oU9KfNIa1A': 1,
#  'UC4GaQ9fCH5IpAq1AImj7XuQ': 1,
#  'UCDGB6MoY1PIuX5oHJSH9Cgg': 1,
#  'UCTghN4pE71SYikcDbbuv5eQ': 1,
#  'UCWrr4Wiu55omoVgMQh1YRcw': 1,
#  'UCIJwWYOfsCfz6PjxbONYXSg': 5,
#  'UCchtPNzW9kgSzrtLAvtuMcw': 1,
#  'UCZO_hYEMUyxvaPOYIUGmc-w': 2,
#  'UCuJ9YP_Hikt4IqITa6ZlxzQ': 2,
#  'UCS34YVeqtFViWRB3jc3o2FQ': 2,
#  'UCfw8x3VR-ElcaWW2Tg_jgSA': 4,
#  'UCYlydCH0iL3qIVO3c1yI_Og': 2,
#  'UCDXEqd6umFFKiEsF9ZSVxOw': 2,
#  'UC4B2vorxDcVMHWbwDfbwTOA': 1,
#  'UCxaVOVnhmT0-HCUv72jtOTA': 8,
#  'UCIuFtIO8i_XqA8lM7q4B1FQ': 2,
#  'UCjdT2bYYpL3GJ_9-9cttiFQ': 1,
#  'UCgWfS_47YPVbKx5EK4FLm4A': 5,
#  'UCerEuo5beXIb--qBaiDhSQA': 2,
#  'UCFeqAfEuKm7lIg2ddQzh61A': 1,
#  'UC3P2G1-vwqRhyfepKIKlGBQ': 1,
#  'UCupvZG-5ko_eiXAupbDfxWw': 3,
#  'UCk6Ns54af47rPzyNvOUnHDA': 1,
#  'UCNxrPkndtafSL_jVVER2zLQ': 1,
#  'UCqFzWxSCi39LnW1JKFR3efg': 7,
#  'UCf9mwD5gp4VslSMCD_Qknmw': 1,
#  'UCG3BRxZiQGXkP6A4rOq2QhQ': 1,
#  'UCR6xN1vlXxFWaIsLw-hA_qA': 1,
#  'UCYtaoJSk9iIrFxx8eZB15ag': 3,
#  'UCUMyZ3GFwAPkEuai3zR3rxg': 6,
#  'UCX9vYeMatNXoiY0u_VDcZAQ': 3,
#  'UCBkNpeyvBO2TdPGVC_PsPUA': 2,
#  'UCawxenzFyo_0rzpzejVHK1w': 1,
#  'UCC0_L3dsR6hprEa93PItzjw': 1,
#  'UCIgHM_a6P-MaUa7u8RoapzA': 3,
#  'UCzKrJ5NSA9o7RHYRG12kHZw': 1,
#  'UCLN3-Syq2bj6O4V6d4g7Tww': 1,
#  'UCv7mRUeeLfr_cYcsVKlkJew': 1,
#  'UC3ltLKLs41EqjXPMON9qSkQ': 2,
#  'UCiw97Iyd9CbAyr00D94v3tg': 1,
#  'UCWwYII3DJo3x1Gwp5b8_omg': 1,
#  'UCPcFg7aBbaVzXoIKSNqwaww': 2,
#  'UC_kARM8MBLDBxZQuZeYYQdQ': 1,
#  'UC2GC7O0nULuhHaeItbNPldw': 2,
#  'UCXv-co3EYHF7aOH4A93qAHQ': 1,
#  'UCSDOrsys45Ss7iyMBJWigCg': 1,
#  'UCJA_JgO3g4sv94OYtMDDtyA': 1,
#  'UCNTu7P3IyRRKJtibrrXG0Yg': 1,
#  'UC5lDVbmgb-sAcx2fjwy3KQA': 1,
#  'UCDPvdKoBCUL9qfBUNY2YrsQ': 1,
#  'UCe-2OsbraYSQkqU6J9xjqLg': 12,
#  'UCDDWI9jztA_rEnV0o2Ujm5Q': 3,
#  'UCQQJ1zCsFOxBuulIGUBGDfw': 2,
#  'UCMYLnqKqTrNtPPFYZRdM2Rg': 1,
#  'UCnXhtV6bM7TeUgMh4mvncDg': 1,
#  'UCDcXzHEjw71Y5EMj13QCCpA': 2,
#  'UCs93viQwZW-ph1oxNf4-tkw': 2,
#  'UC7s0alNI86k3CCaD8aOIcIw': 1,
#  'UCOK_RKB7ErNzkF3_DPfWUWQ': 2,
#  'UCPZqBlOTxyuzvHqvTy6I_hg': 1,
#  'UCy9xDEfMD8jrXU3NatFLLtw': 3,
#  'UC09Fia5XvD_JHUmllOBkhXA': 1,
#  'UCcE6uT3LB62v9ZYDfEy-ANQ': 1,
#  'UC1ZLXjXm3hKIcdnBWkEq8fg': 1,
#  'UCRcwOauWwSRaEaVnKy-UjRA': 1,
#  'UCGGlk1zXSXEeb_gP2ciY7Hg': 6,
#  'UCoxSGpW1YLvSjioonRaLbBg': 1,
#  'UCFI_HrVjdjKT9Y2DzBNBfMA': 1,
#  'UCtAnPvb9vhTDtNBfqUuOL0Q': 1,
#  'UCiSarBtpSphUrxtKDIW9c_A': 1,
#  'UCtinbF-Q-fVthA0qrFQTgXQ': 5,
#  'UCR9zNYkbsirABgzGi6i238A': 1,
#  'UCO_wGnKlld2g3PeiXbBD_XA': 1,
#  'UC37PFGlxWgx4tU6SlhPCdCw': 2,
#  'UCh9IsCRMfcUw9VVuB4iPP4A': 2,
#  'UCaYyVZvXGbxgPlicRnkErEQ': 1,
#  'UC7z7QwsK120X7hs7Wqi05aA': 2,
#  'UCGakUs_c0iYHGF5IXcPyguQ': 1,
#  'UCdyMwof5lX2UxXX9J9robkg': 1,
#  'UCb1o_cU97XtFA8YKxwV0UNg': 1,
#  'UCeZmz1Il1Ek1ttLE4ml2Img': 1,
#  'UCVWSfj_6x17X6ajZfo8-Kew': 1,
#  'UCk9msGFqSjNRLWeqk-CsLmg': 1,
#  'UCutJqz56653xV2wwSvut_hQ': 2,
#  'UCW8oY4R2qz61KmZjjUpu9Ww': 2,
#  'UCYhOmkm3CV8ZZ5uufagQ10A': 1,
#  'UCnZn7MJZ4B-GEe2AGMkDNaw': 1,
#  'UCzID5aFPBbvOPUoFb23_eSg': 1,
#  'UCLO5YnTRG8jySOUeU2ohnpw': 2,
#  'UCHMUvJUzb5HHYM_-fitRRBg': 1,
#  'UC0CNGfg_nO5ZnmWwhyQvQLg': 1,
#  'UChEmvd47U5S-lCbZvUjzGcA': 2,
#  'UCWi3PwONxmnA0o6Ahsbrv3w': 4,
#  'UC7_gcs09iThXybpVgjHZ_7g': 5,
#  'UCmOBcTDsualJq20Z3oGKd6w': 1,
#  'UCl7IyrcHJvI13IqpzH-cMHg': 2,
#  'UCYtWqkXGhAXv87gqoJhvZFQ': 1,
#  'UCmCXpOPE4-d8fZku4PxwnZA': 1,
#  'UCTKxcERj6SbybTF8LaFs1Hg': 1,
#  'UCuUUXUht1Osb9PVZayL14NA': 1,
#  'UCwNhhTBAXXePtgAz0Fs2flg': 2,
#  'UCCsOwxgEIS6Dz9lbbb4E3qg': 2,
#  'UC-HaopJx9G7MtL0wpAXx_2g': 1,
#  'UCArtZd4qMFfDCC8uKoHKn-A': 2,
#  'UCHgVY7Ww9Ya44-nxKpC3UOA': 1,
#  'UC8LcA3grYZg0GNpxlXh8owg': 1,
#  'UC5-KypSe7TdapTGA-9oC_PQ': 2,
#  'UCfyehHM_eo4g5JUyWmms2LA': 4,
#  'UCL7vy7MDOq9-tE-r6taQBlw': 5,
#  'UCemWUaSsUwgeYpGfkbvSQjg': 3,
#  'UCjujUHQnQDiIbAiY_GGD8zA': 1,
#  'UCIc3VLtBvQD0KqttqEJ4KYw': 1,
#  'UCNrXyaj_RdP3XjLPBLfyBdg': 1,
#  'UCuIn3Cb_KomGMPonBTHW6Cg': 1,
#  'UC7HaW7CHqRUZQ0cbC4mB4NQ': 1,
#  'UCAAszizDDdScfqclAybLiEA': 2,
#  'UCJln3D6deu-rA2UZbmgj-kw': 2,
#  'UCRCODdRFa5G2r3jkBCw9J7Q': 3,
#  'UCoK6uR64orX30YxrlP1cR2g': 2,
#  'UC282p6WVfdNBr7lMmgNQ6sw': 7,
#  'UCLrUcFaBGxFTIr6RA1ToZRw': 4,
#  'UC5nummn8xUaCqBsXnxEBh5A': 1,
#  'UCMDducspUU8dNb-mmuZR4wQ': 1,
#  'UCpVZPdYPkw47GLBKf6wCIAA': 1,
#  'UCm81dAvJhQcPDKvydBIEeyQ': 2,
#  'UC2qEG3TGNL2ovqrW0QDtFiA': 1,
#  'UCid9EwD-noQ9HGT_A61prKw': 5,
#  'UCigXhxKUIQr9_xJPIHArPiw': 1,
#  'UC6N6gvX6PUEfZgFkxA3sxlg': 2,
#  'UCggQhf35fbvZOosqcKm2AGA': 1,
#  'UCbZKAK7hnMuiJR7OGn4GFCQ': 1,
#  'UCsNud7A3Vz8X8Pqfw2L2wKg': 2,
#  'UCqMi0lQcC4j8MgkxnwEtHNg': 1,
#  'UCE8deXi-Eea3SuEV1Q1L4ug': 4,
#  'UCX6bbY8FRLgA08bhRIolG_Q': 1,
#  'UCLegnNLfivOIBlM97QUwefQ': 2,
#  'UC7IZqZ7vqJqin02yRee8M5A': 2,
#  'UCkgDPe8rhfsq5fJ3VWnQFLA': 3,
#  'UCL4sTV6SZniwiD3bRcrtNag': 1,
#  'UCK4lZM1dC6jEDzEhwPYvqMw': 5,
#  'UCzHcC_PfVKid0BITeTkZMjQ': 3,
#  'UC2XIaI2fGf4zPGyyRgFNJVQ': 1,
#  'UCCGLzU6yF7DBAIg0493j9ow': 2,
#  'UCQ7Zz8JYQXhv1WxbFNL_96w': 1,
#  'UC1TEpIIlUYM1Z4xWloAYGyg': 1,
#  'UC6iniX9nuuuwacoo_um3H_g': 1,
#  'UC0PMQXAwF6O6aeTpv962miA': 4,
#  'UCHW5uBSFBxilq2UhdPKdF5Q': 1,
#  'UCzmiEcHwcreH1xAVI9_a1MQ': 1,
#  'UC42VsoDtra5hMiXZSsD6eGg': 2,
#  'UC5vfe-HtXk_V0WgaoHqjxfg': 2,
#  'UCrUbqTCagwsaP2Fmr0p1TsA': 3,
#  'UCXBNYqHC-DakYa2D6gvkYDw': 1,
#  'UCmuccm2PUMlyIyvD6EOh_qA': 1,
#  'UCqvS0UZpSh8ydVQ7TxGNOJw': 3,
#  'UChSDkJMclPPBjyKqa4AQ9CA': 1,
#  'UCy5-ES0_mSak4qifQRcpwPw': 1,
#  'UCsPF3cApzCohxPp5oKdoWSQ': 1,
#  'UCf1u0VYm6PDejGsp77IbOpA': 1,
#  'UC4yOq3vxWGQeVe9rw1O02Nw': 2,
#  'UC0ED5C9OaHHlbpk55kNU5DQ': 2,
#  'UCzfyYtgvkx5mLy8nlLlayYg': 2,
#  'UCKyLxCQmg1MRyVH775YV8GA': 1,
#  'UCFOCH1L-2_O6vjhm_XoWksQ': 4,
#  'UCofORWTh9OYkrls8ruk2e0g': 3,
#  'UCWWq-rwjtG3NKzvZdwsXbqw': 1,
#  'UCnucBIHl6ohUTLfuOvpDM_Q': 8,
#  'UCeGvSi1Tb8OV78ue3_tux1A': 1,
#  'UCxvqciz5t_zKH0F2urF5yqg': 3,
#  'UCL2n7VnndYlbq6wiz6bxl0Q': 1,
#  'UCxucf8O8itcmkqu3d7yUavg': 5,
#  'UCHWJD3niQpHco1UjPYW0epg': 1,
#  'UCQMoeRP9SDaFipXDBIp3pFA': 5,
#  'UCxa4dNRfXRP0i9AzJUxGTyw': 1,
#  'UC3zffrbEGkNQXOiDj60o3Wg': 1,
#  'UCieJ3jImTKBR0CSo9fohnfw': 1,
#  'UCKeXa16clt79bbdVelLlqTg': 2,
#  'UCvotk2i7ir_2NJjJMiNCgnw': 5,
#  'UCZC45sBWNdkqSQ9Bwtt5lfA': 5,
#  'UCUB4mERPZ2V4GsO-T80AS2w': 1,
#  'UCLgJExBkiFBJxYhxsB5AJ7A': 1,
#  'UCeE673Co7hqMVNgDsIG5lQw': 1,
#  'UC-Q4WBqNtMF_2GbIsGjic4A': 1,
#  'UCxbLxZt5-Na0GZPIuuCucJg': 1,
#  'UCkqyYA8cSkbEAQ--bHdcBhg': 1,
#  'UCeTlAPV-TD0C-g-CRwFoz8g': 1,
#  'UC3auWN2JDfJy40MeB_hyBiQ': 3,
#  'UCeeFfhMcJa1kjtfZAGskOCA': 1,
#  'UCooC__cRxJCDO0DGs0ipjtA': 3,
#  'UCI8RJKzD-Yo7X0hUwUdXt2w': 1,
#  'UC5DRS1AfES0hVY8eBRUqlrA': 2,
#  'UCdlFmz0PxKWi7Uy05E-wp1w': 1,
#  'UCICWID-pS6fKVfeqGxJxGrw': 1,
#  'UC3IIbdGzO_8TqqNDzUR-gBg': 1,
#  'UC1C0Q3WUdv6t6ieM3a1vfyg': 1,
#  'UCn2MTOcWPppqn-hfh_qOF1Q': 1,
#  'UCB_HCEahBLwrZqj8WK8fWiQ': 1,
#  'UCnQnYo2NI4ozagGFCcsj9DQ': 2,
#  'UCbefCUItNOC_tnSzDN3BNGg': 3,
#  'UCVr6TsvMeTD9PCAKQqTzQ_A': 2,
#  'UC4OLYMoWyPkFGVZDDQ4EhFg': 1,
#  'UCx0eQsDrjn-EXMWeusTh2cQ': 1,
#  'UC8El-KamqNxKQg-r15BmIxw': 1,
#  'UCyXHoU7HQH06yoKg4y3X6ww': 1,
#  'UC6zhI71atP7YLoZyIyCIGNw': 5,
#  'UCajaRgUHyER6YBzk5bax0zQ': 1,
#  'UCgpUcV686d7DjYn2QjAEKiA': 1,
#  'UC_wM2uFtbBXPZPbHL94tfLw': 1,
#  'UCK33kufuprDPsfRPkMfgoRA': 2,
#  'UC75cS2N-5hIplBVPxNtZs5w': 1,
#  'UCGUkuAaBDkYPdUhIetzLQxQ': 5,
#  'UCOZmEMF5_FLLEtt3qeVv3lA': 1,
#  'UCzTKskwIc_-a0cGvCXA848Q': 2,
#  'UCHaB9LfH7lxyRPdNM3iZcJQ': 1,
#  'UClS1ZfxMTd9h1AkiQP2V54w': 1,
#  'UC0saNEiunBnnMubSwfVUepg': 1,
#  'UCXdWux01giurAUf2fPjXyRQ': 1,
#  'UCjdQgZNBKbWgx3_bTNCq1IA': 1,
#  'UC8WZHu0bmmJwS0775Sr_0aA': 1,
#  'UCaEi5QHsm4oNtGvk3DvzXAg': 1,
#  'UCwmFOfFuvRPI112vR5DNnrA': 6,
#  'UCxgA2h9v8fwALjhUIVv57bw': 1,
#  'UCYXvAOKehklq8lXX9oJhsEg': 2,
#  'UCGjETdt4PobqegtvuWRid5A': 3,
#  'UCZM2vsQp6xH1qmDCp8Ucwzg': 3,
#  'UC4wcC-ixA4EAD-XAXcdLv6w': 1,
#  'UCU6MxFBBZXBuSh6tLEbVq8A': 2,
#  'UCq6VFHwMzcMXbuKyG7SQYIg': 4,
#  'UCIhx8gV4mgRybaXcZnY5WVA': 1,
#  'UCKnMcgDLxDeq9HqUgLhtYbQ': 1,
#  'UCzSBv-iml0SCoAE-6v2ReWQ': 1,
#  'UC_xu1E_ySdB3EfLMaRfPT0A': 1,
#  'UCLq35g_MyAFUqd1xdkxN5kg': 2,
#  'UCmOhq0UWv_a85qdnbPgh7Mg': 2,
#  'UCzTdZz7z2sPRGCImodwOw0g': 6,
#  'UCUZUs2_5YPuZzviJVq0VjrQ': 1,
#  'UCzr91qFDgqPMOPg8xNijG8g': 1,
#  'UCGW9DSPXhtDajHpA28HO2Ng': 6,
#  'UCnrO0wqhKpMYUt_wSeaIasw': 6,
#  'UCxwl-prqInq1AQeiTjfJhOg': 2,
#  'UCqP8HosuK1VRD60wBaEEFtA': 1,
#  'UCCJ9Shh3w90o4LawLcOQ3Bg': 4,
#  'UC8Rospwl8JsEWl6WK1wgbdg': 1,
#  'UCrbrN66-0KK6DaLJg2t5fvQ': 1,
#  'UCjRMxmxocd3NbSc4xx7ypIQ': 1,
#  'UCoVJ-VqlxzKOY8Y6eKATu2w': 1,
#  'UCtZAaljDNIsIAIhwYYzvEiw': 2,
#  'UCbochVIwBCzJb9I2lLGXGjQ': 4,
#  'UC859jrBzNQGyHJEPBukzmTQ': 1,
#  'UCRuo8PJqeCD2i5Cao5haFHw': 2,
#  'UCUxuCVwzAsu41TI7UjOJYTA': 1,
#  'UCLeGsm5mPFTCXvqP9abta4A': 1,
#  'UCekQr9znsk2vWxBo3YiLq2w': 1,
#  'UCjb0MYm5NVLktN1b6GqQzOA': 1,
#  'UC4-eGDvOe41__-RiE0E9L6A': 4,
#  'UCke6I9N4KfC968-yRcd5YRg': 1,
#  'UCitROb1t7y9-4w8rs_-fMpg': 1,
#  'UC3BkgUUbMBysMwneW7N1pEQ': 1,
#  'UCnRuuiSVqDF2EmoYS7yE6ZA': 3,
#  'UCDH7rvHSmgdJl1w8PwXgK0Q': 1,
#  'UCw-6oDSq4P6h8ruebe5kSdQ': 1,
#  'UCzIunM7MqATSS9EoMhvPtOA': 1,
#  'UC4mHPIKWH4LpAu0LT3B3vBQ': 1,
#  'UCUth4kd_lkAltr7VusgNdSw': 1,
#  'UCfHtlDGt-QF5AKfeqjmIPHQ': 1,
#  'UCyHVforXYgg3bZs8luMfDcg': 1,
#  'UCWV3obpZVGgJ3j9FVhEjF2Q': 3,
#  'UCmCXCupUyIdWchmM0TtPV1Q': 1,
#  'UC2FA0UeTQAy3SffCvu69yTQ': 1,
#  'UCsDmvk3zlWs61YjWozMQ1tA': 1,
#  'UC5xAkS4828lDivq8cKFGSyw': 1,
#  'UCbVweePZlI0oDtBKu6I725Q': 1,
#  'UChTPGIZ0proRnhFhENlilKg': 1,
#  'UC0TT06mUKsXnCeHRSUgD1Dw': 1,
#  'UCuQ9PbS08dQJNWfwjQE-Fnw': 4,
#  'UCIKqXLBAv-TBo5aadLdpBUQ': 1,
#  'UCojgigZML_nuNmtqPO-0rqQ': 1,
#  'UCemXyN0MvApSEEtGvAsdo3g': 1,
#  'UC0f4yKY3WF5hWBCfjypRPTw': 1,
#  'UCotZ-qisEJABEStw67UnWXw': 1,
#  'UCtCRqkyw02rlU00-8QKC8fg': 1,
#  'UC4sdNaRsJE5U5kVgWCe22Ew': 1,
#  'UCxJ_Liuzh6kPdok1bIk4zEA': 1,
#  'UCe2ba_7LwQdNK5BKFSLm41Q': 3,
#  'UCGqFN0x-7MpWemIlT9Xmskw': 1,
#  'UCH0-0_0XNqkg8dTLYtFaWRg': 7,
#  'UCfDXsZ2-Wkd88QB8QloHDbw': 3,
#  'UCtvYrG5IeaYNeHDKjKJJNRA': 1,
#  'UCC14Fq2GD3dUMj6Pq0qcdlg': 1,
#  'UCcAF5uakt8c-i5IuChQmVMw': 1,
#  'UCVXNTkFA7h7o4qk7M7C0xBQ': 1,
#  'UCIrrRLyFMVmmL9NDAU2obJA': 4,
#  'UCQlVOYJyQp64rA12ac0mv6g': 1,
#  'UCtRZhZgOx7BJ_0vQEvCwI4w': 4,
#  'UCQZAjCaVre-Yzuc_x9gxcRA': 1,
#  'UCp09HHAYNT4joY1K_vr5dpA': 1,
#  'UCqGoMWYphRN_r9HB-0JDH2g': 1,
#  'UCTb3hlOhqE3hQD-tW-GQvsA': 1,
#  'UCeZ_GliTTOBahnjcnnRihAA': 1,
#  'UCbA3EjrdDfInPURQJKZ-epA': 5,
#  'UCR-Y4lWmrCYbr1XavmNMlvQ': 3,
#  'UCPbGiUt4Yu8EsaFM-KAmgjg': 2,
#  'UCeeWigmYlfIs9O4IneNHSAQ': 4,
#  'UCJPxSU-gTcYBuGveeOIPisg': 1,
#  'UCk93IyPZhXR3aQDHu4wLcTw': 1,
#  'UCH7ydmFIIxH-zMUSQdN4juA': 1,
#  'UCM6gjz16btqFIMY5nvQlSmw': 1,
#  'UCAbdeLiTPdjk1X2TY_ZdLDw': 2,
#  'UC8kY9Kx8dKGN3DN7I8SRQZA': 1,
#  'UCp63hPajo9Z7EEFpN9JYuMA': 3,
#  'UCH7wS695SVoVt_YlEzPswNA': 1,
#  'UCF1fu3BC2PCANgQQ63wRBHg': 1,
#  'UCneDwGLSclD-s7fRBnUIIcA': 1,
#  'UCWrlAhvRJXylZEciB716_pw': 1,
#  'UCurJsOc2S-CyK4T7jKIolIg': 6,
#  'UC4pxiz_9Ok-B4jiKBVYLODg': 6,
#  'UC7DdEm33SyaTDtWYGO2CwdA': 5,
#  'UC2vlpX8sNDBmPcY_1_QSGJg': 4,
#  'UCExPfvk_KO8mYAMZpENeTNQ': 1,
#  'UCtOHkTxCwPWkdkTckp1-jlw': 2,
#  'UCtmlDuXL7Hxs_fF0zXlvgPw': 1,
#  'UCkKdqfQUDb6BcC4mwYEkTnQ': 1,
#  'UCRbmoQpKsACJnnpWaECa_WA': 1,
#  'UC7PKWVICl-tLGxYvfhQMzmw': 1,
#  'UCwS9IeUbQdOrTVluMv_P8gA': 1,
#  'UCClXFRz0VUXBGfUPBTYMOnw': 1,
#  'UC64DDoBdEnCF-5CNwt38lJQ': 1,
#  'UCdD2tf-YhMHApzfHbh4qI8g': 3,
#  'UCcsGzu7c9aTTakcVbzCknJQ': 1,
#  'UCbcAUzRKwwsnUu183ATJ_Aw': 1,
#  'UC3DkFux8Iv-aYnTRWzwaiBA': 1,
#  'UCsHaCORAuXxrMDzC0hr8GPw': 1,
#  'UCYVnuzrfrXHJ3Px3C9MKm3g': 2,
#  'UC-i3WnEFcTntkZc-Pv9gArw': 2,
#  'UC8DkSNrAfUYu8pb2Rk6EBow': 1,
#  'UCR5ipBlStoUYuMJZakKQTLA': 1,
#  'UCMyyXCurk6jXXOWt2eKyCgg': 3,
#  'UCIGl_6GmKR7fPRBBDDRcR0Q': 1,
#  'UC54gPkG3GEwFNDxxueq5__A': 7,
#  'UCIYMha4U94ta2SUAUEJGCPA': 1,
#  'UC_BsvLreQRwuodBNmekJSqw': 1,
#  'UCpNBV-e-_D_8cxYP4arQd4A': 1,
#  'UCTSu4x8ahsJ16T9fWiwlKdg': 1,
#  'UC-M3mqjgXStNPkVkZLf4EUA': 2,
#  'UCC9if4ROH2RO8k8asekxYyA': 1,
#  'UC09TnEfWiPZptifvgYxwC4Q': 1,
#  'UCIjCwlHG4kaHYHeGdvyBB4Q': 1,
#  'UCJkMlOu7faDgqh4PfzbpLdg': 5,
#  'UCqJ2AFqEpwa_8xeFP-vmJVQ': 1,
#  'UCOEYBSAadyBJpzpRej7bVtw': 2,
#  'UCII0hP2Ycmhh5j8lS4cexBQ': 4,
#  'UCZOVADZ9qmqhyxL9DRQox2Q': 1,
#  'UCloOPkaQY_Wo0016hhe1Uhg': 1,
#  'UCGRB1ZjIqAiaGwt-XLq9CnA': 1,
#  'UC-M9eLhclbe16sDaxLzc0ng': 5,
#  'UCOaYkOKlNI_phqjlEQ8rtIg': 1,
#  'UCpvTnpyb4Fpcj8Gms4-PkLw': 1,
#  'UC0sytTpk1adR_cfjHhiJ08Q': 1,
#  'UCiB202OH2jNpS5oIRD7GEXg': 1,
#  'UC7fCHaJMqQn_kyB5ZPKsPdg': 1,
#  'UCyW8ZqouFxjlJEFPfE8f3dw': 1,
#  'UCYunCNCAjyMNY7cvssnHkhg': 1,
#  'UCkGthGTWjI2awl1pqCQRncQ': 2,
#  'UClCQI_L-iS5UvO5BC1HDFtg': 1,
#  'UCmQThz1OLYt8mb2PU540LOA': 2,
#  'UCXzL34BZy6Zx-JehfIjGdZQ': 3,
#  'UCDnFqgGj9ZP8cUciE8s9_-w': 1,
#  'UCijtN0JqzsEqzhPVbA7wKiA': 1,
#  'UCXeZ3H2x_eAVWN3fKQNxxtg': 1,
#  'UCB0ABGbdSggBXLF0UdN4d5A': 3,
#  'UCJcKVWFTooc1uSvLUWH08sQ': 1,
#  'UCV17pU7FxuU0_BKKVLTA6jA': 1,
#  'UCT31um1Ic8KweVWEMBC1K7A': 2,
#  'UC6csx5vR6yZLToQeepswSgw': 1,
#  'UClydU5bsfQTzebnMMZ4CqUw': 1,
#  'UC8jK_qPTLefP7tSEdCAnF-Q': 4,
#  'UCF8VNHnHs1faDFuD-ywldLg': 1,
#  'UCW9G5gdEQOA9GgtZefIbrZQ': 1,
#  'UCA9ny6OgbIM08aBg8i5dUfg': 1,
#  'UCVtEytgcL5fZcSiKx-BjimQ': 1,
#  'UCPUiGO8iYGi7_2h3AUymaIw': 1,
#  'UCio9eHYbIrKYK0j71nfUEqA': 2,
#  'UCzOh1Tok8rytS2Bcl7IX33A': 1,
#  'UCq9sSEvtgAU6dLjysnO-jOQ': 1,
#  'UCzoX5XCYaxZKDTVnk7cEXWg': 1,
#  'UC0wf4lCB7kBeqQN4IRp6ntQ': 4,
#  'UCGA7nPOXJkwtI-zU1gitDKw': 2,
#  'UCiYDCJxVAinVDnPq0Box1JA': 1,
#  'UCdS5sqt3r7wkTtaPgkfiIEQ': 2,
#  'UCMMlfkaoAu07PDvhh2M8J3A': 1,
#  'UCMR-7A2pf4iNq_6It-HM66w': 1,
#  'UC835-cI1YECh9iNMXH13fKw': 1,
#  'UCL3XrA4SheRl6y0NsRhGjRA': 4,
#  'UCSpvjDk06HLxBaw8sZw7SkA': 2,
#  'UCSuJjfAVOCAhaHicxqPHkGQ': 1,
#  'UCevr8amEiF35JY-2vhKtUuw': 3,
#  'UCDLUhFutpCnIEmFL-VF2n5A': 2,
#  'UC4UQFLK99sYuG1b8oRd5BvQ': 2,
#  'UCZJJpBbqY-eeNQrWz_Igsdg': 1,
#  'UCOeVhGZOgV_s0mOcVeGpatQ': 1,
#  'UCy83CGJe7nbeRDaqx2QtoMA': 1,
#  'UCfLAzLhQsUOYIAq02LB32nQ': 1,
#  'UC95Jrs8WBarzXFhFsmzOVmw': 1,
#  'UCLGe0PxyRFWmXVGJKq_gGvw': 2,
#  'UCjdTh4i86rUvrL9_S_73Drw': 1,
#  'UCL8Nxsa1LB9DrMTHtt3IKiw': 1,
#  'UCs-VUSOSWP22YuJHoDWTz_w': 1,
#  'UC4Y6bt3nixoEi-KngirFEvA': 1,
#  'UCHT2rctdd5RnXDZ-DoJOeEA': 4,
#  'UCO9LPWL-UtupgPug7Ad6nSA': 2,
#  'UCMfXktX6B6AzmgVk0LIJ45Q': 3,
#  'UC0n9yiP-AD2DpuuYCDwlNxQ': 1,
#  'UCTelpYBQRu9xXdkxuBLfDyA': 1,
#  'UCfHGGDUVLpjENQJne_SknBw': 1,
#  'UCTSCvnsxOcoknftrqdXQzyg': 4,
#  'UCYzUOg9p-Z_1o_e-Ua4-VHQ': 4,
#  'UCqpyFHhE13LsrG5qDknJcFQ': 1,
#  'UC1bdp3O9KHg0Q9JbocfJGyQ': 1,
#  'UC-vGJgaFhMZCP0fpKBFujtg': 1,
#  'UCNpY7BgxICtDNZDSGtqUdAw': 1,
#  'UCI9dGhdza3qupiV0mVNO97A': 1,
#  'UC_LSPsOpygfKRLo_QsCww_A': 1,
#  'UCvmX-MI8Jxahaw2soPdKfAQ': 1,
#  'UCvpZjspm7S2MTWBy7D-OQ0A': 6,
#  'UCmajVTORW3vp5qM8r0myznA': 1,
#  'UC7t5OM0oKq_x8w4oXjxqeWw': 1,
#  'UC3MZuJJHcwPvspSAkmTDGwA': 1,
#  'UC4g1owgPjW5WlpgNylPI1aw': 1,
#  'UCWsKxsqPkZsy-iLyQIb8qQQ': 1,
#  'UCfKQFcnpBW5QVKNXW7rzC3Q': 1,
#  'UC_i3FGKrtR0ixy4-8l_NpSA': 1,
#  'UC8rador8CU-pTJ6p7WNiv6w': 1,
#  'UCOdTRzlGI895eAJvuBdGgpg': 4,
#  'UCMgCvJ3_QahXgvwj6LjOd-w': 3,
#  'UCFtYib6opQe34It-d6C4qUQ': 1,
#  'UCYGk6uIV1r8Drsj2WHcIJlw': 2,
#  'UCMdWozpKxFvgCS716NrmS-w': 5,
#  'UCuH4xjfwVqU9LOrGamzLczg': 1,
#  'UC2a9zmrdjvLsrRgi4G4blWw': 3,
#  'UClZ7b9vI3QGjpdlmajHOXxA': 1,
#  'UCV24TA5OeBVp3ftnTGhmsWg': 1,
#  'UChbLEF49FP8HvmuaaFzfldA': 1,
#  'UCSk4LcffuVj6wTYPkRQ99Ew': 1,
#  'UCYsT86HPpToJxAjpVoTubvw': 2,
#  'UCRX7UEyE8kp35mPrgC2sosA': 3,
#  'UCEVEliy8HEExJ3qzus7U3LQ': 2,
#  'UCaMYfhdKrlqqEpkynPvgVQw': 12,
#  'UChnKIpHVGYVDfx8UGVrOpKA': 1,
#  'UCvN2kqDAGhH9M07gOohci4A': 2,
#  'UC4SUUloEcrgjsxbmy_rQQXA': 1,
#  'UCPd6iac_5S-XPz0qwZdV4rQ': 6,
#  'UCnGvDC6xz0XEseYW_SwToMg': 1,
#  'UCpcTrCXblq78GZrTUTLWeBw': 3,
#  'UCI7w8UvDDnGn1IjyxneUqaQ': 1,
#  'UCtVd0c0tGXuTSbU5d8cSBUg': 1,
#  'UCLEjjG12meCLTU4eLta8bVw': 2,
#  'UCGmnsW623G1r-Chmo5RB4Yw': 10,
#  'UCcZS2lT8AmdwPSFjnLBgAgw': 2,
#  'UC1TaReAPiLPy1dyHopzlaqA': 2,
#  'UCQjhljg4QE7fz2DjG1febeg': 2,
#  'UCqkZ2-0Pm3u9NNRBZ1icolg': 1,
#  'UCWgNIMSPkbNMmIhhMF_OkDg': 1,
#  'UCacByxmUzDpkn5WAnENoYrw': 1,
#  'UCzo12YMx9qRKlGcpf6yTTQA': 1,
#  'UCBZiUUYeLfS5rIj4TQvgSvA': 2,
#  'UCSN0oWRkNsrx_MdYK5QTHJQ': 1,
#  'UCG6yiJIGz3WCbD4POfFQxtQ': 1,
#  'UCRgCbwOa1f76Ec_eRBhhezA': 2,
#  'UCY2jUnU118sVkdj2xafiJ0g': 5,
#  'UC4gPKdabQVW2YyhCtO7JErw': 3,
#  'UC7xd6CSzzhpSJdfVS9Ekmag': 1,
#  'UC83YFC6NknBsg1fSWyXjOoQ': 1,
#  'UC5V4HHKqo9-0eQ-Lhjc7C0Q': 3,
#  'UCS1SHyxP0UhAg84AKamy3jA': 4,
#  'UCRKKTpP3IVdU9k7oCw1Ul1w': 1,
#  'UCutHc0-uTE1TKwEks93E_uA': 1,
#  'UCKHZtLB2ruUniTIXuCKB9WQ': 1,
#  'UCYraBfUqw2O6qeNYRowX4UA': 4,
#  'UC98I6fLu91w6R3rmwDxXmpw': 11,
#  'UCrIA3FSdgYseou-mmAPpn6A': 1,
#  'UCQ85zY0CVzslphEa0JIv_Tg': 1,
#  'UCsrgL-QuUioeuAKpbhy69XQ': 3,
#  'UC4qWDBnr9u2Ko7OGmELwv0A': 1,
#  'UC6_0TodTfmjbDA9m_rjGiIw': 1,
#  'UCzJfZozRYkKPbQP9xbGyFfA': 1,
#  'UC-RX7Rb0D8xmWGWIwL8kvmQ': 1,
#  'UC-LE7UowYotavwgFWKfN-nQ': 1,
#  'UC4bvYNI5G6eodqB7FridAmw': 1,
#  'UC0AE_22J0kAo30yjasaeFqw': 5,
#  'UCz-4oiSHDAgJTgHeAoqtCHg': 1,
#  'UCMfrQ47YaoNv_7zB9qAn5AQ': 1,
#  'UClxSHjCb9E3ctzZg5vj8Stw': 2,
#  'UCUwhDdyeWjyMlLEdLYVmU8g': 2,
#  'UCP5oS3-leCu2cuPktZNcZEw': 1,
#  'UCOlSkLGHRG-Xg_S4Tit9sWw': 2,
#  'UC0bC92gFO25qcJcECTQNN_A': 4,
#  'UC3RpTX6fEMJ6KBNTTgXJB9w': 2,
#  'UCf7P7LZsVOvv8KWs2p1YINw': 1,
#  'UCoBwP4F5BSu8QC_KUAvIXmg': 1,
#  'UCRI95a1fRD_8RTH1Wpz7P9A': 1,
#  'UCFgTraDDJbGGmK665419prg': 4,
#  'UCOphSwZiKwW_QbEdYVlKpjA': 1,
#  'UCZpKcVBccIjO9n0RXx3ZGFg': 1,
#  'UCsTcErHg8oDvUnTzoqsYeNw': 8,
#  'UC_gV70G_Y51LTa3qhu8KiEA': 5,
#  'UCddZO5JkiNWrjAmh7YeCNcQ': 2,
#  'UCnQtJro3IurKlxp7XSPqpaA': 1,
#  'UCFDxyA1H3VEN0VQwfMe2VMQ': 1,
#  'UCvgt4ph5fROR3Fo0_pBc43Q': 4,
#  'UCi844f7R7YxdWXEAo7Tkk7Q': 6,
#  'UC_NVYGhfkd7aXYqp-4rLFWA': 3,
#  'UCXtb5VOeeH7MehLE3soYXBw': 3,
#  'UCRHVCYjvfXWO_DpIYwYauyQ': 1,
#  'UCG7yOZ7cPubnm2J6J8evlhA': 3,
#  'UCuM4X4D5U3_udV_7hVuc77g': 1,
#  'UCQXRhiyzUqZIz7-WJYJ7PaQ': 2,
#  'UCrKXYE-Y4saxVFPI7Fuuzyw': 2,
#  'UC9m-qxco1XNevlxSvqyUouQ': 3,
#  'UCZ-qxagOkAmCEP-Tu6YliUQ': 4,
#  'UCxE76PmXA8V_5wHOWGpRrmA': 1,
#  'UCKta32VnUFelxucjL-xyugQ': 1,
#  'UCI9ZSwJFw7GgVzumTkw_WEQ': 2,
#  'UCLCOHYva87wg_Q_YmxXPnmQ': 1,
#  'UCN-Klifn9C7kINwpIA0uOHw': 1,
#  'UCmUNy7Ry5VAZH-8qojtYaTg': 1,
#  'UCsDl6A77CrbkSJLtxQFVDGw': 2,
#  'UCTwATkJREcvThWbnKBxhwDQ': 1,
#  'UCbGhNoP4CGW34r6P97RXSDA': 1,
#  'UCxMsgwldMZiuFTD6jjv32yQ': 5,
#  'UCLuQqm5mjCFoWNyBhL4G8Iw': 1,
#  'UCykERqO6KgqYF6t3l_hNVfQ': 1,
#  'UCNOB3ZW7bFz9zOrgk8m-bRA': 1,
#  'UCmeds0MLhjfkjD_5acPnFlQ': 1,
#  'UCWkr08nsQ9GuFvHgQYafi_w': 1,
#  'UCAoMPWcQKA_9Af5YhWdrZgw': 2,
#  'UCHuZmQ0lSW8TG81dVZZh5rw': 6,
#  'UCjB8ZGky2svRO8OQvr-qT5g': 1,
#  'UC-4M2IHj056bWaBcokUAXgQ': 2,
#  'UC3701gugFyUfCSjM0XNS-iw': 1,
#  'UC7eGPwc0OTHMo-l6RAml16Q': 1,
#  'UCUtTt06-cuZoprkR0GPQutg': 1,
#  'UC7FhOuPmxz8spz_xvJf_xow': 5,
#  'UCbbQalJ4OaC0oQ0AqRaOJ9g': 1,
#  'UC_9Rt5h1ieQYhLb452SQEoQ': 4,
#  'UCHBXe3D3JT0pGY37_0C8G2w': 3,
#  'UCzJIliq68IHSn-Kwgjeg2AQ': 1,
#  'UCzicAnUinaY78KhazBtmbTg': 9,
#  'UCN14VoNSni7WqcGeuWn2OLg': 8,
#  'UCRAosZcO3ifiCasetIdw8RQ': 1,
#  'UCJnbtZ0qx5Wnglcq28gA7-Q': 1,
#  'UCpF1zGJnci56b225IQB9-0A': 4,
#  'UC2NU0s1H0p9N4jvF7qV59vA': 1,
#  'UC1kPr-GOUJAtgdj7ZE_0Qig': 1,
#  'UCVTQuK2CaWaTgSsoNkn5AiQ': 6,
#  'UCdIWg_E1ckuONPTsdvevYgg': 1,
#  'UCcnNWp-tx3-FaCWV4pMFTAg': 1,
#  'UCy7MBnbfYT9SU7Ty7jDK3Vw': 1,
#  'UCbFnGyIcAhDrj-90OzvI7kw': 3,
#  'UCF9IpcBgYvMS3GKkM_xwiqA': 1,
#  'UCXXyrfKFDg2zUrmD1NMUvTA': 1,
#  'UCkuPobJMx7DPUdwlVo1TFfA': 4,
#  'UC8VWLYhEUPhZiZpt3JJBzAg': 2,
#  'UC1b3_sjaoNsCeoudk5dPq4Q': 1,
#  'UCRoYDJ82NUt5gTIGFa1Fn6A': 1,
#  'UCh0wrs-8ywjgZO7flfSmlqg': 1,
#  'UCo2ISnT2ZBA3aYYFilzli1g': 1,
#  'UCoj1MMpCJg1PZzH5cr3pr7g': 1,
#  'UCmsO3CyGDSgi1-XhkVns3TA': 3,
#  'UCdJdEguB1F1CiYe7OEi3SBg': 6,
#  'UC2mOfxCo3Sf8cEhm54cvJaQ': 1,
#  'UCEXFSf2qoF4ZNZ5sSBsYIkw': 4,
#  'UC4m1l1G3tpb4C1EiljBLI3A': 1,
#  'UCrbadOtGETTy2SjVRGt6geQ': 1,
#  'UCt-iWHoWz_iLXAfSX3NJUFQ': 1,
#  'UCa3pRChmBEOY5tc42-7RRXA': 1,
#  'UCUuZD1beHND0mnjJL3ZNhCw': 1,
#  'UCDWXSvLB8aoBAIJzqu58VWw': 1,
#  'UCnh59SDp1U1oF6wC8vk5-Pw': 1,
#  'UCnjK9YWSbd0AAjHhM3vAu7A': 1,
#  'UCie_AtZ1-Ooyjfp6tgieKkg': 1,
#  'UC0m6sH8e-FdNISwoeYjtJQQ': 1,
#  'UCYdtOv2wKNgd3MYf9ZSOGtw': 2,
#  'UCjumxqJ0E7rxXDhfMC80bQg': 3,
#  'UCxXmY0UeTN9NbdsxPvvF4xg': 1,
#  'UCMnPZh6PyA5PSYoNt0cjuxg': 2,
#  'UCkoTaszxu8JUlcMerwi41WA': 3,
#  'UCKXs11Oj1codrEy33D6XgkQ': 1,
#  'UC4Boh-JJrLC60ZiNTaSwAxA': 2,
#  'UCDB-Sy9lw2R-muVoK8nE_BQ': 3,
#  'UCxSz6JVYmzVhtkraHWZC7HQ': 2,
#  'UClX69_vYjZkkk2Xn87ZN9Vw': 1,
#  'UCG2JpNasy6zqbDr3FOUOgJQ': 1,
#  'UCy0KW2N_CiPUCra1J2H9mXg': 1,
#  'UCngMw0G2y2YFLPVbyEsfVog': 4,
#  'UCQd82ZrlW8b8_MujwDO9ajw': 4,
#  'UCQiT2drDUu-X0gE13NoUxlw': 2,
#  'UCdKAKyBRBOhM2bcxtag3pEg': 1,
#  'UCcN5pRT1RBLVVcaTXSf0_CA': 1,
#  'UCjxAJ62JFIoyWU14F9yZ1WQ': 1,
#  'UCRC7W-nFQhzjommX4VL4hFg': 1,
#  'UCXV_RBIFNTulEdcuKkRZhBA': 3,
#  'UC6HFaHrumuF4Y1W6r0wZa7Q': 1,
#  'UCt_t6FwNsqr3WWoL6dFqG9w': 5,
#  'UCHCph-_jLba_9atyCZJPLQQ': 4,
#  'UCwML8GCqkP1UbKVEqzbPpbQ': 1,
#  'UC4vT3qTr8fwVS7IsPgqaGCQ': 6,
#  'UC0BvmQ-UWDnDc9seBcSanRA': 1,
#  'UCAdUn5nnzd7SHxwivr0Y6mg': 1,
#  'UC4m9rhlOV1VCFbqZJXpVcFw': 1,
#  'UCSv-qhxlF4tKSj9bn9D8dtA': 1,
#  'UCpr4KsHaDSfS3EsrDFreLig': 1,
#  'UC_V1C2x4I71CNttRyUlLLLQ': 1,
#  'UCfvssu5wvOX5vPHruFHxaJw': 2,
#  'UCe175uyEJ0BL-XoDjWYEXtA': 1,
#  'UCSxLDHfK2yzL7jhCJWG7EPg': 1,
#  'UCuBwNHXUJY7wg1qcJdq08Yg': 3,
#  'UCKe6w0exI94U-RzqAyoY1VA': 5,
#  'UCJhnjPLyVIrMEydRtLMoaGg': 2,
#  'UCDw3OJ18XPW_d97amcn2yCg': 1,
#  'UCeUYwh-WiIoG47ECQvQxKsA': 5,
#  'UCkrdI6_uNjgw4LUbE6JCxmQ': 1,
#  'UCiND1uo3qhV7peJCkGeDumQ': 1,
#  'UCJ_beVv6STCc-ahDiG2x8ig': 2,
#  'UC4-bcER4WWrAqLSoq50dmzw': 1,
#  'UCO2Yez6kJYRmXDlWACVg_hw': 2,
#  'UCPkHlo8qsFWEiMhlHRIcLyQ': 1,
#  'UCPHXtOVmjvbP9OJihsd7gCg': 5,
#  'UCXeEpbu7Ia6-KWZcteeeCSQ': 1,
#  'UCku6eQ82A8yQzZ0QFv1xlSQ': 1,
#  'UCyyGJDITMRC0DbxMJQdG3aA': 4,
#  'UCPvx9GpqtJYaS9mllhzHnoA': 2,
#  'UCqRraVICLr0asn90cAvkIZQ': 1,
#  'UCAvwetms56ntZtQWkYoqEIQ': 1,
#  'UCg7lal8IC-xPyKfgH4rdUcA': 3,
#  'UC3ta8QbpOZeXxEdCuF8mxzw': 1,
#  'UCRP9dtwcZVRbZ-b2xs-jKtA': 1,
#  'UCyG_mUXBIWaoLkuiRnAWDvA': 4,
#  'UCscCSZoK3BknJKSZry17JiQ': 1,
#  'UC5I2hjZYiW9gZPVkvzM8_Cw': 1,
#  'UCOWUNZA1AijnF_uTcEt1GVA': 1,
#  'UCzfW1TX7tTN8YC3okF2W33A': 1,
#  'UClr2w9Y8o8S-KG6hxvm6HLg': 3,
#  'UC_LYwDvadRtiDyVTPqS73NQ': 1,
#  'UC1MZSpslIu5BLp2WvWYJRzw': 4,
#  'UCuTfanz0SvSK-Cg7zgZNkGQ': 4,
#  'UCdTfFrHxFfPA_seIk6OH4Hg': 1,
#  'UClarhNTgYk5wuztsunOx2Cw': 1,
#  'UCX8Rig7syHiCNfbllCjQsTQ': 2,
#  'UC_YydHJ2xTRctvZgAq2YC1A': 1,
#  'UCuUsh8tSpCzQSfTBPXHMlHA': 1,
#  'UCCdbWBXlTmBkqAZSl3O11-Q': 1,
#  'UCGZUI9cloMsjXdGTNcnbjFw': 1,
#  'UCy-pRSIMMBsp-AZlV4go3vw': 5,
#  'UC5v0MIieVwwYZgsmhJ8YNoQ': 1,
#  'UCiFIe01TK1RuHSRf4HL23ZA': 1,
#  'UC7x4oF7wz9iABY-AsMaZ0_Q': 1,
#  'UCHiOdkM6bB29MnsqKJW762A': 1,
#  'UCFLzjEjXvQxfIynnis_9N5Q': 2,
#  'UCnWL55MDph0EBpr7aeSz8-A': 1,
#  'UCHle8xt_YqgwVqnimyoapyA': 9,
#  'UCRjpH-yyhlqtzdWO3_o2tQQ': 1,
#  'UC9Pbo1KXq5LRSV8yNTW6jtw': 1,
#  'UCpBkBMO8IbYAMdtYNaMxKgQ': 3,
#  'UC4Rr0bNviQhqG41aIG_HJJw': 3,
#  'UCYCnGi1DXHvHlffFY7pEDmQ': 5,
#  'UCBABwcl4rEOUlX9MAWw9jIw': 2,
#  'UCDt4dFdsJyjjA8mQULkOLLw': 5,
#  'UC-uPNldCnPeasW6iUSD2ODQ': 1,
#  'UCS3hX9ajO9p8BVro5O5mLNA': 2,
#  'UCsh8nwFp0JhAUbCy3YYB1RA': 1,
#  'UCH04_WiU4pSm6qH6EsuvtKw': 1,
#  'UCtRNf-1fRJT36ywpBL6cZqw': 1,
#  'UCsyMrOnR00_qRn57BxSI_7A': 1,
#  'UCvo5K33uLCggS5K_fpWXh4A': 2,
#  'UC0HQzjG4ttIg2j74a1_4ISg': 1,
#  'UCbO5NezK3oE-u8dBzEtwm9A': 1,
#  'UC1xwwLwm6WSMbUn_Tp597hQ': 1,
#  'UCQUoZPIgJYIif6bX7rbWlGg': 6,
#  'UC9xvzqqefobTOSclNTFtOkQ': 1,
#  'UCNWlx_0XxpUkci6PnCwH_dQ': 2,
#  'UCsJTILBiwQ_51L2yN67ZGeQ': 3,
#  'UCX_I4OYHtepE1LgmD-FxgEg': 1,
#  'UCJiJcj6eQpPIFqn_tKc6umw': 1,
#  'UCZenRGLPfB_IwmDnYlIx6Qg': 1,
#  'UCk3UVvyjBZLg20CmRRfwdvA': 1,
#  'UCxjs86jJMMa3Mhxt8KThsYA': 1,
#  'UCfzPHd4iRcgzevtxtKwCbaw': 1,
#  'UCENsEdSphkXuvIVlfqpU-7Q': 1,
#  'UCZMG3yAmFFBdZvw5RbpjcZA': 1,
#  'UCfmcficWfsbYy3gqiuWOzqA': 1,
#  'UCZfHpifEjx8tiLlvVQWvmgw': 6,
#  'UCgkgitLqIpOvqafanUD2AVQ': 2,
#  'UCj1NFgILYDJj664zIyA_Ocw': 1,
#  'UCUm6ogIfXGUuvFNM2g-_OFA': 2,
#  'UCTd8KPOJjkZ_r5zt5yrculg': 1,
#  'UCVgV3U01KnT646fAGjlRsKQ': 2,
#  'UCv1FgMM56Ulpmz8RDa33hfQ': 1,
#  'UCAZVp6THoC95ZZXxEaDNEwg': 1,
#  'UCchrr0T1E3eAWwopSRkknkA': 1,
#  'UCRrCiR_F-olJgMClfsl7YAg': 2,
#  'UC9V4YMznqy74Ve2cW0KCg6w': 1,
#  'UCJTWU5K7kl9EE109HBeoldA': 6,
#  'UCyuDBN8RWdEsYKNxdkbaGKg': 1,
#  'UCS0IyAjNbVEZXK71iOVgXlQ': 6,
#  'UCXyCAcjoWz9SMLGJT8dR0pA': 6,
#  'UC2k2x0gsgTYxqIkxQGe8hmQ': 3,
#  'UC63UZ-gmGAqoIk-Kxd3A6mg': 1,
#  'UC2pmfLm7iq6Ov1UwYrWYkZA': 4,
#  'UCuFXFUfqqGwKMMTI4o4qwHg': 1,
#  'UCIOIKnbmiEu-TL7xxlJuSTg': 1,
#  'UCaA927wFhJrs8WYnoLv5Rlg': 1,
#  'UCPajkkwdrzikFZzsBWIUoyA': 1,
#  'UCH4pgep82jmDFn3ZaFz46cw': 3,
#  'UC_emNizR6F0IYAu68pl3Y1Q': 1,
#  'UCAy_KEOjhjKP7BETzJrsaxg': 2,
#  'UCVzf8FYePStNECgM-AcSiqg': 1,
#  'UCGk3_R7hOzRaXcdTnF4QJvw': 1,
#  'UCXUytomDrKxU699nTxPCbLw': 1,
#  'UCzK_0O9NZeH9T5_zCWVQQoQ': 3,
#  'UC4Vb3jy9KeLcsYGHsiSk_jg': 1,
#  'UCynIYcsBwTrwBIecconPN2A': 2,
#  'UC9et8o7xZFng0OCNSA0ILKA': 4,
#  'UCdbxCNuDuhfzo2veDYBOcjw': 1,
#  'UCTXeJ33DzXI2veQpKfrvaYw': 1,
#  'UCEaomcRESR3tBQDs3O8TPEQ': 2,
#  'UCMu5gPmKp5av0QCAajKTMhw': 5,
#  'UCb1e2wIwTsbwoY318fk9Rmw': 1,
#  'UCEA4OwRUESSdq9_E5l-TELQ': 1,
#  'UCk9gPdY4fbH0BRhyTio9XIg': 1,
#  'UCcZ2nCUn7vSlMfY5PoH982Q': 1,
#  'UCcoJdqoJtjqj8zcG93QoyHg': 1,
#  'UCkWQ0gDrqOCarmUKmppD7GQ': 2,
#  'UCAiVvAu8goct_cQeOgpI07g': 1,
#  'UCz4KEygtdLIPNnryTeF7hog': 4,
#  'UCrxsbWp33yuZmQvHfYyP4eg': 7,
#  'UC9cJaIlANnGSVSEG3fA1z0Q': 1,
#  'UCzA9MkuQ-Jaa8TxXHHIvXbw': 1,
#  'UCePLML9taJYjoDrYohkEr6Q': 1,
#  'UCi7r2oNnEN0oHc1XDVkFUxA': 1,
#  'UCaIyJ4xNpwHBfR6Jd0AgLWQ': 4,
#  'UCFsrZ8ZbpciuTQDqeuIC1xg': 6,
#  'UC0KCCM5Y1j74Lkkxp0VsHHw': 1,
#  'UC_DS_Smk2habvdDJuS5gv6A': 1,
#  'UCEG_X195mDPg7KpAKiFg5jQ': 16,
#  'UCSLyvqPsNDKWm_11aWW6-9g': 1,
#  'UCuw1VDsmOWOldKGLYq6AkVg': 1,
#  'UCTzlQb5zXxT5cIb0QiEvZRQ': 1,
#  'UCLjHvoc_KLJV8GNeVBJdVVw': 2,
#  'UCsEukrAd64fqA7FjwkmZ_Dw': 9,
#  'UCOnH80veDXqAPF8jDVZQDeA': 1,
#  'UCi8FFfKYNNNZz2XjkbWdcpw': 2,
#  'UCmHE6JlZdi9CgLXNts5jNaA': 1,
#  'UC412PVVGZGt_htPub-XmNLQ': 4,
#  'UCRib3CNrtW0giPkKy3R2WOw': 1,
#  'UCootdudxV2EbMHOlvtKeDAg': 6,
#  'UCY__1FyOajX2l9T0no4uNBQ': 1,
#  'UCvD9GB-E4q_TuMpwUtFBhLA': 6,
#  'UC-DUdA7u2Q2zuHuok3vBv9w': 1,
#  'UCY2hV7xJqrGzaQoTyIr5zvw': 1,
#  'UCaOuM_M71WxH1aSjaIsIeBA': 2,
#  'UCa1WbVCkTqd5ecG6G2adIow': 1,
#  'UC9LSOx3idPsQ-Va_J4Bz6oQ': 2,
#  'UCrqsNpKuDQZreGaxBL_a5Jg': 4,
#  'UC5U7SUlhBSQW1at6Y-aZbzg': 6,
#  'UCtwPnQE0sGDu0PbY5gQ8fnw': 1,
#  'UCukCyHaD-bK3in_pKpfH9Eg': 1,
#  'UCEl915e-AtoJ7i1m_SXekTw': 1,
#  'UCmPGLq_t9w2n8hItBPqE1ZA': 1,
#  'UCF6n7-CirehhlpyMPhivO0g': 2,
#  'UCc3hN1wa36Ymgd8yZtNjHTQ': 2,
#  'UCNAz5Ut1Swwg6h6ysBtWFog': 4,
#  'UCz5CCA2lIUyC1JMaTbQjH3g': 2,
#  'UC50rQms-q7Qjl9ft0wMNaLA': 1,
#  'UCziw6dXMaE2how8TxUUqqmA': 1,
#  'UCLDUF5JqXn2FAXY3tAAl6TQ': 1,
#  'UC0u9FKn2vM0HRhQx_eI5qwQ': 3,
#  'UCl0R2_Y0-E81FGZWLoriQ0A': 2,
#  'UCeD3VwVu0HzIkPbLwl1D_VA': 2,
#  'UCdsUfxjDZXY7yECf89Sow0w': 1,
#  'UCDoRuWwhUztZfUOZxzlpRPQ': 1,
#  'UC2x37qSXsLmhmftaS-ic_gA': 3,
#  'UCBR8-60-B28hp2BmDPdntcQ': 2,
#  'UCqvEXxPyPRTUdEE_AXBe-tA': 3,
#  'UCLYimOsgmIVf6KNjzXPkUwQ': 1,
#  'UC4IEmIzWf_X4lEPtGm7kgzQ': 2,
#  'UCc2_j9TZ1UU9nCedF3UsuFQ': 4,
#  'UCR_GYJ9ssHTTVW9hiunEWvg': 1,
#  'UChd7R5X3Ed3woUz3M13nSxA': 4,
#  'UCjgpFI5dU-D1-kh9H1muoxQ': 3,
#  'UCpwFulVhWRsS92nYOTdh-uw': 1,
#  'UCHLywIFGrNhgHxeI1dRpfOg': 3,
#  'UC6JRrn_7Qe1CZBcQDMieadw': 4,
#  'UCJ47W_WzuzbHaONWB5a9i7w': 5,
#  'UCem5WH8j6f0R4IpF55z0zqQ': 1,
#  'UCKLCWpdCH6vqbGBiYw5RGkA': 2,
#  'UCAkP51BEzkKimJh7KDflx_g': 3,
#  'UCNpbTBAGC2aYfqfos9DDyAw': 1,
#  'UCpkURvAKJTxbtM64x3ZEgUA': 1,
#  'UCD_P_X2TdzlF_n-Uobnvf5g': 1,
#  'UCRUULstZRWS1lDvJBzHnkXA': 1,
#  'UCepghKFsRQbEcmpv3O1VFuQ': 1,
#  'UC-CbPYT4pz-y4hgyy7PZ2-w': 2,
#  'UCvmWj7t7nP3yOSU_rl9doCQ': 1,
#  'UCcJa3B-7SEjnrijLkJVplDA': 2,
#  'UCT_j3a9mJYv601Tp3Bcy-QQ': 1,
#  'UCjkUQ-_fGADyBYrIWviibmg': 1,
#  'UCTs-d2DgyuJVRICivxe2Ktg': 1,
#  'UCZfDHQE3mrZ7123Wl3iRhbg': 1,
#  'UCCdnua4PSRmgmnLVrzICp_Q': 1,
#  'UCqemGRNILm3F13r7IM6-kkw': 2,
#  'UC040XFJEsSRhTkmieXp1kDQ': 1,
#  'UCHxUvRJB7ypxsC_2_8pnXjw': 1,
#  'UC81hVmI5eEBIt3s3HQpJd_w': 1,
#  'UCm4JnxTxtvItQecKUc4zRhQ': 1,
#  'UCNqLq36of2I_YWqPuGJjSwg': 1,
#  'UCZOVdmfatIcyt2Db_06HLsA': 1,
#  'UCRNCZ4jZcjhhC_ST-6Yvw1g': 1,
#  'UCZ_3XN3kr6ShGxXmt6jwSsQ': 1,
#  'UCe_DN7kH6urn-1DGZPLhBlQ': 1,
#  'UCr6jTDO4DqyB_JlU5Uyn0cw': 1,
#  'UCtqWqzD_uzZ_ydEJDgyU79g': 1,
#  'UCp2y1jHxpSQohLodTInRD-Q': 1,
#  'UCkqnyO9IhmZaa_pdQ1lwmaw': 6,
#  'UCIKF1msqN7lW9gplsifOPkQ': 1,
#  'UCWiPkogV65gqqNkwqci4yZA': 5,
#  'UCMeSdTmzXitYH2nnHLDlxFA': 1,
#  'UCWq-qJSudqKrzquTVep9Jwg': 1,
#  'UC7gnV9U47_yawcpfOUnipSw': 2,
#  'UCef29bYGgUSoJjVkqhcAPkw': 2,
#  'UCFyoQVryRKUxWpROdGpJWGw': 1,
#  'UCYUQQgogVeQY8cMQamhHJcg': 2,
#  'UCZgCEJCy4I1OO8PqBK2fLCQ': 1,
#  'UCOIdrWi76lzuNg4lKRWYnhQ': 1,
#  'UCM8r8bIG7xKRGDEd7oSyxPQ': 1,
#  'UC1e6iW4ojbhn0gUCyvjawKg': 3,
#  'UCfC3R0Y2LfjFAw1k5Hdzgbw': 1,
#  'UCS613EogLXE0lTsxyC1cWLA': 3,
#  'UCSYGTjJdJId2LDq405WdPpQ': 2,
#  'UC4--UkLF_QyNAwc1hxrH0tw': 1,
#  'UCnU2EtUW8Z4DxSqXxJ5cMQg': 7,
#  'UCSrPuHtKbst7Zy8pyWn_3Cg': 6,
#  'UCq3zaHCaZtb3TtNwwz0PK2w': 5,
#  'UCBbsyG0o_cWlyY46ZRSdYJg': 4,
#  'UCRVKN08mowTmLPY9BnJH9GQ': 1,
#  'UCU5lVrQpVHgAA0zAleZdxLA': 2,
#  'UCaNV51NgkCnEXWcrR8Utv0A': 5,
#  'UC8nidfOKkcgpO6tfc9OSdBQ': 2,
#  'UCZOnSuO8tWFXLp8a828lgtA': 1,
#  'UCs7Sp_-bnuFcFu3D-z16acw': 3,
#  'UC_MkjhQr_D_lGlO3uu-GxyA': 1,
#  'UCi0aSU3x06FHJ2hUHgc0_Xw': 2,
#  'UCGMEwmTEHMhRZg1revBjxzw': 1,
#  'UC9ql--q_LV7zhDI1CCO9Xdg': 2,
#  'UCwk3ZUfODiv4KygYVf6TLpQ': 1,
#  'UCdKHj5_rH5IwARj2fEl9dIQ': 1,
#  'UCsrY4q8xGPJQbQ8HPQZn6iA': 1,
#  'UCmY3dSr-0TOkJqy0btd2AJg': 3,
#  'UCz0CFmWykIY0FqpkF7GgbuA': 1,
#  'UCAzyupPG4vdo8jd9nJ13LAw': 1,
#  'UCWwyZFbSiQoKDUfXmAvqA9A': 1,
#  'UCl03K9tXZWLKOf6cu3aHOfA': 1,
#  'UCM_vP8QqPyVCnGxT8bKtrLw': 1,
#  'UCuTN5_c8WljtfCaSw-bypGA': 3,
#  'UCXvhJmqkKXI6fvWtv9uEUcw': 1,
#  'UC_q-UNDJeEBSHqKzAP_8x_A': 4,
#  'UCplTh7UXTKHPkahcpin2yOg': 3,
#  'UCTK88HZEOljUoIZyOrLSM2g': 5,
#  'UCFl_bV4TB1KuM6kqOuemCQg': 1,
#  'UCQDOCKAxfpGz0651lfVFx0g': 1,
#  'UCnHe3m9lqUpXZlkTPaVf5vw': 2,
#  'UCVT3jHWD4S74JibMTzX0pmA': 1,
#  'UC8DA3ySHaLzyhkYHZANpVOA': 9,
#  'UCY_ZUvCv9C_tv5yC0YR0eWg': 3,
#  'UCWDIL65Y3kHmLjfp_0ZrpfQ': 4,
#  'UCu6_Ypm5e8WEvBRKop6oblw': 1,
#  'UCn6j0KektGIuQNRdGbFPNww': 1,
#  'UCocVP3aqyyAxWnaU-Xxi0PA': 2,
#  'UCh2gZBX_qZ5qjkPY8x3bSSA': 1,
#  'UCn7Z0uhzGS1KjnO-sWml_dw': 1,
#  'UCflb1gG-X1dy1Ru5JIk5sPw': 6,
#  'UC8yspKRsCdec9XvRSHFDB2w': 1,
#  'UCcWl6q7rcJ9WoF_Kwmxg23A': 13,
#  'UCX68OES0EiFTMylVKFoszZg': 1,
#  'UC9WE5MrJCDIFpb2CFLWGjJg': 2,
#  'UC0bHk99PoUpappP5dpDMMYg': 1,
#  'UC33YY4rzVmYkrLlLCMl7KEA': 1,
#  'UC9k9wQAp0SrWYZVORZnPIlg': 1,
#  'UCNqEKy6csRlAJ7fBL2CtXfg': 1,
#  'UCJsSEDFFnMFvW9JWU6XUn0Q': 1,
#  'UCcLAlDdJLIbfQc3EAQTn90A': 1,
#  'UCdvjM7WQLJ-EpJ80g1XmLtA': 1,
#  'UCzZHRlm3DmzBZcpbKn2vlWw': 1,
#  'UCHgleR62IO4SCuDaOLZ4njw': 2,
#  'UCRRxSTgPUY0q_YToaczc2BQ': 2,
#  'UC5-gWZXAQqSGVfPHkA7NRiQ': 6,
#  'UCmi9wFeEZCV9gMDO-Sw_F-w': 1,
#  'UC2XHI5iGgrQjDAids9J3SsA': 1,
#  'UCIinw2AQWa-tir4LC4A-Iow': 1,
#  'UCXBE_QQSZueB8082ml5fslg': 4,
#  'UCWvAYJ--6HicfWAhqJdMYAg': 1,
#  'UCLXV9vzJwgYOyGaZlD89VfA': 1,
#  'UCAiKrZDrrSJnLpDM-zEVyng': 1,
#  'UCpB959t8iPrxQWj7G6n0ctQ': 2,
#  'UC-s_hG_sI02u_4k0-sOdt-w': 1,
#  'UCYwjLObJIPhvdBUC7DWZReA': 1,
#  'UCQIUhhcmXsu6cN6n3y9-Pww': 4,
#  'UCJkWoS4RsldA1coEIot5yDA': 5,
#  'UCP9ma95lbHYbjzPKTfiNgRQ': 2,
#  'UCV-0wytm-vh-p92aJidWSkA': 1,
#  'UClZF-fzz_0u8jN9on7UAPSg': 1,
#  'UCDWnt6Lpy485nkGZYDg7kVw': 1,
#  'UCgzxHGWC2YlphdqTWZeHvPQ': 1,
#  'UC7IcJI8PUf5Z3zKxnZvTBog': 5,
#  'UCvHstDy96lx3R971bTX4gLg': 1,
#  'UC-HcCN_4a9mJ2OjKjLsVzMw': 1,
#  'UCZMaXa587unuwLlRtzwNQ1A': 1,
#  'UCUfpQmWcv3JsVkQUGv8w__w': 1,
#  'UC9_3h1t3FEvhC-1toDU3fww': 1,
#  'UC6P24bhhCmMPOcujA9PKPTA': 3,
#  'UCGUmDohfMwaqdkWwOMxyGRw': 2,
#  'UC_wfQp3EVnGNee-GwGzKcSQ': 1,
#  'UCZa48HasUkTB9yW8LK5HUgw': 3,
#  'UCAWlwILydRAPX0TUJeEH1tw': 1,
#  'UCaCl_YJvwRuT9tSciCavOxQ': 1,
#  'UCxa1aSLYVSb_yl6uCbZRQKw': 3,
#  'UCkOny4N1-Qn9UTx7pYnEL3A': 1,
#  'UCuQHSPd2qUUX7MXfATV0CjA': 1,
#  'UCmcdjO73mZy8w0XzIY-HBOA': 1,
#  'UCrtTfCAu6LaDF3liSc4D3mg': 1,
#  'UCZ9YdClgOz-5qEvkc1s3j6Q': 1,
#  'UCFYMDSW-BzeYZKFSxROw3Rg': 3,
#  'UCr7SOnf5UUAuVQsl6d5HSaw': 2,
#  'UCb2fKNBRtC06yz_NsUGbYgw': 3,
#  'UC_4Pa96XptXJfcksvM1ao8w': 1,
#  'UCPRlGA2w7C_DVw-1ynolJYw': 1,
#  'UCLSzSrVi-XZJvRBIwFYxc4Q': 1,
#  'UC2fhTIbnQlFYaFzyTcmPkXg': 2,
#  'UCDZESjYAwh-ws7ZSZZ8DKeg': 3,
#  'UC2TT4PdhvEBgdAmrGv-2QuA': 2,
#  'UCB1dTI-Djbe6YIEzJCYaz_g': 1,
#  'UCzqbfYjQmf9nLQPMxVgPhiA': 2,
#  'UC8pyuVwduKKfTvV3kGeMFTg': 3,
#  'UCBJuxfqZuiibvcwSc8ViGsQ': 1,
#  'UCh49FvTrwKYFgHU0Ssrqyww': 1,
#  'UCDO89DCjRd7tt5-yLmRUXKg': 1,
#  'UCdP03tbrVRJmPwiCZgXVeAw': 6,
#  'UCH0OPrZkDKwIiWgLz4dULQQ': 2,
#  'UCU4CZAbdWW1VCjBsjFBb3oQ': 1,
#  ...}

# %% [markdown]
# ### Kindness x betweenness regression

# %%
slope, intercept, r_value, p_value, std_err = ss.linregress(x=df["betweenness"],y=df["kindness"])
line = slope*df["betweenness"]+intercept
slope, intercept, r_value, p_value, std_err
# Out:
# (0.31983470724569923,
#  0.001228809327340851,
#  0.02400497450125736,
#  0.027487007567903426,
#  0.14505539208839227)

# %%
plt.plot(df["betweenness"],df["kindness"],'o', df["betweenness"], line)
plt.xlabel("Kindness")
plt.ylabel("Betweenness")
# Out:
# Text(0, 0.5, 'Betweenness')

# %% [markdown]
# ### Kindness x closeness regression

# %%
slope, intercept, r_value, p_value, std_err = ss.linregress(x=df["closeness"],y=df["kindness"])
line = slope*df["closeness"]+intercept
slope, intercept, r_value, p_value, std_err### Kindness x betweenness regression
# Out:
# (0.12065639965982783,
#  -0.00010027351427306544,
#  0.01840626304804266,
#  0.09097724001590445,
#  0.07137495687213474)

# %%
plt.plot(df["closeness"],df["kindness"],'o', df["closeness"], line)
# Out:
# [<matplotlib.lines.Line2D at 0x7f707d6666d8>,
#  <matplotlib.lines.Line2D at 0x7f707d6667f0>]

# %%
slope, intercept, r_value, p_value, std_err = ss.linregress(x=df["publishedAt"],y=df["kindness"])
line = slope*df["publishedAt"]+intercept
slope, intercept, r_value, p_value, std_err### Kindness x betweenness regression
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-aabd22a25719> in <module>
# ----> 1 slope, intercept, r_value, p_value, std_err = ss.linregress(x=int(df["publishedAt"]),y=df["kindness"])
#       2 line = slope*df["publishedAt"]+intercept
#       3 slope, intercept, r_value, p_value, std_err### Kindness x betweenness regression
#
# ~/.local/lib/python3.5/site-packages/pandas/core/series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
#  'title': g.nodes[n]['title'],
#         'country': g.nodes[n]['country'],
#         'publishedAt': g.nodes[n]['publishedAt'],
#         'viewCount': g.nodes[n]['viewCount'],
#         'subscriberCount': g.nodes[n]['subscriberCount'],
#         'videoCount': g.nodes[n]['videoCount'],
#         'topics': g.nodes[n]['topics'],
#         'kindness': g.nodes[n]['kindness'],
#         'outdegrees': g.nodes[n]['outdegrees'],
#         'indegrees': g.nodes[n]['indegrees'],
#         'betweenness': g.nodes[n]['betweenness'],
#         'closeness': g.nodes[n]['closeness'],
